# %%
try:
    import openmdao.api as om
    import dymos as dm
except ImportError:
    # !python -m pip install openmdao[notebooks]
    # !python -m pip install dymos
    import openmdao.api as om
    import dymos as dm

# %% [markdown]
# # Water Rocket
#
# Author: Bernardo Bahia Monteiro (bbahia@umich.edu)
#
# In this example, we will optimize a water rocket for range and height at the apogee, using design variables that are easily modifiable just before launch: the empty mass, the initial water volume and the launch angle.
# This example builds on [multi-phase cannonball](../multi_phase_cannonball/multi_phase_cannonball.md) ane is adapted from _Optimization of a Water Rocket in OpenMDAO/Dymos_ {cite}`bbahia_2020`.
#
# ## Nomenclature
#
# | Symbol               | definition                             |
# |----------------------|----------------------------------------|
# | $v_\text{out}$       | water exit speed at the nozzle         |
# | $A_\text{out}$       | nozzle area                            |
# | $V_w$                | water volume in the rocket             |
# | $p$                  | pressure in the rocket                 |
# | $p_a$                | ambient pressure                       |
# | $\dot{\,}$           | time derivative                        |
# | $k$                  | polytropic constant                    |
# | $V_b$                | internal volume of the rocket          |
# | $\rho_w$             | water density                          |
# | $T$                  | thrust                                 |
# | $q$                  | dynamic pressure                       |
# | $S$                  | cross sectional area                   |
# | $(\cdot)_0$          | value of $(\cdot)$ at $t=0$            |
# | $t$                  | time                                   |

# %% [markdown]
# ## Problem Formulation
#
# A natural objective function for a water rocket is the maximum height achieved by the rocket during flight, or the horizontal distance it travels, i.e. its range.
# The design of a water rocket is somewhat constrained by the soda bottle used as its engine.
# This means that the volume available for water and air is fixed, the initial launch pressure is limited by the bottle's strength (since the pressure is directly related to the energy available for the rocket, it is easy to see that it should be as high as possible) and the nozzle throat area is also fixed.
# Given these manufacturing constraints, the design variables we are left with are the empty mass (it can be easily changed through adding ballast), the water volume at the launch, and the launch angle.
# With this considerations in mind, a natural formulation for the water rocket problem is
#
# \begin{align}
#     \text{maximize}   &\quad \text{range or height} \\
#     \text{w.r.t.}     &\quad \text{empty mass, initial water volume, launch angle, trajectory} \\
#     \text{subject to} &\quad \text{flight dynamics} \\
#                       &\quad \text{fluid dynamics inside the rocket} \\
#                       &\quad 0 < \text{initial water volume} < \text{volume of bottle} \\
#                       &\quad 0^\circ < \text{launch angle} < 90^\circ \\
#                       &\quad 0 < \text{empty mass}
# \end{align}

# %% [markdown]
# ##  Model
#
# The water rocket model is divided into three basic components: a *water engine*, responsible for modelling the fluid dynamics inside the rocket and returning its thrust;  the *aerodynamics*, responsible for calculating the atmospheric drag of the rocket; and the *equations of motion*, responsible for propagating the rocket's trajectory in time, using Newton's laws and the forces provided by the other two components.
#
# In order to integrate these three basic components, some additional interfacing components are necessary: an atmospheric model to provide values of ambient pressure for the water engine and air density to the calculation of the dynamic pressure for the aerodynamic model, and a component that calculates the instantaneous mass of the rocket by summing the water mass with the rocket's empty mass.
# The high level layout of this model is shown in below.
#
# <figure>
#   <img src="figures/water_rocket_overview.svg"/>
#   <figcaption>N2 diagram for the water rocket model</figcaption>
# </figure>
#
# `atmos`, `dynamic_pressure`, `aero` and `eom` are the same models used in [multi-phase cannonball](../multi_phase_cannonball/multi_phase_cannonball.md).
# The remaining components are discussed below.
#
# ```{Warning}
# The `eom` component has a singularity in the flight path angle derivative when the flight speed is zero.
# This happens because the rotational dynamics are not modelled.
# This can cause convergence problems if the launch velocity is set to zero or the launch angle is set to $90^\circ$
# ```
#
# ```{Note}
# Since the range of altitudes achieved by the water rocket is very small (100m), the air density and pressure are practically constant, thus the use of an atmospheric model is not necessary. However, using it makes it easier to reuse code from [multi-phase cannonball (../multi_phase_cannonball/multi_phase_cannonball.md).
# ```
#
# ### Water engine
#
# The water engine is modelled by assuming that the air expansion in the rocket
# follows an adiabatic process and the water flow is incompressible and inviscid,
# i.e.  it follows Bernoulli's equation. We also make the following simplifying
# assumptions:
#
# 1. The thrust developed after the water is depleted is negligible
# 2. The area inside the bottle is much smaller than the nozzle area
# 3. The inertial forces do not affect the fluid dynamics inside the bottle
#
# This simplified modelling can be found in Prusa[@Prusa2000].
# A more rigorous formulation, which drops all these simplifying assumptions can be found in Wheeler[@Wheeler2002], Gommes[@Gommes2010], and Barria-Perotti[@BarrioPerotti2010].
#
# The first assumption leads to an underestimation of the rocket performance, since the air left in the bottle after it is out of water is known to generate appreciable thrust[@Thorncroft2009].
# This simplified model, however, produces physically meaningful results.
#
# There are two states in this dynamical model, the water volume in the rocket $V_w$ and the gauge pressure inside the rocket $p$.
# The constitutive equations and the N2 diagram showing the model organization are shown below.
#
# ### Constitutive equations of the water engine model
# | Component              | Equation                                                    |
# | -----------------------|-------------------------------------------------------------|
# | water_exhaust_speed    | $v_\text{out} = \sqrt{2(p-p_a)/\rho_w}$                     |
# | water_flow_rate        | $\dot{V}_w = -v_\text{out} A_\text{out}$                    |
# | pressure_rate          | $\dot{p} = kp\frac{\dot{V_w}}{(V_b-V_w)}$                   |
# | water_thrust           | $T = (\rho_w v_\text{out})(v_\text{out}A_\text{out})$       |
#
# <figure>
#   <img src="figures/water_rocket_waterengine.svg"/>
#   <figcaption>N2 diagram for the water engine group</figcaption>
# </figure>
#
# ### Water engine
#
# The water engine is modelled by assuming that the air expansion in the rocket
# follows an adiabatic process and the water flow is incompressible and inviscid,
# i.e.  it follows Bernoulli's equation. We also make the following simplifying
# assumptions:
#
# 1. The thrust developed after the water is depleted is negligible
# 2. The area inside the bottle is much smaller than the nozzle area
# 3. The inertial forces do not affect the fluid dynamics inside the bottle
#
# This simplified modelling can be found in Prusa {cite}`Prusa2000`.
# A more rigorous formulation, which drops all these simplifying assumptions can be found in Wheeler {cite}`Wheeler2002`, Gommes {cite}`Gommes2010`, and Barria-Perotti {cite}`BarrioPerotti2010`.
#
# The first assumption leads to an underestimation of the rocket performance, since the air left in the bottle after it is out of water is known to generate appreciable thrust {cite}`Thorncroft2009`.
# This simplified model, however, produces physically meaningful results.
#
# There are two states in this dynamical model, the water volume in the rocket $V_w$ and the gauge pressure inside the rocket $p$.
# The constitutive equations and the N2 diagram showing the model organization are shown below.
#
# ### Constitutive equations of the water engine model
# | Component              | Equation                                                    |
# | -----------------------|-------------------------------------------------------------|
# | water_exhaust_speed    | $v_\text{out} = \sqrt{2(p-p_a)/\rho_w}$                     |
# | water_flow_rate        | $\dot{V}_w = -v_\text{out} A_\text{out}$                    |
# | pressure_rate          | $\dot{p} = kp\frac{\dot{V_w}}{(V_b-V_w)}$                   |
# | water_thrust           | $T = (\rho_w v_\text{out})(v_\text{out}A_\text{out})$       |
#
# <figure>
#   <img src="figures/water_rocket_waterengine.svg"/>
#   <figcaption>N2 diagram for the water engine group</figcaption>
# </figure>

# %%
import numpy as np

import openmdao.api as om


class WaterEngine(om.Group):
    """
    Computes thrust and water flow for a water.

    Simplifications:
     - the pressure due to the water column in the non inertial frame (i.e.
       under a+g acceleration) is insignificant compared to the air pressure
     - the water does not have appreciable speed inside the bottle
    """
    def initialize(self):
        self.options.declare('num_nodes', types=int)

    def setup(self):
        nn = self.options['num_nodes']

        self.add_subsystem(name='water_exhaust_speed',
                           subsys=_WaterExhaustSpeed(num_nodes=nn),
                           promotes=['p', 'p_a', 'rho_w'])

        self.add_subsystem(name='water_flow_rate',
                           subsys=_WaterFlowRate(num_nodes=nn),
                           promotes=['A_out', 'Vdot'])

        self.add_subsystem(name='pressure_rate',
                           subsys=_PressureRate(num_nodes=nn),
                           promotes=['p', 'k', 'V_b', 'V_w', 'Vdot', 'pdot'])

        self.add_subsystem(name='water_thrust',
                           subsys=_WaterThrust(num_nodes=nn),
                           promotes=['rho_w', 'A_out', 'F'])

        self.connect('water_exhaust_speed.v_out', 'water_flow_rate.v_out')
        self.connect('water_exhaust_speed.v_out', 'water_thrust.v_out')

# %%
class _WaterExhaustSpeed(om.ExplicitComponent):
    def initialize(self):
        self.options.declare('num_nodes', types=int)

    def setup(self):
        nn = self.options['num_nodes']

        self.add_input(name='rho_w', val=1e3*np.ones(nn), desc='water density', units='kg/m**3')
        self.add_input(name='p', val=6.5e5*np.ones(nn), desc='air pressure', units='N/m**2')  # 5.5bar = 80 psi
        self.add_input(name='p_a', val=1.01e5*np.ones(nn), desc='air pressure', units='N/m**2')

        self.add_output(name='v_out', shape=(nn,), desc='water exhaust speed', units='m/s')

        ar = np.arange(nn)

        self.declare_partials(of='*', wrt='*', rows=ar, cols=ar)

    def compute(self, inputs, outputs):
        p = inputs['p']
        p_a = inputs['p_a']
        rho_w = inputs['rho_w']

        outputs['v_out'] = np.sqrt(2*(p-p_a)/rho_w)

    def compute_partials(self, inputs, partials):
        p = inputs['p']
        p_a = inputs['p_a']
        rho_w = inputs['rho_w']

        v_out = np.sqrt(2*(p-p_a)/rho_w)

        partials['v_out', 'p'] = 1/v_out/rho_w
        partials['v_out', 'p_a'] = -1/v_out/rho_w
        partials['v_out', 'rho_w'] = dv_outdrho_w = 1/v_out*(-(p-p_a)/rho_w**2)

# %%
class _PressureRate(om.ExplicitComponent):
    def initialize(self):
        self.options.declare('num_nodes', types=int)

    def setup(self):
        nn = self.options['num_nodes']

        self.add_input(name='p', val=np.ones(nn), desc='air pressure', units='N/m**2')
        self.add_input(name='k', val=1.4*np.ones(nn), desc='polytropic coefficient for expansion', units=None)
        self.add_input(name='V_b', val=2e-3*np.ones(nn), desc='bottle volume', units='m**3')
        self.add_input(name='V_w', val=1e-3*np.ones(nn), desc='water volume', units='m**3')
        self.add_input(name='Vdot', shape=(nn,), desc='water flow', units='m**3/s')

        self.add_output(name='pdot', shape=(nn,), desc='pressure derivative', units='N/m**2/s')

        ar = np.arange(nn)

        self.declare_partials(of='*', wrt='*', rows=ar, cols=ar)

    def compute(self, inputs, outputs):
        p = inputs['p']
        k = inputs['k']
        V_b = inputs['V_b']
        V_w = inputs['V_w']
        Vdot = inputs['Vdot']

        pdot = p*k*Vdot/(V_b-V_w)

        outputs['pdot'] = pdot

    def compute_partials(self, inputs, partials):
        p = inputs['p']
        k = inputs['k']
        V_b = inputs['V_b']
        V_w = inputs['V_w']
        Vdot = inputs['Vdot']

        partials['pdot', 'p'] = k*Vdot/(V_b-V_w)
        partials['pdot', 'k'] = p*Vdot/(V_b-V_w)
        partials['pdot', 'V_b'] = -p*Vdot/(V_b-V_w)**2
        partials['pdot', 'V_w'] = p*Vdot/(V_b-V_w)**2
        partials['pdot', 'Vdot'] = p*k/(V_b-V_w)

# %%
class _WaterFlowRate(om.ExplicitComponent):
    """ Computer water flow rate"""
    def initialize(self):
        self.options.declare('num_nodes', types=int)

    def setup(self):
        nn = self.options['num_nodes']

        self.add_input(name='A_out', val=np.ones(nn), desc='nozzle outlet area', units='m**2')
        self.add_input(name='v_out', val=np.zeros(nn), desc='water exhaust speed', units='m/s')

        self.add_output(name='Vdot', shape=(nn,), desc='water flow', units='m**3/s')

        ar = np.arange(nn)

        self.declare_partials(of='*', wrt='*', rows=ar, cols=ar)

    def compute(self, inputs, outputs):
        A_out = inputs['A_out']
        v_out = inputs['v_out']

        outputs['Vdot'] = -v_out*A_out

    def compute_partials(self, inputs, partials):
        A_out = inputs['A_out']
        v_out = inputs['v_out']

        partials['Vdot', 'A_out'] = -v_out
        partials['Vdot', 'v_out'] = -A_out

# %% [markdown]
# The `_MassAdder` component calculates the rocket's instantaneous mass by
# summing the water mass with the rockets empty mass, i.e.
#
# \begin{align}
#     m = m_\text{empty}+\rho_w V_w
# \end{align}

# %%
class _MassAdder(om.ExplicitComponent):

    def initialize(self):
        self.options.declare('num_nodes', types=int)

    def setup(self):
        nn = self.options['num_nodes']

        self.add_input('m_empty', val=np.zeros(nn), desc='empty mass', units='kg')
        self.add_input('V_w', val=1e-3*np.ones(nn), desc='water volume', units='m**3')
        self.add_input('rho_w', val=1e3*np.ones(nn), desc="water density", units='kg/m**3')

        self.add_output('m', val=np.zeros(nn), desc='total mass', units='kg')

        ar = np.arange(nn)
        self.declare_partials('*', '*', cols=ar, rows=ar)

    def compute(self, inputs, outputs):
        outputs['m'] = inputs['m_empty'] + inputs['rho_w']*inputs['V_w']

    def compute_partials(self, inputs, jacobian):
        jacobian['m', 'm_empty'] = 1
        jacobian['m', 'rho_w'] = inputs['V_w']
        jacobian['m', 'V_w'] = inputs['rho_w']

# %% [markdown]
# Now these components are joined in a single group

# %%
class WaterPropulsionODE(om.Group):

    def initialize(self):
        self.options.declare('num_nodes', types=int)
        self.options.declare('ballistic', types=bool, default=False,
                             desc='If True, neglect propulsion system.')

    def setup(self):
        nn = self.options['num_nodes']

        self.add_subsystem(name='atmos',
                           subsys=USatm1976Comp(num_nodes=nn))

        if not self.options['ballistic']:
            self.add_subsystem(name='water_engine',
                               subsys=WaterEngine(num_nodes=nn))

            self.add_subsystem(name='mass_adder',
                               subsys=_MassAdder(num_nodes=nn))

        self.add_subsystem(name='dynamic_pressure',
                           subsys=DynamicPressureComp(num_nodes=nn))

        self.add_subsystem(name='aero',
                           subsys=LiftDragForceComp(num_nodes=nn))

        self.add_subsystem(name='eom',
                           subsys=FlightPathEOM2D(num_nodes=nn))

        self.connect('atmos.rho', 'dynamic_pressure.rho')
        self.connect('dynamic_pressure.q', 'aero.q')

        self.connect('aero.f_drag', 'eom.D')
        self.connect('aero.f_lift', 'eom.L')

        if not self.options['ballistic']:
            self.connect('atmos.pres', 'water_engine.p_a')
            self.connect('water_engine.F', 'eom.T')
            self.connect('mass_adder.m', 'eom.m')

# %% [markdown]
# ## Phases
#
# The flight of the water rocket is split in three distinct phases: propelled ascent, ballistic ascent and ballistic descent.
# If the simplification of no thrust without water were lifted, there would be an extra "air propelled ascent" phase between the propelled ascent and ballistic ascent phases.
#
# **Propelled ascent:** is the flight phase where the rocket still has water inside, and hence it is producing thrust.
# The thrust is given by the water engine model, and fed into the flight dynamic equations.
# It starts at launch and finishes when the water is depleted, i.e. $V_w=0$.
#
# **Ballistic ascent:** is the flight phase where the rocket is ascending ($\gamma>0$) but produces no thrust.
# This phase begins at the end of thepropelled ascent phase and ends at the apogee, defined by $\gamma=0$.
#
# **Descent:** is the phase where the rocket is descending without thrust.
# It begins at the end of the ballistic ascent phase and ends with ground impact, i.e. $h=0$.

# %%
def new_propelled_ascent_phase(transcription):
    propelled_ascent = dm.Phase(ode_class=WaterPropulsionODE,
                                transcription=transcription)

    # All initial states except flight path angle and water volume are fixed
    # Final flight path angle is fixed (we will set it to zero so that the phase ends at apogee)
    # Final water volume is fixed (we will set it to zero so that phase ends when bottle empties)
    propelled_ascent.set_time_options(
        fix_initial=True, duration_bounds=(0.001, 0.5), duration_ref=0.1, units='s')
    propelled_ascent.add_state('r', units='m', rate_source='eom.r_dot',
                               fix_initial=True, fix_final=False, ref=1.0, defect_ref=1.0)
    propelled_ascent.add_state('h', units='m', rate_source='eom.h_dot', targets=['atmos.h'],
                               fix_initial=True, fix_final=False, ref=1.0, defect_ref=1.0)
    propelled_ascent.add_state('gam', units='deg', rate_source='eom.gam_dot', targets=['eom.gam'],
                               fix_initial=False, fix_final=False, lower=0, upper=85.0, ref=90)
    propelled_ascent.add_state('v', units='m/s', rate_source='eom.v_dot', targets=['dynamic_pressure.v', 'eom.v'],
                               fix_initial=True, fix_final=False, ref=100, defect_ref=100)

    propelled_ascent.add_state('p', units='bar', rate_source='water_engine.pdot',
                               targets=['water_engine.p'], fix_initial=True, fix_final=False,
                               lower=1.02)
    propelled_ascent.add_state('V_w', units='L', rate_source='water_engine.Vdot',
                               targets=['water_engine.V_w', 'mass_adder.V_w'],
                               fix_initial=False, fix_final=True, ref=10, defect_ref=10)

    propelled_ascent.add_parameter(
        'S', targets=['aero.S'], units='m**2')
    propelled_ascent.add_parameter(
        'm_empty', targets=['mass_adder.m_empty'], units='kg')
    propelled_ascent.add_parameter(
        'V_b', targets=['water_engine.V_b'], units='m**3')

    propelled_ascent.add_timeseries_output('water_engine.F', 'T', units='N')

    return propelled_ascent

# %%
def new_ballistic_ascent_phase(transcription):
    ballistic_ascent = dm.Phase(ode_class=WaterPropulsionODE, transcription=transcription,
                                ode_init_kwargs={'ballistic': True})

    # All initial states are free (they will be  linked to the final stages of propelled_ascent).
    # Final flight path angle is fixed (we will set it to zero so that the phase ends at apogee)
    ballistic_ascent.set_time_options(
        fix_initial=False, initial_bounds=(0.001, 1), duration_bounds=(0.001, 10),
        duration_ref=1, units='s')

    ballistic_ascent.add_state('r', units='m', rate_source='eom.r_dot', fix_initial=False,
                               fix_final=False)
    ballistic_ascent.add_state('h', units='m', rate_source='eom.h_dot', targets=['atmos.h'],
                               fix_initial=False, fix_final=False)
    ballistic_ascent.add_state('gam', units='deg', rate_source='eom.gam_dot', targets=['eom.gam'],
                               fix_initial=False, fix_final=True, upper=89)
    ballistic_ascent.add_state('v', units='m/s', rate_source='eom.v_dot',
                               targets=['dynamic_pressure.v', 'eom.v'], fix_initial=False,
                               fix_final=False)

    ballistic_ascent.add_parameter('S', targets=['aero.S'], units='m**2')
    ballistic_ascent.add_parameter('m_empty', targets=['eom.m'], units='kg')

    return ballistic_ascent

# %%
def new_descent_phase(transcription):
    descent = dm.Phase(ode_class=WaterPropulsionODE, transcription=transcription,
                       ode_init_kwargs={'ballistic': True})

    # All initial states and time are free (they will be linked to the final states of ballistic_ascent).
    # Final altitude is fixed (we will set it to zero so that the phase ends at ground impact)
    descent.set_time_options(initial_bounds=(.5, 100), duration_bounds=(.5, 100),
                             duration_ref=10, units='s')

    descent.add_state('r', units='m', rate_source='eom.r_dot', fix_initial=False, fix_final=False)
    descent.add_state('h', units='m', rate_source='eom.h_dot', targets=['atmos.h'],
                      fix_initial=False, fix_final=True)
    descent.add_state('gam', units='deg', rate_source='eom.gam_dot', targets=['eom.gam'],
                      fix_initial=False, fix_final=False)
    descent.add_state('v', units='m/s', rate_source='eom.v_dot',
                      targets=['dynamic_pressure.v', 'eom.v'], fix_initial=False, fix_final=False)

    descent.add_parameter('S', targets=['aero.S'], units='m**2')
    descent.add_parameter('mass', targets=['eom.m'], units='kg')

    return descent

# %% [markdown]
# ##  Model parameters
#
# The model requires a few constant parameters.
# The values used are shown in the following table.
#
# Values for parameters in the water rocket model
#
# |   Parameter        | Value                | Unit         | Reference                                           |
# |--------------------|----------------------|--------------|-----------------------------------------------------|
# | $C_D$              | 0.3450               | -            | {cite}`BarrioPerotti2009`                           |
# | $S$                | $\pi 106^2/4$        | $mm^2$       | {cite}`BarrioPerotti2009`                           |
# | $k$                | 1.2                  | -            | {cite}`Thorncroft2009` {cite}`Fischer2020` {cite}`Romanelli2013`   |
# | $A_\text{out}$     | $\pi22^2/4$          | $mm^2$       | {cite}`aircommand_nozzle`                                |
# | $V_b$              | 2                    | L            |                                                     |
# | $\rho_w$           | 1000                 | $kg/m^3$     |                                                     |
# | $p_0$              | 6.5                  | bar          |                                                     |
# | $v_0$              | 0.1                  | $m/s$        |                                                     |
# | $h_0$              | 0                    | $m$          |                                                     |
# | $r_0$              | 0                    | $m$          |                                                     |
#
# Values for the bottle volume $V_b$, its cross-sectional area $S$ and the nozzle area $A_\text{out}$ are determined by the soda bottle that makes the rocket primary structure, and thus are not easily modifiable by the designer.
# The polytropic coefficient $k$ is a function of the moist air characteristics inside the rocket.
# The initial speed $v_0$ must be set to a value higher than zero, otherwise the flight dynamic equations become singular.
# This issue arises from the angular dynamics of the rocket not being modelled.
# The drag coefficient $C_D$ is sensitive to the aerodynamic design, but can be optimized by a single discipline analysis.
# The initial pressure $p_0$ should be maximized in order to obtain the maximum range or height for the rocket.
# It is limited by the structural properties of the bottle, which are modifiable by the designer, since the bottle needs to be available commercially.
# Finally, the starting point of the rocket is set to the origin.
#
# ## Putting it all together
#
# The different phases must be combined in a single trajectory, and linked in a sequence.
# Here we also define the design variables.

# %%
def new_water_rocket_trajectory(objective):
    tx_prop = dm.Radau(num_segments=50, order=3, compressed=True)
    tx_bal = dm.Radau(num_segments=10, order=3, compressed=True)
    tx_desc = dm.Radau(num_segments=10, order=3, compressed=True)
    traj = dm.Trajectory()

    # Add phases to trajectory
    propelled_ascent = traj.add_phase('propelled_ascent', new_propelled_ascent_phase(tx_prop))
    ballistic_ascent = traj.add_phase('ballistic_ascent', new_ballistic_ascent_phase(tx_bal))
    descent = traj.add_phase('descent', new_descent_phase(tx_desc))

    # Link phases
    traj.link_phases(phases=['propelled_ascent', 'ballistic_ascent'], vars=['*'])
    traj.link_phases(phases=['ballistic_ascent', 'descent'], vars=['*'])

    # Set objective function
    if objective == 'height':
        ballistic_ascent.add_objective('h', loc='final', ref=-1.0)
    elif objective == 'range':
        descent.add_objective('r', loc='final', ref=-0.01)
    else:
        raise ValueError(f"objective='{objective}' is not defined. Try using 'height' or 'range'")

    # Add design parameters to the trajectory.
    traj.add_parameter('CD',
                       targets={'propelled_ascent': ['aero.CD'],
                                'ballistic_ascent': ['aero.CD'],
                                'descent': ['aero.CD']},
                       val=0.3450, units=None, opt=False)
    traj.add_parameter('CL',
                       targets={'propelled_ascent': ['aero.CL'],
                                'ballistic_ascent': ['aero.CL'],
                                'descent': ['aero.CL']},
                       val=0.0, units=None, opt=False)
    traj.add_parameter('T',
                       targets={'ballistic_ascent': ['eom.T'],
                                'descent': ['eom.T']},
                       val=0.0, units='N', opt=False)
    traj.add_parameter('alpha',
                       targets={'propelled_ascent': ['eom.alpha'],
                                'ballistic_ascent': ['eom.alpha'],
                                'descent': ['eom.alpha']},
                       val=0.0, units='deg', opt=False)

    traj.add_parameter('m_empty', units='kg', val=0.15,
                       targets={'propelled_ascent': 'm_empty',
                                'ballistic_ascent': 'm_empty',
                                'descent': 'mass'},
                       lower=0, upper=1, ref=0.1,
                       opt=True)
    traj.add_parameter('V_b', units='m**3', val=2e-3,
                       targets={'propelled_ascent': 'V_b'},
                       opt=False)

    traj.add_parameter('S', units='m**2', val=np.pi*106e-3**2/4, opt=False)
    traj.add_parameter('A_out', units='m**2', val=np.pi*22e-3**2/4.,
                       targets={'propelled_ascent': ['water_engine.A_out']},
                       opt=False)
    traj.add_parameter('k', units=None, val=1.2, opt=False,
                       targets={'propelled_ascent': ['water_engine.k']})

    return traj, {'propelled_ascent': propelled_ascent,
                  'ballistic_ascent': ballistic_ascent,
                  'descent': descent}

# %% [markdown]
# ## Helper Functions to Access the Results

# %%
def summarize_results(water_rocket_problem):
    p = water_rocket_problem
    Entry = namedtuple('Entry', 'value unit')
    summary = {
        'Launch angle': Entry(p.get_val('traj.propelled_ascent.timeseries.states:gam',  units='deg')[0, 0], 'deg'),
        'Flight angle at end of propulsion': Entry(p.get_val('traj.propelled_ascent.timeseries.states:gam',
                                                   units='deg')[-1, 0], 'deg'),
        'Empty mass': Entry(p.get_val('traj.parameters:m_empty', units='kg')[0], 'kg'),
        'Water volume': Entry(p.get_val('traj.propelled_ascent.timeseries.states:V_w', 'L')[0, 0], 'L'),
        'Maximum range': Entry(p.get_val('traj.descent.timeseries.states:r', units='m')[-1, 0], 'm'),
        'Maximum height': Entry(p.get_val('traj.ballistic_ascent.timeseries.states:h', units='m')[-1, 0], 'm'),
        'Maximum velocity': Entry(p.get_val('traj.propelled_ascent.timeseries.states:v', units='m/s')[-1, 0], 'm/s'),
    }

    return summary

# %%
def plot_propelled_ascent(p, exp_out):
    fig, ax = plt.subplots(5, 1, sharex=True, figsize=(4, 8))
    t_imp = p.get_val('traj.propelled_ascent.time', 's')
    t_exp = exp_out.get_val('traj.propelled_ascent.time', 's')

    ax[0].plot(t_imp, p.get_val('traj.propelled_ascent.timeseries.states:p', 'bar'), 'ro', markerfacecolor='None')
    ax[0].plot(t_exp, exp_out.get_val('traj.propelled_ascent.timeseries.states:p', 'bar'), 'r-')
    ax[0].set_ylabel('p (bar)')
    ax[0].set_ylim(bottom=0)

    ax[1].plot(t_imp, p.get_val('traj.propelled_ascent.timeseries.states:V_w', 'L'), 'ro', markerfacecolor='None')
    ax[1].plot(t_exp, exp_out.get_val('traj.propelled_ascent.timeseries.states:V_w', 'L'), 'r-')
    ax[1].set_ylabel('$V_w$ (L)')
    ax[1].set_ylim(0, p.get_val('traj.parameters:V_b', 'L')[0])

    ax[2].plot(t_imp, p.get_val('traj.propelled_ascent.timeseries.T', 'N'), 'ro', markerfacecolor='None')
    ax[2].plot(t_exp, exp_out.get_val('traj.propelled_ascent.timeseries.T', 'N'), 'r-')
    ax[2].set_ylabel('T (N)')
    ax[2].set_ylim(bottom=0)

    ax[3].plot(t_imp, p.get_val('traj.propelled_ascent.timeseries.states:v', 'm/s'), 'ro', markerfacecolor='None')
    ax[3].plot(t_exp, exp_out.get_val('traj.propelled_ascent.timeseries.states:v', 'm/s'), 'r-')
    ax[3].set_ylabel('v (m/s)')
    ax[3].set_ylim(bottom=0)

    ax[4].plot(t_imp, p.get_val('traj.propelled_ascent.timeseries.states:gam', 'deg'), 'ro', markerfacecolor='None')
    ax[4].plot(t_exp, exp_out.get_val('traj.propelled_ascent.timeseries.states:gam', 'deg'), 'r-')
    ax[4].set_ylabel('$\gamma$ (deg)')
    ax[4].yaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins='auto', steps=[1, 1.5, 3, 4.5, 6, 9, 10]))

    ax[-1].set_xlabel('t (s)')

    fig.tight_layout()

# %%
def plot_states(p, exp_out):
    fig, axes = plt.subplots(nrows=4, ncols=1, figsize=(4, 8), sharex=True)

    states = ['r', 'h', 'v', 'gam']
    units = ['m', 'm', 'm/s', 'deg']
    phases = ['propelled_ascent', 'ballistic_ascent', 'descent']

    time_imp = {'ballistic_ascent': p.get_val('traj.ballistic_ascent.timeseries.time'),
                'propelled_ascent': p.get_val('traj.propelled_ascent.timeseries.time'),
                'descent': p.get_val('traj.descent.timeseries.time')}

    time_exp = {'ballistic_ascent': exp_out.get_val('traj.ballistic_ascent.timeseries.time'),
                'propelled_ascent': exp_out.get_val('traj.propelled_ascent.timeseries.time'),
                'descent': exp_out.get_val('traj.descent.timeseries.time')}

    x_imp = {phase: {state: p.get_val(f"traj.{phase}.timeseries.states:{state}", unit)
                     for state, unit in zip(states, units)
                     }
             for phase in phases
             }

    x_exp = {phase: {state: exp_out.get_val(f"traj.{phase}.timeseries.states:{state}", unit)
                     for state, unit in zip(states, units)
                     }
             for phase in phases
             }

    for i, (state, unit) in enumerate(zip(states, units)):
        axes[i].set_ylabel(f"{state} ({unit})" if state != 'gam' else f'$\gamma$ ({unit})')

        axes[i].plot(time_imp['propelled_ascent'], x_imp['propelled_ascent'][state], 'ro', markerfacecolor='None')
        axes[i].plot(time_imp['ballistic_ascent'], x_imp['ballistic_ascent'][state], 'mo', markerfacecolor='None')
        axes[i].plot(time_imp['descent'], x_imp['descent'][state], 'bo', markerfacecolor='None')
        axes[i].plot(time_exp['propelled_ascent'], x_exp['propelled_ascent'][state], 'r-', label='Propelled Ascent')
        axes[i].plot(time_exp['ballistic_ascent'], x_exp['ballistic_ascent'][state], 'm-', label='Ballistic Ascent')
        axes[i].plot(time_exp['descent'], x_exp['descent'][state], 'b-', label='Descent')

        if state == 'gam':
            axes[i].yaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins='auto', steps=[1, 1.5, 3, 4.5, 6, 9, 10]))
            axes[i].set_yticks(np.arange(-90, 91, 45))

    axes[i].set_xlabel('t (s)')
    axes[0].legend()

    fig.tight_layout()

# %%
def plot_trajectory(p, exp_out):
    fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(6, 8))

    time_imp = {'ballistic_ascent': p.get_val('traj.ballistic_ascent.timeseries.time'),
                'propelled_ascent': p.get_val('traj.propelled_ascent.timeseries.time'),
                'descent': p.get_val('traj.descent.timeseries.time')}

    time_exp = {'ballistic_ascent': exp_out.get_val('traj.ballistic_ascent.timeseries.time'),
                'propelled_ascent': exp_out.get_val('traj.propelled_ascent.timeseries.time'),
                'descent': exp_out.get_val('traj.descent.timeseries.time')}

    r_imp = {'ballistic_ascent': p.get_val('traj.ballistic_ascent.timeseries.states:r'),
             'propelled_ascent': p.get_val('traj.propelled_ascent.timeseries.states:r'),
             'descent': p.get_val('traj.descent.timeseries.states:r')}

    r_exp = {'ballistic_ascent': exp_out.get_val('traj.ballistic_ascent.timeseries.states:r'),
             'propelled_ascent': exp_out.get_val('traj.propelled_ascent.timeseries.states:r'),
             'descent': exp_out.get_val('traj.descent.timeseries.states:r')}

    h_imp = {'ballistic_ascent': p.get_val('traj.ballistic_ascent.timeseries.states:h'),
             'propelled_ascent': p.get_val('traj.propelled_ascent.timeseries.states:h'),
             'descent': p.get_val('traj.descent.timeseries.states:h')}

    h_exp = {'ballistic_ascent': exp_out.get_val('traj.ballistic_ascent.timeseries.states:h'),
             'propelled_ascent': exp_out.get_val('traj.propelled_ascent.timeseries.states:h'),
             'descent': exp_out.get_val('traj.descent.timeseries.states:h')}

    axes.plot(r_imp['propelled_ascent'], h_imp['propelled_ascent'], 'ro', markerfacecolor='None')
    axes.plot(r_imp['ballistic_ascent'], h_imp['ballistic_ascent'], 'mo', markerfacecolor='None')
    axes.plot(r_imp['descent'], h_imp['descent'], 'bo', markerfacecolor='None')

    axes.plot(r_exp['propelled_ascent'], h_exp['propelled_ascent'], 'r-')
    axes.plot(r_exp['ballistic_ascent'], h_exp['ballistic_ascent'], 'm-')
    axes.plot(r_exp['descent'], h_exp['descent'], 'b-')

    axes.set_xlabel('r (m)')
    axes.set_ylabel('h (m)')
    axes.set_aspect('equal', 'box')

    fig.tight_layout()

# %% [markdown]
# ## Optimizing for Height

# %%
from dymos.models.atmosphere import USatm1976Comp
from dymos.examples.aircraft_steady_flight.dynamic_pressure_comp import DynamicPressureComp
from dymos.examples.min_time_climb.aero.lift_drag_force_comp import LiftDragForceComp
from dymos.models.eom.flight_path_eom_2d import FlightPathEOM2D
from dymos.examples.water_rocket.water_engine_comp import _WaterThrust
from dymos.examples.water_rocket.phases import set_sane_initial_guesses
from dymos.examples.water_rocket.water_propulsion_ode import WaterPropulsionODE
import matplotlib.pyplot as plt
import matplotlib as mpl
from collections import namedtuple

p = om.Problem(model=om.Group())

traj, phases = new_water_rocket_trajectory(objective='height')
traj = p.model.add_subsystem('traj', traj)

p.driver = om.pyOptSparseDriver(optimizer='IPOPT')
p.driver.opt_settings['print_level'] = 4
p.driver.opt_settings['max_iter'] = 1000
p.driver.declare_coloring()

# Finish Problem Setup
p.model.linear_solver = om.DirectSolver()

p.setup()
set_sane_initial_guesses(p, phases)

p.run_driver()

summary = summarize_results(p)
for key, entry in summary.items():
    print(f'{key}: {entry.value:6.4f} {entry.unit}')

exp_out = traj.simulate(times_per_seg=200)

# NOTE: only the last figure is shown in the generated docs
plot_propelled_ascent(p, exp_out)
plot_trajectory(p, exp_out)
plot_states(p, exp_out)

plt.show()

# Check results (tolerance is relative unless value is zero)
# Out:
# --- Linkage Report [traj] ---
#     --- propelled_ascent - ballistic_ascent ---
#         time [final]  ==  time [initial]
#         r    [final]  ==  r    [initial]
#         h    [final]  ==  h    [initial]
#         gam  [final]  ==  gam  [initial]
#         v    [final]  ==  v    [initial]
# ----------------------------
#     --- ballistic_ascent - descent ---
#         time [final]  ==  time [initial]
#         r    [final]  ==  r    [initial]
#         h    [final]  ==  h    [initial]
#         gam  [final]  ==  gam  [initial]
#         v    [final]  ==  v    [initial]
# ----------------------------
# Full total jacobian was computed 3 times, taking 4.169893 seconds.
# Total jacobian shape: (1151, 1153)
#
#
# Jacobian shape: (1151, 1153)  ( 0.70% nonzero)
# FWD solves: 21   REV solves: 0
# Total colors vs. total size: 21 vs 1153  (98.2% improvement)
#
# Sparsity computed using tolerance: 1e-25
# Time to compute sparsity: 4.169893 sec.
# Time to compute coloring: 2.950234 sec.
# Memory to compute coloring: -21.539062 MB.
#
#
# Optimization Problem -- Optimization using pyOpt_sparse
# ================================================================================
#     Objective Function: _objfunc
#
#     Solution:
# --------------------------------------------------------------------------------
#     Total Time:                    7.7799
#        User Objective Time :       0.5181
#        User Sensitivity Time :     4.1986
#        Interface Time :            2.3373
#        Opt Solver Time:            0.7258
#     Calls to Objective Function :      65
#     Calls to Sens Function :           48
#
#
#    Objectives
#       Index  Name                                                          Value          Optimum
#           0  traj.phases.ballistic_ascent.indep_states.states:h    -5.413318E+01     0.000000E+00
#
#    Variables (c - continuous, i - integer, d - discrete)
#       Index  Name                                                       Type      Lower Bound            Value      Upper Bound     Status
#           0  traj.parameters:m_empty_0                                     c     0.000000E+00     1.425115E+00     1.000000E+01
#           1  traj.phases.propelled_ascent.time_extents.t_duration_0        c     1.000000E-02     8.785118E-01     5.000000E+00
#           2  traj.phases.propelled_ascent.indep_states.states:r_0          c    -1.000000E+21     1.260854E-05     1.000000E+21
#           3  traj.phases.propelled_ascent.indep_states.states:r_1          c    -1.000000E+21     5.365894E-05     1.000000E+21
#           4  traj.phases.propelled_ascent.indep_states.states:r_2          c    -1.000000E+21     7.239536E-05     1.000000E+21
#           5  traj.phases.propelled_ascent.indep_states.states:r_3          c    -1.000000E+21     1.259707E-04     1.000000E+21
#           6  traj.phases.propelled_ascent.indep_states.states:r_4          c    -1.000000E+21     2.241258E-04     1.000000E+21
#           7  traj.phases.propelled_ascent.indep_states.states:r_5          c    -1.000000E+21     2.610666E-04     1.000000E+21
#           8  traj.phases.propelled_ascent.indep_states.states:r_6          c    -1.000000E+21     3.563266E-04     1.000000E+21
#           9  traj.phases.propelled_ascent.indep_states.states:r_7          c    -1.000000E+21     5.121997E-04     1.000000E+21
#          10  traj.phases.propelled_ascent.indep_states.states:r_8          c    -1.000000E+21     5.674472E-04     1.000000E+21
#          11  traj.phases.propelled_ascent.indep_states.states:r_9          c    -1.000000E+21     7.046869E-04     1.000000E+21
#          12  traj.phases.propelled_ascent.indep_states.states:r_10         c    -1.000000E+21     9.186044E-04     1.000000E+21
#          13  traj.phases.propelled_ascent.indep_states.states:r_11         c    -1.000000E+21     9.922487E-04     1.000000E+21
#          14  traj.phases.propelled_ascent.indep_states.states:r_12         c    -1.000000E+21     1.171658E-03     1.000000E+21
#          15  traj.phases.propelled_ascent.indep_states.states:r_13         c    -1.000000E+21     1.443854E-03     1.000000E+21
#          16  traj.phases.propelled_ascent.indep_states.states:r_14         c    -1.000000E+21     1.535965E-03     1.000000E+21
#          17  traj.phases.propelled_ascent.indep_states.states:r_15         c    -1.000000E+21     1.757697E-03     1.000000E+21
#          18  traj.phases.propelled_ascent.indep_states.states:r_16         c    -1.000000E+21     2.088375E-03     1.000000E+21
#          19  traj.phases.propelled_ascent.indep_states.states:r_17         c    -1.000000E+21     2.199014E-03     1.000000E+21
#          20  traj.phases.propelled_ascent.indep_states.states:r_18         c    -1.000000E+21     2.463213E-03     1.000000E+21
#          21  traj.phases.propelled_ascent.indep_states.states:r_19         c    -1.000000E+21     2.852571E-03     1.000000E+21
#          22  traj.phases.propelled_ascent.indep_states.states:r_20         c    -1.000000E+21     2.981804E-03     1.000000E+21
#          23  traj.phases.propelled_ascent.indep_states.states:r_21         c    -1.000000E+21     3.288618E-03     1.000000E+21
#          24  traj.phases.propelled_ascent.indep_states.states:r_22         c    -1.000000E+21     3.736866E-03     1.000000E+21
#          25  traj.phases.propelled_ascent.indep_states.states:r_23         c    -1.000000E+21     3.884760E-03     1.000000E+21
#          26  traj.phases.propelled_ascent.indep_states.states:r_24         c    -1.000000E+21     4.234350E-03     1.000000E+21
#          27  traj.phases.propelled_ascent.indep_states.states:r_25         c    -1.000000E+21     4.741721E-03     1.000000E+21
#          28  traj.phases.propelled_ascent.indep_states.states:r_26         c    -1.000000E+21     4.908352E-03     1.000000E+21
#          29  traj.phases.propelled_ascent.indep_states.states:r_27         c    -1.000000E+21     5.300896E-03     1.000000E+21
#          30  traj.phases.propelled_ascent.indep_states.states:r_28         c    -1.000000E+21     5.867647E-03     1.000000E+21
#          31  traj.phases.propelled_ascent.indep_states.states:r_29         c    -1.000000E+21     6.053100E-03     1.000000E+21
#          32  traj.phases.propelled_ascent.indep_states.states:r_30         c    -1.000000E+21     6.488797E-03     1.000000E+21
#          33  traj.phases.propelled_ascent.indep_states.states:r_31         c    -1.000000E+21     7.115218E-03     1.000000E+21
#          34  traj.phases.propelled_ascent.indep_states.states:r_32         c    -1.000000E+21     7.319588E-03     1.000000E+21
#          35  traj.phases.propelled_ascent.indep_states.states:r_33         c    -1.000000E+21     7.798662E-03     1.000000E+21
#          36  traj.phases.propelled_ascent.indep_states.states:r_34         c    -1.000000E+21     8.485075E-03     1.000000E+21
#          37  traj.phases.propelled_ascent.indep_states.states:r_35         c    -1.000000E+21     8.708468E-03     1.000000E+21
#          38  traj.phases.propelled_ascent.indep_states.states:r_36         c    -1.000000E+21     9.231169E-03     1.000000E+21
#          39  traj.phases.propelled_ascent.indep_states.states:r_37         c    -1.000000E+21     9.977935E-03     1.000000E+21
#          40  traj.phases.propelled_ascent.indep_states.states:r_38         c    -1.000000E+21     1.022047E-02     1.000000E+21
#          41  traj.phases.propelled_ascent.indep_states.states:r_39         c    -1.000000E+21     1.078707E-02     1.000000E+21
#          42  traj.phases.propelled_ascent.indep_states.states:r_40         c    -1.000000E+21     1.159459E-02     1.000000E+21
#          43  traj.phases.propelled_ascent.indep_states.states:r_41         c    -1.000000E+21     1.185640E-02     1.000000E+21
#          44  traj.phases.propelled_ascent.indep_states.states:r_42         c    -1.000000E+21     1.246721E-02     1.000000E+21
#          45  traj.phases.propelled_ascent.indep_states.states:r_43         c    -1.000000E+21     1.333593E-02     1.000000E+21
#          46  traj.phases.propelled_ascent.indep_states.states:r_44         c    -1.000000E+21     1.361715E-02     1.000000E+21
#          47  traj.phases.propelled_ascent.indep_states.states:r_45         c    -1.000000E+21     1.427251E-02     1.000000E+21
#          48  traj.phases.propelled_ascent.indep_states.states:r_46         c    -1.000000E+21     1.520290E-02     1.000000E+21
#          49  traj.phases.propelled_ascent.indep_states.states:r_47         c    -1.000000E+21     1.550370E-02     1.000000E+21
#          50  traj.phases.propelled_ascent.indep_states.states:r_48         c    -1.000000E+21     1.620398E-02     1.000000E+21
#          51  traj.phases.propelled_ascent.indep_states.states:r_49         c    -1.000000E+21     1.719659E-02     1.000000E+21
#          52  traj.phases.propelled_ascent.indep_states.states:r_50         c    -1.000000E+21     1.751713E-02     1.000000E+21
#          53  traj.phases.propelled_ascent.indep_states.states:r_51         c    -1.000000E+21     1.826274E-02     1.000000E+21
#          54  traj.phases.propelled_ascent.indep_states.states:r_52         c    -1.000000E+21     1.931813E-02     1.000000E+21
#          55  traj.phases.propelled_ascent.indep_states.states:r_53         c    -1.000000E+21     1.965861E-02     1.000000E+21
#          56  traj.phases.propelled_ascent.indep_states.states:r_54         c    -1.000000E+21     2.044999E-02     1.000000E+21
#          57  traj.phases.propelled_ascent.indep_states.states:r_55         c    -1.000000E+21     2.156880E-02     1.000000E+21
#          58  traj.phases.propelled_ascent.indep_states.states:r_56         c    -1.000000E+21     2.192942E-02     1.000000E+21
#          59  traj.phases.propelled_ascent.indep_states.states:r_57         c    -1.000000E+21     2.276705E-02     1.000000E+21
#          60  traj.phases.propelled_ascent.indep_states.states:r_58         c    -1.000000E+21     2.394997E-02     1.000000E+21
#          61  traj.phases.propelled_ascent.indep_states.states:r_59         c    -1.000000E+21     2.433095E-02     1.000000E+21
#          62  traj.phases.propelled_ascent.indep_states.states:r_60         c    -1.000000E+21     2.521535E-02     1.000000E+21
#          63  traj.phases.propelled_ascent.indep_states.states:r_61         c    -1.000000E+21     2.646312E-02     1.000000E+21
#          64  traj.phases.propelled_ascent.indep_states.states:r_62         c    -1.000000E+21     2.686471E-02     1.000000E+21
#          65  traj.phases.propelled_ascent.indep_states.states:r_63         c    -1.000000E+21     2.779643E-02     1.000000E+21
#          66  traj.phases.propelled_ascent.indep_states.states:r_64         c    -1.000000E+21     2.910987E-02     1.000000E+21
#          67  traj.phases.propelled_ascent.indep_states.states:r_65         c    -1.000000E+21     2.953232E-02     1.000000E+21
#          68  traj.phases.propelled_ascent.indep_states.states:r_66         c    -1.000000E+21     3.051198E-02     1.000000E+21
#          69  traj.phases.propelled_ascent.indep_states.states:r_67         c    -1.000000E+21     3.189194E-02     1.000000E+21
#          70  traj.phases.propelled_ascent.indep_states.states:r_68         c    -1.000000E+21     3.233554E-02     1.000000E+21
#          71  traj.phases.propelled_ascent.indep_states.states:r_69         c    -1.000000E+21     3.336380E-02     1.000000E+21
#          72  traj.phases.propelled_ascent.indep_states.states:r_70         c    -1.000000E+21     3.481121E-02     1.000000E+21
#          73  traj.phases.propelled_ascent.indep_states.states:r_71         c    -1.000000E+21     3.527626E-02     1.000000E+21
#          74  traj.phases.propelled_ascent.indep_states.states:r_72         c    -1.000000E+21     3.635383E-02     1.000000E+21
#          75  traj.phases.propelled_ascent.indep_states.states:r_73         c    -1.000000E+21     3.786972E-02     1.000000E+21
#          76  traj.phases.propelled_ascent.indep_states.states:r_74         c    -1.000000E+21     3.835654E-02     1.000000E+21
#          77  traj.phases.propelled_ascent.indep_states.states:r_75         c    -1.000000E+21     3.948418E-02     1.000000E+21
#          78  traj.phases.propelled_ascent.indep_states.states:r_76         c    -1.000000E+21     4.106962E-02     1.000000E+21
#          79  traj.phases.propelled_ascent.indep_states.states:r_77         c    -1.000000E+21     4.157858E-02     1.000000E+21
#          80  traj.phases.propelled_ascent.indep_states.states:r_78         c    -1.000000E+21     4.275712E-02     1.000000E+21
#          81  traj.phases.propelled_ascent.indep_states.states:r_79         c    -1.000000E+21     4.441329E-02     1.000000E+21
#          82  traj.phases.propelled_ascent.indep_states.states:r_80         c    -1.000000E+21     4.494476E-02     1.000000E+21
#          83  traj.phases.propelled_ascent.indep_states.states:r_81         c    -1.000000E+21     4.617508E-02     1.000000E+21
#          84  traj.phases.propelled_ascent.indep_states.states:r_82         c    -1.000000E+21     4.790324E-02     1.000000E+21
#          85  traj.phases.propelled_ascent.indep_states.states:r_83         c    -1.000000E+21     4.845764E-02     1.000000E+21
#          86  traj.phases.propelled_ascent.indep_states.states:r_84         c    -1.000000E+21     4.974069E-02     1.000000E+21
#          87  traj.phases.propelled_ascent.indep_states.states:r_85         c    -1.000000E+21     5.154222E-02     1.000000E+21
#          88  traj.phases.propelled_ascent.indep_states.states:r_86         c    -1.000000E+21     5.211997E-02     1.000000E+21
#          89  traj.phases.propelled_ascent.indep_states.states:r_87         c    -1.000000E+21     5.345680E-02     1.000000E+21
#          90  traj.phases.propelled_ascent.indep_states.states:r_88         c    -1.000000E+21     5.533315E-02     1.000000E+21
#          91  traj.phases.propelled_ascent.indep_states.states:r_89         c    -1.000000E+21     5.593475E-02     1.000000E+21
#          92  traj.phases.propelled_ascent.indep_states.states:r_90         c    -1.000000E+21     5.732646E-02     1.000000E+21
#          93  traj.phases.propelled_ascent.indep_states.states:r_91         c    -1.000000E+21     5.927923E-02     1.000000E+21
#          94  traj.phases.propelled_ascent.indep_states.states:r_92         c    -1.000000E+21     5.990518E-02     1.000000E+21
#          95  traj.phases.propelled_ascent.indep_states.states:r_93         c    -1.000000E+21     6.135298E-02     1.000000E+21
#          96  traj.phases.propelled_ascent.indep_states.states:r_94         c    -1.000000E+21     6.338389E-02     1.000000E+21
#          97  traj.phases.propelled_ascent.indep_states.states:r_95         c    -1.000000E+21     6.403475E-02     1.000000E+21
#          98  traj.phases.propelled_ascent.indep_states.states:r_96         c    -1.000000E+21     6.553994E-02     1.000000E+21
#          99  traj.phases.propelled_ascent.indep_states.states:r_97         c    -1.000000E+21     6.765083E-02     1.000000E+21
#         100  traj.phases.propelled_ascent.indep_states.states:r_98         c    -1.000000E+21     6.832721E-02     1.000000E+21
#         101  traj.phases.propelled_ascent.indep_states.states:r_99         c    -1.000000E+21     6.989119E-02     1.000000E+21
#         102  traj.phases.propelled_ascent.indep_states.states:r_100        c    -1.000000E+21     7.208408E-02     1.000000E+21
#         103  traj.phases.propelled_ascent.indep_states.states:r_101        c    -1.000000E+21     7.278663E-02     1.000000E+21
#         104  traj.phases.propelled_ascent.indep_states.states:r_102        c    -1.000000E+21     7.441094E-02     1.000000E+21
#         105  traj.phases.propelled_ascent.indep_states.states:r_103        c    -1.000000E+21     7.668801E-02     1.000000E+21
#         106  traj.phases.propelled_ascent.indep_states.states:r_104        c    -1.000000E+21     7.741744E-02     1.000000E+21
#         107  traj.phases.propelled_ascent.indep_states.states:r_105        c    -1.000000E+21     7.910374E-02     1.000000E+21
#         108  traj.phases.propelled_ascent.indep_states.states:r_106        c    -1.000000E+21     8.146737E-02     1.000000E+21
#         109  traj.phases.propelled_ascent.indep_states.states:r_107        c    -1.000000E+21     8.222445E-02     1.000000E+21
#         110  traj.phases.propelled_ascent.indep_states.states:r_108        c    -1.000000E+21     8.397454E-02     1.000000E+21
#         111  traj.phases.propelled_ascent.indep_states.states:r_109        c    -1.000000E+21     8.642732E-02     1.000000E+21
#         112  traj.phases.propelled_ascent.indep_states.states:r_110        c    -1.000000E+21     8.721289E-02     1.000000E+21
#         113  traj.phases.propelled_ascent.indep_states.states:r_111        c    -1.000000E+21     8.902875E-02     1.000000E+21
#         114  traj.phases.propelled_ascent.indep_states.states:r_112        c    -1.000000E+21     9.157350E-02     1.000000E+21
#         115  traj.phases.propelled_ascent.indep_states.states:r_113        c    -1.000000E+21     9.238849E-02     1.000000E+21
#         116  traj.phases.propelled_ascent.indep_states.states:r_114        c    -1.000000E+21     9.427229E-02     1.000000E+21
#         117  traj.phases.propelled_ascent.indep_states.states:r_115        c    -1.000000E+21     9.691212E-02     1.000000E+21
#         118  traj.phases.propelled_ascent.indep_states.states:r_116        c    -1.000000E+21     9.775753E-02     1.000000E+21
#         119  traj.phases.propelled_ascent.indep_states.states:r_117        c    -1.000000E+21     9.971163E-02     1.000000E+21
#         120  traj.phases.propelled_ascent.indep_states.states:r_118        c    -1.000000E+21     1.024500E-01     1.000000E+21
#         121  traj.phases.propelled_ascent.indep_states.states:r_119        c    -1.000000E+21     1.033269E-01     1.000000E+21
#         122  traj.phases.propelled_ascent.indep_states.states:r_120        c    -1.000000E+21     1.053539E-01     1.000000E+21
#         123  traj.phases.propelled_ascent.indep_states.states:r_121        c    -1.000000E+21     1.081945E-01     1.000000E+21
#         124  traj.phases.propelled_ascent.indep_states.states:r_122        c    -1.000000E+21     1.091042E-01     1.000000E+21
#         125  traj.phases.propelled_ascent.indep_states.states:r_123        c    -1.000000E+21     1.112071E-01     1.000000E+21
#         126  traj.phases.propelled_ascent.indep_states.states:r_124        c    -1.000000E+21     1.141541E-01     1.000000E+21
#         127  traj.phases.propelled_ascent.indep_states.states:r_125        c    -1.000000E+21     1.150980E-01     1.000000E+21
#         128  traj.phases.propelled_ascent.indep_states.states:r_126        c    -1.000000E+21     1.172798E-01     1.000000E+21
#         129  traj.phases.propelled_ascent.indep_states.states:r_127        c    -1.000000E+21     1.203379E-01     1.000000E+21
#         130  traj.phases.propelled_ascent.indep_states.states:r_128        c    -1.000000E+21     1.213174E-01     1.000000E+21
#         131  traj.phases.propelled_ascent.indep_states.states:r_129        c    -1.000000E+21     1.235819E-01     1.000000E+21
#         132  traj.phases.propelled_ascent.indep_states.states:r_130        c    -1.000000E+21     1.267563E-01     1.000000E+21
#         133  traj.phases.propelled_ascent.indep_states.states:r_131        c    -1.000000E+21     1.277732E-01     1.000000E+21
#         134  traj.phases.propelled_ascent.indep_states.states:r_132        c    -1.000000E+21     1.301243E-01     1.000000E+21
#         135  traj.phases.propelled_ascent.indep_states.states:r_133        c    -1.000000E+21     1.334208E-01     1.000000E+21
#         136  traj.phases.propelled_ascent.indep_states.states:r_134        c    -1.000000E+21     1.344770E-01     1.000000E+21
#         137  traj.phases.propelled_ascent.indep_states.states:r_135        c    -1.000000E+21     1.369194E-01     1.000000E+21
#         138  traj.phases.propelled_ascent.indep_states.states:r_136        c    -1.000000E+21     1.403446E-01     1.000000E+21
#         139  traj.phases.propelled_ascent.indep_states.states:r_137        c    -1.000000E+21     1.414423E-01     1.000000E+21
#         140  traj.phases.propelled_ascent.indep_states.states:r_138        c    -1.000000E+21     1.439810E-01     1.000000E+21
#         141  traj.phases.propelled_ascent.indep_states.states:r_139        c    -1.000000E+21     1.475426E-01     1.000000E+21
#         142  traj.phases.propelled_ascent.indep_states.states:r_140        c    -1.000000E+21     1.486843E-01     1.000000E+21
#         143  traj.phases.propelled_ascent.indep_states.states:r_141        c    -1.000000E+21     1.513254E-01     1.000000E+21
#         144  traj.phases.propelled_ascent.indep_states.states:r_142        c    -1.000000E+21     1.550321E-01     1.000000E+21
#         145  traj.phases.propelled_ascent.indep_states.states:r_143        c    -1.000000E+21     1.562207E-01     1.000000E+21
#         146  traj.phases.propelled_ascent.indep_states.states:r_144        c    -1.000000E+21     1.589710E-01     1.000000E+21
#         147  traj.phases.propelled_ascent.indep_states.states:r_145        c    -1.000000E+21     1.628329E-01     1.000000E+21
#         148  traj.phases.propelled_ascent.indep_states.states:r_146        c    -1.000000E+21     1.640718E-01     1.000000E+21
#         149  traj.phases.propelled_ascent.indep_states.states:r_147        c    -1.000000E+21     1.669394E-01     1.000000E+21
#         150  traj.phases.propelled_ascent.indep_states.states:r_148        c    -1.000000E+21     1.709686E-01     1.000000E+21
#         151  traj.phases.propelled_ascent.indep_states.states:r_149        c    -1.000000E+21     1.722617E-01     1.000000E+21
#         152  traj.phases.propelled_ascent.indep_states.states:h_0          c    -1.000000E+21     1.401620E-04     1.000000E+21
#         153  traj.phases.propelled_ascent.indep_states.states:h_1          c    -1.000000E+21     5.893136E-04     1.000000E+21
#         154  traj.phases.propelled_ascent.indep_states.states:h_2          c    -1.000000E+21     7.931347E-04     1.000000E+21
#         155  traj.phases.propelled_ascent.indep_states.states:h_3          c    -1.000000E+21     1.371336E-03     1.000000E+21
#         156  traj.phases.propelled_ascent.indep_states.states:h_4          c    -1.000000E+21     2.423512E-03     1.000000E+21
#         157  traj.phases.propelled_ascent.indep_states.states:h_5          c    -1.000000E+21     2.817876E-03     1.000000E+21
#         158  traj.phases.propelled_ascent.indep_states.states:h_6          c    -1.000000E+21     3.831894E-03     1.000000E+21
#         159  traj.phases.propelled_ascent.indep_states.states:h_7          c    -1.000000E+21     5.484309E-03     1.000000E+21
#         160  traj.phases.propelled_ascent.indep_states.states:h_8          c    -1.000000E+21     6.068402E-03     1.000000E+21
#         161  traj.phases.propelled_ascent.indep_states.states:h_9          c    -1.000000E+21     7.516474E-03     1.000000E+21
#         162  traj.phases.propelled_ascent.indep_states.states:h_10         c    -1.000000E+21     9.766946E-03     1.000000E+21
#         163  traj.phases.propelled_ascent.indep_states.states:h_11         c    -1.000000E+21     1.054014E-02     1.000000E+21
#         164  traj.phases.propelled_ascent.indep_states.states:h_12         c    -1.000000E+21     1.242092E-02     1.000000E+21
#         165  traj.phases.propelled_ascent.indep_states.states:h_13         c    -1.000000E+21     1.526782E-02     1.000000E+21
#         166  traj.phases.propelled_ascent.indep_states.states:h_14         c    -1.000000E+21     1.622965E-02     1.000000E+21
#         167  traj.phases.propelled_ascent.indep_states.states:h_15         c    -1.000000E+21     1.854218E-02     1.000000E+21
#         168  traj.phases.propelled_ascent.indep_states.states:h_16         c    -1.000000E+21     2.198443E-02     1.000000E+21
#         169  traj.phases.propelled_ascent.indep_states.states:h_17         c    -1.000000E+21     2.313461E-02     1.000000E+21
#         170  traj.phases.propelled_ascent.indep_states.states:h_18         c    -1.000000E+21     2.587833E-02     1.000000E+21
#         171  traj.phases.propelled_ascent.indep_states.states:h_19         c    -1.000000E+21     2.991535E-02     1.000000E+21
#         172  traj.phases.propelled_ascent.indep_states.states:h_20         c    -1.000000E+21     3.125375E-02     1.000000E+21
#         173  traj.phases.propelled_ascent.indep_states.states:h_21         c    -1.000000E+21     3.442846E-02     1.000000E+21
#         174  traj.phases.propelled_ascent.indep_states.states:h_22         c    -1.000000E+21     3.906019E-02     1.000000E+21
#         175  traj.phases.propelled_ascent.indep_states.states:h_23         c    -1.000000E+21     4.058684E-02     1.000000E+21
#         176  traj.phases.propelled_ascent.indep_states.states:h_24         c    -1.000000E+21     4.419270E-02     1.000000E+21
#         177  traj.phases.propelled_ascent.indep_states.states:h_25         c    -1.000000E+21     4.941957E-02     1.000000E+21
#         178  traj.phases.propelled_ascent.indep_states.states:h_26         c    -1.000000E+21     5.113466E-02     1.000000E+21
#         179  traj.phases.propelled_ascent.indep_states.states:h_27         c    -1.000000E+21     5.517218E-02     1.000000E+21
#         180  traj.phases.propelled_ascent.indep_states.states:h_28         c    -1.000000E+21     6.099513E-02     1.000000E+21
#         181  traj.phases.propelled_ascent.indep_states.states:h_29         c    -1.000000E+21     6.289898E-02     1.000000E+21
#         182  traj.phases.propelled_ascent.indep_states.states:h_30         c    -1.000000E+21     6.736905E-02     1.000000E+21
#         183  traj.phases.propelled_ascent.indep_states.states:h_31         c    -1.000000E+21     7.378947E-02     1.000000E+21
#         184  traj.phases.propelled_ascent.indep_states.states:h_32         c    -1.000000E+21     7.588260E-02     1.000000E+21
#         185  traj.phases.propelled_ascent.indep_states.states:h_33         c    -1.000000E+21     8.078644E-02     1.000000E+21
#         186  traj.phases.propelled_ascent.indep_states.states:h_34         c    -1.000000E+21     8.780622E-02     1.000000E+21
#         187  traj.phases.propelled_ascent.indep_states.states:h_35         c    -1.000000E+21     9.008927E-02     1.000000E+21
#         188  traj.phases.propelled_ascent.indep_states.states:h_36         c    -1.000000E+21     9.542845E-02     1.000000E+21
#         189  traj.phases.propelled_ascent.indep_states.states:h_37         c    -1.000000E+21     1.030500E-01     1.000000E+21
#         190  traj.phases.propelled_ascent.indep_states.states:h_38         c    -1.000000E+21     1.055238E-01     1.000000E+21
#         191  traj.phases.propelled_ascent.indep_states.states:h_39         c    -1.000000E+21     1.113002E-01     1.000000E+21
#         192  traj.phases.propelled_ascent.indep_states.states:h_40         c    -1.000000E+21     1.195264E-01     1.000000E+21
#         193  traj.phases.propelled_ascent.indep_states.states:h_41         c    -1.000000E+21     1.221918E-01     1.000000E+21
#         194  traj.phases.propelled_ascent.indep_states.states:h_42         c    -1.000000E+21     1.284079E-01     1.000000E+21
#         195  traj.phases.propelled_ascent.indep_states.states:h_43         c    -1.000000E+21     1.372420E-01     1.000000E+21
#         196  traj.phases.propelled_ascent.indep_states.states:h_44         c    -1.000000E+21     1.401003E-01     1.000000E+21
#         197  traj.phases.propelled_ascent.indep_states.states:h_45         c    -1.000000E+21     1.467585E-01     1.000000E+21
#         198  traj.phases.propelled_ascent.indep_states.states:h_46         c    -1.000000E+21     1.562046E-01     1.000000E+21
#         199  traj.phases.propelled_ascent.indep_states.states:h_47         c    -1.000000E+21     1.592570E-01     1.000000E+21
#         200  traj.phases.propelled_ascent.indep_states.states:h_48         c    -1.000000E+21     1.663605E-01     1.000000E+21
#         201  traj.phases.propelled_ascent.indep_states.states:h_49         c    -1.000000E+21     1.764228E-01     1.000000E+21
#         202  traj.phases.propelled_ascent.indep_states.states:h_50         c    -1.000000E+21     1.796707E-01     1.000000E+21
#         203  traj.phases.propelled_ascent.indep_states.states:h_51         c    -1.000000E+21     1.872229E-01     1.000000E+21
#         204  traj.phases.propelled_ascent.indep_states.states:h_52         c    -1.000000E+21     1.979065E-01     1.000000E+21
#         205  traj.phases.propelled_ascent.indep_states.states:h_53         c    -1.000000E+21     2.013516E-01     1.000000E+21
#         206  traj.phases.propelled_ascent.indep_states.states:h_54         c    -1.000000E+21     2.093562E-01     1.000000E+21
#         207  traj.phases.propelled_ascent.indep_states.states:h_55         c    -1.000000E+21     2.206666E-01     1.000000E+21
#         208  traj.phases.propelled_ascent.indep_states.states:h_56         c    -1.000000E+21     2.243106E-01     1.000000E+21
#         209  traj.phases.propelled_ascent.indep_states.states:h_57         c    -1.000000E+21     2.327720E-01     1.000000E+21
#         210  traj.phases.propelled_ascent.indep_states.states:h_58         c    -1.000000E+21     2.447152E-01     1.000000E+21
#         211  traj.phases.propelled_ascent.indep_states.states:h_59         c    -1.000000E+21     2.485602E-01     1.000000E+21
#         212  traj.phases.propelled_ascent.indep_states.states:h_60         c    -1.000000E+21     2.574830E-01     1.000000E+21
#         213  traj.phases.propelled_ascent.indep_states.states:h_61         c    -1.000000E+21     2.700657E-01     1.000000E+21
#         214  traj.phases.propelled_ascent.indep_states.states:h_62         c    -1.000000E+21     2.741138E-01     1.000000E+21
#         215  traj.phases.propelled_ascent.indep_states.states:h_63         c    -1.000000E+21     2.835031E-01     1.000000E+21
#         216  traj.phases.propelled_ascent.indep_states.states:h_64         c    -1.000000E+21     2.967327E-01     1.000000E+21
#         217  traj.phases.propelled_ascent.indep_states.states:h_65         c    -1.000000E+21     3.009863E-01     1.000000E+21
#         218  traj.phases.propelled_ascent.indep_states.states:h_66         c    -1.000000E+21     3.108477E-01     1.000000E+21
#         219  traj.phases.propelled_ascent.indep_states.states:h_67         c    -1.000000E+21     3.247321E-01     1.000000E+21
#         220  traj.phases.propelled_ascent.indep_states.states:h_68         c    -1.000000E+21     3.291939E-01     1.000000E+21
#         221  traj.phases.propelled_ascent.indep_states.states:h_69         c    -1.000000E+21     3.395334E-01     1.000000E+21
#         222  traj.phases.propelled_ascent.indep_states.states:h_70         c    -1.000000E+21     3.540814E-01     1.000000E+21
#         223  traj.phases.propelled_ascent.indep_states.states:h_71         c    -1.000000E+21     3.587541E-01     1.000000E+21
#         224  traj.phases.propelled_ascent.indep_states.states:h_72         c    -1.000000E+21     3.695784E-01     1.000000E+21
#         225  traj.phases.propelled_ascent.indep_states.states:h_73         c    -1.000000E+21     3.847994E-01     1.000000E+21
#         226  traj.phases.propelled_ascent.indep_states.states:h_74         c    -1.000000E+21     3.896861E-01     1.000000E+21
#         227  traj.phases.propelled_ascent.indep_states.states:h_75         c    -1.000000E+21     4.010025E-01     1.000000E+21
#         228  traj.phases.propelled_ascent.indep_states.states:h_76         c    -1.000000E+21     4.169067E-01     1.000000E+21
#         229  traj.phases.propelled_ascent.indep_states.states:h_77         c    -1.000000E+21     4.220108E-01     1.000000E+21
#         230  traj.phases.propelled_ascent.indep_states.states:h_78         c    -1.000000E+21     4.338269E-01     1.000000E+21
#         231  traj.phases.propelled_ascent.indep_states.states:h_79         c    -1.000000E+21     4.504255E-01     1.000000E+21
#         232  traj.phases.propelled_ascent.indep_states.states:h_80         c    -1.000000E+21     4.557505E-01     1.000000E+21
#         233  traj.phases.propelled_ascent.indep_states.states:h_81         c    -1.000000E+21     4.680748E-01     1.000000E+21
#         234  traj.phases.propelled_ascent.indep_states.states:h_82         c    -1.000000E+21     4.853798E-01     1.000000E+21
#         235  traj.phases.propelled_ascent.indep_states.states:h_83         c    -1.000000E+21     4.909297E-01     1.000000E+21
#         236  traj.phases.propelled_ascent.indep_states.states:h_84         c    -1.000000E+21     5.037713E-01     1.000000E+21
#         237  traj.phases.propelled_ascent.indep_states.states:h_85         c    -1.000000E+21     5.217958E-01     1.000000E+21
#         238  traj.phases.propelled_ascent.indep_states.states:h_86         c    -1.000000E+21     5.275747E-01     1.000000E+21
#         239  traj.phases.propelled_ascent.indep_states.states:h_87         c    -1.000000E+21     5.409435E-01     1.000000E+21
#         240  traj.phases.propelled_ascent.indep_states.states:h_88         c    -1.000000E+21     5.597015E-01     1.000000E+21
#         241  traj.phases.propelled_ascent.indep_states.states:h_89         c    -1.000000E+21     5.657142E-01     1.000000E+21
#         242  traj.phases.propelled_ascent.indep_states.states:h_90         c    -1.000000E+21     5.796209E-01     1.000000E+21
#         243  traj.phases.propelled_ascent.indep_states.states:h_91         c    -1.000000E+21     5.991277E-01     1.000000E+21
#         244  traj.phases.propelled_ascent.indep_states.states:h_92         c    -1.000000E+21     6.053790E-01     1.000000E+21
#         245  traj.phases.propelled_ascent.indep_states.states:h_93         c    -1.000000E+21     6.198352E-01     1.000000E+21
#         246  traj.phases.propelled_ascent.indep_states.states:h_94         c    -1.000000E+21     6.401073E-01     1.000000E+21
#         247  traj.phases.propelled_ascent.indep_states.states:h_95         c    -1.000000E+21     6.466026E-01     1.000000E+21
#         248  traj.phases.propelled_ascent.indep_states.states:h_96         c    -1.000000E+21     6.616209E-01     1.000000E+21
#         249  traj.phases.propelled_ascent.indep_states.states:h_97         c    -1.000000E+21     6.826763E-01     1.000000E+21
#         250  traj.phases.propelled_ascent.indep_states.states:h_98         c    -1.000000E+21     6.894215E-01     1.000000E+21
#         251  traj.phases.propelled_ascent.indep_states.states:h_99         c    -1.000000E+21     7.050155E-01     1.000000E+21
#         252  traj.phases.propelled_ascent.indep_states.states:h_100        c    -1.000000E+21     7.268737E-01     1.000000E+21
#         253  traj.phases.propelled_ascent.indep_states.states:h_101        c    -1.000000E+21     7.338750E-01     1.000000E+21
#         254  traj.phases.propelled_ascent.indep_states.states:h_102        c    -1.000000E+21     7.500595E-01     1.000000E+21
#         255  traj.phases.propelled_ascent.indep_states.states:h_103        c    -1.000000E+21     7.727418E-01     1.000000E+21
#         256  traj.phases.propelled_ascent.indep_states.states:h_104        c    -1.000000E+21     7.800062E-01     1.000000E+21
#         257  traj.phases.propelled_ascent.indep_states.states:h_105        c    -1.000000E+21     7.967974E-01     1.000000E+21
#         258  traj.phases.propelled_ascent.indep_states.states:h_106        c    -1.000000E+21     8.203267E-01     1.000000E+21
#         259  traj.phases.propelled_ascent.indep_states.states:h_107        c    -1.000000E+21     8.278617E-01     1.000000E+21
#         260  traj.phases.propelled_ascent.indep_states.states:h_108        c    -1.000000E+21     8.452772E-01     1.000000E+21
#         261  traj.phases.propelled_ascent.indep_states.states:h_109        c    -1.000000E+21     8.696789E-01     1.000000E+21
#         262  traj.phases.propelled_ascent.indep_states.states:h_110        c    -1.000000E+21     8.774927E-01     1.000000E+21
#         263  traj.phases.propelled_ascent.indep_states.states:h_111        c    -1.000000E+21     8.955517E-01     1.000000E+21
#         264  traj.phases.propelled_ascent.indep_states.states:h_112        c    -1.000000E+21     9.208533E-01     1.000000E+21
#         265  traj.phases.propelled_ascent.indep_states.states:h_113        c    -1.000000E+21     9.289550E-01     1.000000E+21
#         266  traj.phases.propelled_ascent.indep_states.states:h_114        c    -1.000000E+21     9.476786E-01     1.000000E+21
#         267  traj.phases.propelled_ascent.indep_states.states:h_115        c    -1.000000E+21     9.739104E-01     1.000000E+21
#         268  traj.phases.propelled_ascent.indep_states.states:h_116        c    -1.000000E+21     9.823098E-01     1.000000E+21
#         269  traj.phases.propelled_ascent.indep_states.states:h_117        c    -1.000000E+21     1.001721E+00     1.000000E+21
#         270  traj.phases.propelled_ascent.indep_states.states:h_118        c    -1.000000E+21     1.028917E+00     1.000000E+21
#         271  traj.phases.propelled_ascent.indep_states.states:h_119        c    -1.000000E+21     1.037625E+00     1.000000E+21
#         272  traj.phases.propelled_ascent.indep_states.states:h_120        c    -1.000000E+21     1.057749E+00     1.000000E+21
#         273  traj.phases.propelled_ascent.indep_states.states:h_121        c    -1.000000E+21     1.085945E+00     1.000000E+21
#         274  traj.phases.propelled_ascent.indep_states.states:h_122        c    -1.000000E+21     1.094974E+00     1.000000E+21
#         275  traj.phases.propelled_ascent.indep_states.states:h_123        c    -1.000000E+21     1.115841E+00     1.000000E+21
#         276  traj.phases.propelled_ascent.indep_states.states:h_124        c    -1.000000E+21     1.145078E+00     1.000000E+21
#         277  traj.phases.propelled_ascent.indep_states.states:h_125        c    -1.000000E+21     1.154440E+00     1.000000E+21
#         278  traj.phases.propelled_ascent.indep_states.states:h_126        c    -1.000000E+21     1.176080E+00     1.000000E+21
#         279  traj.phases.propelled_ascent.indep_states.states:h_127        c    -1.000000E+21     1.206404E+00     1.000000E+21
#         280  traj.phases.propelled_ascent.indep_states.states:h_128        c    -1.000000E+21     1.216116E+00     1.000000E+21
#         281  traj.phases.propelled_ascent.indep_states.states:h_129        c    -1.000000E+21     1.238564E+00     1.000000E+21
#         282  traj.phases.propelled_ascent.indep_states.states:h_130        c    -1.000000E+21     1.270026E+00     1.000000E+21
#         283  traj.phases.propelled_ascent.indep_states.states:h_131        c    -1.000000E+21     1.280104E+00     1.000000E+21
#         284  traj.phases.propelled_ascent.indep_states.states:h_132        c    -1.000000E+21     1.303400E+00     1.000000E+21
#         285  traj.phases.propelled_ascent.indep_states.states:h_133        c    -1.000000E+21     1.336057E+00     1.000000E+21
#         286  traj.phases.propelled_ascent.indep_states.states:h_134        c    -1.000000E+21     1.346519E+00     1.000000E+21
#         287  traj.phases.propelled_ascent.indep_states.states:h_135        c    -1.000000E+21     1.370709E+00     1.000000E+21
#         288  traj.phases.propelled_ascent.indep_states.states:h_136        c    -1.000000E+21     1.404626E+00     1.000000E+21
#         289  traj.phases.propelled_ascent.indep_states.states:h_137        c    -1.000000E+21     1.415494E+00     1.000000E+21
#         290  traj.phases.propelled_ascent.indep_states.states:h_138        c    -1.000000E+21     1.440627E+00     1.000000E+21
#         291  traj.phases.propelled_ascent.indep_states.states:h_139        c    -1.000000E+21     1.475880E+00     1.000000E+21
#         292  traj.phases.propelled_ascent.indep_states.states:h_140        c    -1.000000E+21     1.487179E+00     1.000000E+21
#         293  traj.phases.propelled_ascent.indep_states.states:h_141        c    -1.000000E+21     1.513314E+00     1.000000E+21
#         294  traj.phases.propelled_ascent.indep_states.states:h_142        c    -1.000000E+21     1.549988E+00     1.000000E+21
#         295  traj.phases.propelled_ascent.indep_states.states:h_143        c    -1.000000E+21     1.561746E+00     1.000000E+21
#         296  traj.phases.propelled_ascent.indep_states.states:h_144        c    -1.000000E+21     1.588952E+00     1.000000E+21
#         297  traj.phases.propelled_ascent.indep_states.states:h_145        c    -1.000000E+21     1.627146E+00     1.000000E+21
#         298  traj.phases.propelled_ascent.indep_states.states:h_146        c    -1.000000E+21     1.639397E+00     1.000000E+21
#         299  traj.phases.propelled_ascent.indep_states.states:h_147        c    -1.000000E+21     1.667752E+00     1.000000E+21
#         300  traj.phases.propelled_ascent.indep_states.states:h_148        c    -1.000000E+21     1.707585E+00     1.000000E+21
#         301  traj.phases.propelled_ascent.indep_states.states:h_149        c    -1.000000E+21     1.720368E+00     1.000000E+21
#         302  traj.phases.propelled_ascent.indep_states.states:gam_0        c     0.000000E+00     9.444444E-01     9.444444E-01          u
#         303  traj.phases.propelled_ascent.indep_states.states:gam_1        c     0.000000E+00     9.423886E-01     9.444444E-01
#         304  traj.phases.propelled_ascent.indep_states.states:gam_2        c     0.000000E+00     9.417189E-01     9.444444E-01
#         305  traj.phases.propelled_ascent.indep_states.states:gam_3        c     0.000000E+00     9.413934E-01     9.444444E-01
#         306  traj.phases.propelled_ascent.indep_states.states:gam_4        c     0.000000E+00     9.410036E-01     9.444444E-01
#         307  traj.phases.propelled_ascent.indep_states.states:gam_5        c     0.000000E+00     9.405971E-01     9.444444E-01
#         308  traj.phases.propelled_ascent.indep_states.states:gam_6        c     0.000000E+00     9.404867E-01     9.444444E-01
#         309  traj.phases.propelled_ascent.indep_states.states:gam_7        c     0.000000E+00     9.402630E-01     9.444444E-01
#         310  traj.phases.propelled_ascent.indep_states.states:gam_8        c     0.000000E+00     9.400010E-01     9.444444E-01
#         311  traj.phases.propelled_ascent.indep_states.states:gam_9        c     0.000000E+00     9.399264E-01     9.444444E-01
#         312  traj.phases.propelled_ascent.indep_states.states:gam_10       c     0.000000E+00     9.397686E-01     9.444444E-01
#         313  traj.phases.propelled_ascent.indep_states.states:gam_11       c     0.000000E+00     9.395748E-01     9.444444E-01
#         314  traj.phases.propelled_ascent.indep_states.states:gam_12       c     0.000000E+00     9.395182E-01     9.444444E-01
#         315  traj.phases.propelled_ascent.indep_states.states:gam_13       c     0.000000E+00     9.393960E-01     9.444444E-01
#         316  traj.phases.propelled_ascent.indep_states.states:gam_14       c     0.000000E+00     9.392420E-01     9.444444E-01
#         317  traj.phases.propelled_ascent.indep_states.states:gam_15       c     0.000000E+00     9.391962E-01     9.444444E-01
#         318  traj.phases.propelled_ascent.indep_states.states:gam_16       c     0.000000E+00     9.390964E-01     9.444444E-01
#         319  traj.phases.propelled_ascent.indep_states.states:gam_17       c     0.000000E+00     9.389684E-01     9.444444E-01
#         320  traj.phases.propelled_ascent.indep_states.states:gam_18       c     0.000000E+00     9.389300E-01     9.444444E-01
#         321  traj.phases.propelled_ascent.indep_states.states:gam_19       c     0.000000E+00     9.388455E-01     9.444444E-01
#         322  traj.phases.propelled_ascent.indep_states.states:gam_20       c     0.000000E+00     9.387359E-01     9.444444E-01
#         323  traj.phases.propelled_ascent.indep_states.states:gam_21       c     0.000000E+00     9.387028E-01     9.444444E-01
#         324  traj.phases.propelled_ascent.indep_states.states:gam_22       c     0.000000E+00     9.386295E-01     9.444444E-01
#         325  traj.phases.propelled_ascent.indep_states.states:gam_23       c     0.000000E+00     9.385338E-01     9.444444E-01
#         326  traj.phases.propelled_ascent.indep_states.states:gam_24       c     0.000000E+00     9.385046E-01     9.444444E-01
#         327  traj.phases.propelled_ascent.indep_states.states:gam_25       c     0.000000E+00     9.384399E-01     9.444444E-01
#         328  traj.phases.propelled_ascent.indep_states.states:gam_26       c     0.000000E+00     9.383548E-01     9.444444E-01
#         329  traj.phases.propelled_ascent.indep_states.states:gam_27       c     0.000000E+00     9.383288E-01     9.444444E-01
#         330  traj.phases.propelled_ascent.indep_states.states:gam_28       c     0.000000E+00     9.382708E-01     9.444444E-01
# ...
#        1126  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    6.127289E-15    0.000000E+00              9.00000E+100
#        1127  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    1.656024E-16    0.000000E+00              9.00000E+100
#        1128  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00   -1.341379E-14    0.000000E+00              9.00000E+100
#        1129  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    4.140060E-15    0.000000E+00              9.00000E+100
#        1130  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00   -5.133674E-15    0.000000E+00              9.00000E+100
#        1131  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    7.948915E-15    0.000000E+00              9.00000E+100
#        1132  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00   -4.968072E-16    0.000000E+00              9.00000E+100
#        1133  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00   -2.401235E-15    0.000000E+00              9.00000E+100
#        1134  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    7.948915E-15    0.000000E+00              9.00000E+100
#        1135  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00   -6.789698E-15    0.000000E+00              9.00000E+100
#        1136  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    1.010175E-14    0.000000E+00              9.00000E+100
#        1137  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00   -1.573223E-15    0.000000E+00              9.00000E+100
#        1138  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00   -9.522138E-15    0.000000E+00              9.00000E+100
#        1139  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    6.955301E-15    0.000000E+00              9.00000E+100
#        1140  traj.linkages.propelled_ascent:time_final|ballistic_ascent:time_initial    e   0.000000E+00    0.000000E+00    0.000000E+00              9.00000E+100
#        1141  traj.linkages.propelled_ascent:r_final|ballistic_ascent:r_initial          e   0.000000E+00    0.000000E+00    0.000000E+00              9.00000E+100
#        1142  traj.linkages.propelled_ascent:h_final|ballistic_ascent:h_initial          e   0.000000E+00    0.000000E+00    0.000000E+00              9.00000E+100
#        1143  traj.linkages.propelled_ascent:gam_final|ballistic_ascent:gam_initial      e   0.000000E+00   -1.421085E-14    0.000000E+00              9.00000E+100
#        1144  traj.linkages.propelled_ascent:v_final|ballistic_ascent:v_initial          e   0.000000E+00    0.000000E+00    0.000000E+00              9.00000E+100
#        1145  traj.linkages.ballistic_ascent:time_final|descent:time_initial             e   0.000000E+00    4.440892E-16    0.000000E+00              9.00000E+100
#        1146  traj.linkages.ballistic_ascent:r_final|descent:r_initial                   e   0.000000E+00    0.000000E+00    0.000000E+00              9.00000E+100
#        1147  traj.linkages.ballistic_ascent:h_final|descent:h_initial                   e   0.000000E+00    0.000000E+00    0.000000E+00              9.00000E+100
#        1148  traj.linkages.ballistic_ascent:gam_final|descent:gam_initial               e   0.000000E+00    1.286343E-30    0.000000E+00              9.00000E+100
#        1149  traj.linkages.ballistic_ascent:v_final|descent:v_initial                   e   0.000000E+00    0.000000E+00    0.000000E+00              9.00000E+100
#
# --------------------------------------------------------------------------------
# Launch angle: 85.0000 deg
# Flight angle at end of propulsion: 84.2233 deg
# Empty mass: 0.1425 kg
# Water volume: 0.8683 L
# Maximum range: 15.7768 m
# Maximum height: 54.1332 m
# Maximum velocity: 47.3203 m/s
#
# Simulating trajectory traj
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# Done simulating trajectory traj

# %%
from openmdao.utils.assert_utils import assert_near_equal

# Check results (tolerance is relative unless value is zero)
assert_near_equal(summary['Launch angle'].value, 85, .02)
assert_near_equal(summary['Flight angle at end of propulsion'].value, 85, .02)
assert_near_equal(summary['Empty mass'].value, 0.1425114, 1e-3)
assert_near_equal(summary['Water volume'].value, 0.868281, 1e-3)
assert_near_equal(summary['Maximum range'].value, 15.78, 5)
assert_near_equal(summary['Maximum height'].value, 54.133184, 1e-3)
assert_near_equal(summary['Maximum velocity'].value, 47.320298, 1e-3)
# Out:
# 1.8344084760194725e-08

# %% [markdown]
# # Optimizing for Range

# %%
p = om.Problem(model=om.Group())

traj, phases = new_water_rocket_trajectory(objective='range')
traj = p.model.add_subsystem('traj', traj)

p.driver = om.pyOptSparseDriver(optimizer='IPOPT')
p.driver.opt_settings['print_level'] = 4
p.driver.opt_settings['max_iter'] = 1000
p.driver.opt_settings['nlp_scaling_method'] = 'gradient-based'
p.driver.declare_coloring(tol=1.0E-12)

# Finish Problem Setup
p.model.linear_solver = om.DirectSolver()
# p.driver.add_recorder(om.SqliteRecorder('ex_water_rocket.db'))

p.setup()
set_sane_initial_guesses(p, phases)

p.run_driver()

summary = summarize_results(p)
for key, entry in summary.items():
    print(f'{key}: {entry.value:6.4f} {entry.unit}')

exp_out = traj.simulate(times_per_seg=200)

# NOTE: only the last figure is shown in the generated docs
plot_propelled_ascent(p, exp_out)
plot_trajectory(p, exp_out)
plot_states(p, exp_out)

plt.show()

# Check results (tolerance is relative unless value is zero)
# Out:
# --- Linkage Report [traj] ---
#     --- propelled_ascent - ballistic_ascent ---
#         time [final]  ==  time [initial]
#         r    [final]  ==  r    [initial]
#         h    [final]  ==  h    [initial]
#         gam  [final]  ==  gam  [initial]
#         v    [final]  ==  v    [initial]
# ----------------------------
#     --- ballistic_ascent - descent ---
#         time [final]  ==  time [initial]
#         r    [final]  ==  r    [initial]
#         h    [final]  ==  h    [initial]
#         gam  [final]  ==  gam  [initial]
#         v    [final]  ==  v    [initial]
# ----------------------------
# Full total jacobian was computed 3 times, taking 4.394888 seconds.
# Total jacobian shape: (1151, 1153)
#
#
# Jacobian shape: (1151, 1153)  ( 0.67% nonzero)
# FWD solves: 19   REV solves: 0
# Total colors vs. total size: 19 vs 1153  (98.4% improvement)
#
# Sparsity computed using tolerance: 1e-12
# Time to compute sparsity: 4.394888 sec.
# Time to compute coloring: 2.498703 sec.
# Memory to compute coloring: -28.042969 MB.
#
#
# Optimization Problem -- Optimization using pyOpt_sparse
# ================================================================================
#     Objective Function: _objfunc
#
#     Solution:
# --------------------------------------------------------------------------------
#     Total Time:                    6.1646
#        User Objective Time :       0.4075
#        User Sensitivity Time :     3.3248
#        Interface Time :            1.8452
#        Opt Solver Time:            0.5870
#     Calls to Objective Function :      53
#     Calls to Sens Function :           43
#
#
#    Objectives
#       Index  Name                                                 Value          Optimum
#           0  traj.phases.descent.indep_states.states:r    -8.511420E+03     0.000000E+00
#
#    Variables (c - continuous, i - integer, d - discrete)
#       Index  Name                                                       Type      Lower Bound            Value      Upper Bound     Status
#           0  traj.parameters:m_empty_0                                     c     0.000000E+00     1.891000E+00     1.000000E+01
#           1  traj.phases.propelled_ascent.time_extents.t_duration_0        c     1.000000E-02     1.125768E+00     5.000000E+00
#           2  traj.phases.propelled_ascent.indep_states.states:r_0          c    -1.000000E+21     1.330997E-04     1.000000E+21
#           3  traj.phases.propelled_ascent.indep_states.states:r_1          c    -1.000000E+21     5.716945E-04     1.000000E+21
#           4  traj.phases.propelled_ascent.indep_states.states:r_2          c    -1.000000E+21     7.720812E-04     1.000000E+21
#           5  traj.phases.propelled_ascent.indep_states.states:r_3          c    -1.000000E+21     1.344606E-03     1.000000E+21
#           6  traj.phases.propelled_ascent.indep_states.states:r_4          c    -1.000000E+21     2.391667E-03     1.000000E+21
#           7  traj.phases.propelled_ascent.indep_states.states:r_5          c    -1.000000E+21     2.785109E-03     1.000000E+21
#           8  traj.phases.propelled_ascent.indep_states.states:r_6          c    -1.000000E+21     3.798260E-03     1.000000E+21
#           9  traj.phases.propelled_ascent.indep_states.states:r_7          c    -1.000000E+21     5.452131E-03     1.000000E+21
#          10  traj.phases.propelled_ascent.indep_states.states:r_8          c    -1.000000E+21     6.037277E-03     1.000000E+21
#          11  traj.phases.propelled_ascent.indep_states.states:r_9          c    -1.000000E+21     7.488703E-03     1.000000E+21
#          12  traj.phases.propelled_ascent.indep_states.states:r_10         c    -1.000000E+21     9.745635E-03     1.000000E+21
#          13  traj.phases.propelled_ascent.indep_states.states:r_11         c    -1.000000E+21     1.052123E-02     1.000000E+21
#          14  traj.phases.propelled_ascent.indep_states.states:r_12         c    -1.000000E+21     1.240801E-02     1.000000E+21
#          15  traj.phases.propelled_ascent.indep_states.states:r_13         c    -1.000000E+21     1.526391E-02     1.000000E+21
#          16  traj.phases.propelled_ascent.indep_states.states:r_14         c    -1.000000E+21     1.622867E-02     1.000000E+21
#          17  traj.phases.propelled_ascent.indep_states.states:r_15         c    -1.000000E+21     1.854788E-02     1.000000E+21
#          18  traj.phases.propelled_ascent.indep_states.states:r_16         c    -1.000000E+21     2.199883E-02     1.000000E+21
#          19  traj.phases.propelled_ascent.indep_states.states:r_17         c    -1.000000E+21     2.315154E-02     1.000000E+21
#          20  traj.phases.propelled_ascent.indep_states.states:r_18         c    -1.000000E+21     2.590047E-02     1.000000E+21
#          21  traj.phases.propelled_ascent.indep_states.states:r_19         c    -1.000000E+21     2.994291E-02     1.000000E+21
#          22  traj.phases.propelled_ascent.indep_states.states:r_20         c    -1.000000E+21     3.128248E-02     1.000000E+21
#          23  traj.phases.propelled_ascent.indep_states.states:r_21         c    -1.000000E+21     3.445875E-02     1.000000E+21
#          24  traj.phases.propelled_ascent.indep_states.states:r_22         c    -1.000000E+21     3.908955E-02     1.000000E+21
#          25  traj.phases.propelled_ascent.indep_states.states:r_23         c    -1.000000E+21     4.061506E-02     1.000000E+21
#          26  traj.phases.propelled_ascent.indep_states.states:r_24         c    -1.000000E+21     4.421659E-02     1.000000E+21
#          27  traj.phases.propelled_ascent.indep_states.states:r_25         c    -1.000000E+21     4.943314E-02     1.000000E+21
#          28  traj.phases.propelled_ascent.indep_states.states:r_26         c    -1.000000E+21     5.114379E-02     1.000000E+21
#          29  traj.phases.propelled_ascent.indep_states.states:r_27         c    -1.000000E+21     5.516891E-02     1.000000E+21
#          30  traj.phases.propelled_ascent.indep_states.states:r_28         c    -1.000000E+21     6.096907E-02     1.000000E+21
#          31  traj.phases.propelled_ascent.indep_states.states:r_29         c    -1.000000E+21     6.286426E-02     1.000000E+21
#          32  traj.phases.propelled_ascent.indep_states.states:r_30         c    -1.000000E+21     6.731163E-02     1.000000E+21
#          33  traj.phases.propelled_ascent.indep_states.states:r_31         c    -1.000000E+21     7.369381E-02     1.000000E+21
#          34  traj.phases.propelled_ascent.indep_states.states:r_32         c    -1.000000E+21     7.577306E-02     1.000000E+21
#          35  traj.phases.propelled_ascent.indep_states.states:r_33         c    -1.000000E+21     8.064173E-02     1.000000E+21
#          36  traj.phases.propelled_ascent.indep_states.states:r_34         c    -1.000000E+21     8.760482E-02     1.000000E+21
#          37  traj.phases.propelled_ascent.indep_states.states:r_35         c    -1.000000E+21     8.986786E-02     1.000000E+21
#          38  traj.phases.propelled_ascent.indep_states.states:r_36         c    -1.000000E+21     9.515725E-02     1.000000E+21
#          39  traj.phases.propelled_ascent.indep_states.states:r_37         c    -1.000000E+21     1.027007E-01     1.000000E+21
#          40  traj.phases.propelled_ascent.indep_states.states:r_38         c    -1.000000E+21     1.051473E-01     1.000000E+21
#          41  traj.phases.propelled_ascent.indep_states.states:r_39         c    -1.000000E+21     1.108572E-01     1.000000E+21
#          42  traj.phases.propelled_ascent.indep_states.states:r_40         c    -1.000000E+21     1.189809E-01     1.000000E+21
#          43  traj.phases.propelled_ascent.indep_states.states:r_41         c    -1.000000E+21     1.216112E-01     1.000000E+21
#          44  traj.phases.propelled_ascent.indep_states.states:r_42         c    -1.000000E+21     1.277417E-01     1.000000E+21
#          45  traj.phases.propelled_ascent.indep_states.states:r_43         c    -1.000000E+21     1.364460E-01     1.000000E+21
#          46  traj.phases.propelled_ascent.indep_states.states:r_44         c    -1.000000E+21     1.392602E-01     1.000000E+21
#          47  traj.phases.propelled_ascent.indep_states.states:r_45         c    -1.000000E+21     1.458119E-01     1.000000E+21
#          48  traj.phases.propelled_ascent.indep_states.states:r_46         c    -1.000000E+21     1.550978E-01     1.000000E+21
#          49  traj.phases.propelled_ascent.indep_states.states:r_47         c    -1.000000E+21     1.580962E-01     1.000000E+21
#          50  traj.phases.propelled_ascent.indep_states.states:r_48         c    -1.000000E+21     1.650699E-01     1.000000E+21
#          51  traj.phases.propelled_ascent.indep_states.states:r_49         c    -1.000000E+21     1.749388E-01     1.000000E+21
#          52  traj.phases.propelled_ascent.indep_states.states:r_50         c    -1.000000E+21     1.781218E-01     1.000000E+21
#          53  traj.phases.propelled_ascent.indep_states.states:r_51         c    -1.000000E+21     1.855189E-01     1.000000E+21
#          54  traj.phases.propelled_ascent.indep_states.states:r_52         c    -1.000000E+21     1.959727E-01     1.000000E+21
#          55  traj.phases.propelled_ascent.indep_states.states:r_53         c    -1.000000E+21     1.993411E-01     1.000000E+21
#          56  traj.phases.propelled_ascent.indep_states.states:r_54         c    -1.000000E+21     2.071631E-01     1.000000E+21
#          57  traj.phases.propelled_ascent.indep_states.states:r_55         c    -1.000000E+21     2.182042E-01     1.000000E+21
#          58  traj.phases.propelled_ascent.indep_states.states:r_56         c    -1.000000E+21     2.217589E-01     1.000000E+21
#          59  traj.phases.propelled_ascent.indep_states.states:r_57         c    -1.000000E+21     2.300077E-01     1.000000E+21
#          60  traj.phases.propelled_ascent.indep_states.states:r_58         c    -1.000000E+21     2.416393E-01     1.000000E+21
#          61  traj.phases.propelled_ascent.indep_states.states:r_59         c    -1.000000E+21     2.453811E-01     1.000000E+21
#          62  traj.phases.propelled_ascent.indep_states.states:r_60         c    -1.000000E+21     2.540592E-01     1.000000E+21
#          63  traj.phases.propelled_ascent.indep_states.states:r_61         c    -1.000000E+21     2.662846E-01     1.000000E+21
#          64  traj.phases.propelled_ascent.indep_states.states:r_62         c    -1.000000E+21     2.702148E-01     1.000000E+21
#          65  traj.phases.propelled_ascent.indep_states.states:r_63         c    -1.000000E+21     2.793250E-01     1.000000E+21
#          66  traj.phases.propelled_ascent.indep_states.states:r_64         c    -1.000000E+21     2.921484E-01     1.000000E+21
#          67  traj.phases.propelled_ascent.indep_states.states:r_65         c    -1.000000E+21     2.962682E-01     1.000000E+21
#          68  traj.phases.propelled_ascent.indep_states.states:r_66         c    -1.000000E+21     3.058136E-01     1.000000E+21
#          69  traj.phases.propelled_ascent.indep_states.states:r_67         c    -1.000000E+21     3.192396E-01     1.000000E+21
#          70  traj.phases.propelled_ascent.indep_states.states:r_68         c    -1.000000E+21     3.235507E-01     1.000000E+21
#          71  traj.phases.propelled_ascent.indep_states.states:r_69         c    -1.000000E+21     3.335349E-01     1.000000E+21
#          72  traj.phases.propelled_ascent.indep_states.states:r_70         c    -1.000000E+21     3.475687E-01     1.000000E+21
#          73  traj.phases.propelled_ascent.indep_states.states:r_71         c    -1.000000E+21     3.520727E-01     1.000000E+21
#          74  traj.phases.propelled_ascent.indep_states.states:r_72         c    -1.000000E+21     3.624998E-01     1.000000E+21
#          75  traj.phases.propelled_ascent.indep_states.states:r_73         c    -1.000000E+21     3.771472E-01     1.000000E+21
#          76  traj.phases.propelled_ascent.indep_states.states:r_74         c    -1.000000E+21     3.818460E-01     1.000000E+21
#          77  traj.phases.propelled_ascent.indep_states.states:r_75         c    -1.000000E+21     3.927205E-01     1.000000E+21
#          78  traj.phases.propelled_ascent.indep_states.states:r_76         c    -1.000000E+21     4.079880E-01     1.000000E+21
#          79  traj.phases.propelled_ascent.indep_states.states:r_77         c    -1.000000E+21     4.128838E-01     1.000000E+21
#          80  traj.phases.propelled_ascent.indep_states.states:r_78         c    -1.000000E+21     4.242107E-01     1.000000E+21
#          81  traj.phases.propelled_ascent.indep_states.states:r_79         c    -1.000000E+21     4.401054E-01     1.000000E+21
#          82  traj.phases.propelled_ascent.indep_states.states:r_80         c    -1.000000E+21     4.452005E-01     1.000000E+21
#          83  traj.phases.propelled_ascent.indep_states.states:r_81         c    -1.000000E+21     4.569852E-01     1.000000E+21
#          84  traj.phases.propelled_ascent.indep_states.states:r_82         c    -1.000000E+21     4.735151E-01     1.000000E+21
#          85  traj.phases.propelled_ascent.indep_states.states:r_83         c    -1.000000E+21     4.788121E-01     1.000000E+21
#          86  traj.phases.propelled_ascent.indep_states.states:r_84         c    -1.000000E+21     4.910606E-01     1.000000E+21
#          87  traj.phases.propelled_ascent.indep_states.states:r_85         c    -1.000000E+21     5.082343E-01     1.000000E+21
#          88  traj.phases.propelled_ascent.indep_states.states:r_86         c    -1.000000E+21     5.137360E-01     1.000000E+21
#          89  traj.phases.propelled_ascent.indep_states.states:r_87         c    -1.000000E+21     5.264550E-01     1.000000E+21
#          90  traj.phases.propelled_ascent.indep_states.states:r_88         c    -1.000000E+21     5.442818E-01     1.000000E+21
#          91  traj.phases.propelled_ascent.indep_states.states:r_89         c    -1.000000E+21     5.499913E-01     1.000000E+21
#          92  traj.phases.propelled_ascent.indep_states.states:r_90         c    -1.000000E+21     5.631879E-01     1.000000E+21
#          93  traj.phases.propelled_ascent.indep_states.states:r_91         c    -1.000000E+21     5.816783E-01     1.000000E+21
#          94  traj.phases.propelled_ascent.indep_states.states:r_92         c    -1.000000E+21     5.875989E-01     1.000000E+21
#          95  traj.phases.propelled_ascent.indep_states.states:r_93         c    -1.000000E+21     6.012810E-01     1.000000E+21
#          96  traj.phases.propelled_ascent.indep_states.states:r_94         c    -1.000000E+21     6.204462E-01     1.000000E+21
#          97  traj.phases.propelled_ascent.indep_states.states:r_95         c    -1.000000E+21     6.265816E-01     1.000000E+21
#          98  traj.phases.propelled_ascent.indep_states.states:r_96         c    -1.000000E+21     6.407579E-01     1.000000E+21
#          99  traj.phases.propelled_ascent.indep_states.states:r_97         c    -1.000000E+21     6.606102E-01     1.000000E+21
#         100  traj.phases.propelled_ascent.indep_states.states:r_98         c    -1.000000E+21     6.669643E-01     1.000000E+21
#         101  traj.phases.propelled_ascent.indep_states.states:r_99         c    -1.000000E+21     6.816441E-01     1.000000E+21
#         102  traj.phases.propelled_ascent.indep_states.states:r_100        c    -1.000000E+21     7.021968E-01     1.000000E+21
#         103  traj.phases.propelled_ascent.indep_states.states:r_101        c    -1.000000E+21     7.087741E-01     1.000000E+21
#         104  traj.phases.propelled_ascent.indep_states.states:r_102        c    -1.000000E+21     7.239675E-01     1.000000E+21
#         105  traj.phases.propelled_ascent.indep_states.states:r_103        c    -1.000000E+21     7.452353E-01     1.000000E+21
#         106  traj.phases.propelled_ascent.indep_states.states:r_104        c    -1.000000E+21     7.520405E-01     1.000000E+21
#         107  traj.phases.propelled_ascent.indep_states.states:r_105        c    -1.000000E+21     7.677587E-01     1.000000E+21
#         108  traj.phases.propelled_ascent.indep_states.states:r_106        c    -1.000000E+21     7.897575E-01     1.000000E+21
#         109  traj.phases.propelled_ascent.indep_states.states:r_107        c    -1.000000E+21     7.967957E-01     1.000000E+21
#         110  traj.phases.propelled_ascent.indep_states.states:r_108        c    -1.000000E+21     8.130508E-01     1.000000E+21
#         111  traj.phases.propelled_ascent.indep_states.states:r_109        c    -1.000000E+21     8.357980E-01     1.000000E+21
#         112  traj.phases.propelled_ascent.indep_states.states:r_110        c    -1.000000E+21     8.430750E-01     1.000000E+21
#         113  traj.phases.propelled_ascent.indep_states.states:r_111        c    -1.000000E+21     8.598802E-01     1.000000E+21
#         114  traj.phases.propelled_ascent.indep_states.states:r_112        c    -1.000000E+21     8.833948E-01     1.000000E+21
#         115  traj.phases.propelled_ascent.indep_states.states:r_113        c    -1.000000E+21     8.909167E-01     1.000000E+21
#         116  traj.phases.propelled_ascent.indep_states.states:r_114        c    -1.000000E+21     9.082866E-01     1.000000E+21
#         117  traj.phases.propelled_ascent.indep_states.states:r_115        c    -1.000000E+21     9.325893E-01     1.000000E+21
#         118  traj.phases.propelled_ascent.indep_states.states:r_116        c    -1.000000E+21     9.403629E-01     1.000000E+21
#         119  traj.phases.propelled_ascent.indep_states.states:r_117        c    -1.000000E+21     9.583134E-01     1.000000E+21
#         120  traj.phases.propelled_ascent.indep_states.states:r_118        c    -1.000000E+21     9.834271E-01     1.000000E+21
#         121  traj.phases.propelled_ascent.indep_states.states:r_119        c    -1.000000E+21     9.914599E-01     1.000000E+21
#         122  traj.phases.propelled_ascent.indep_states.states:r_120        c    -1.000000E+21     1.010008E+00     1.000000E+21
#         123  traj.phases.propelled_ascent.indep_states.states:r_121        c    -1.000000E+21     1.035958E+00     1.000000E+21
#         124  traj.phases.propelled_ascent.indep_states.states:r_122        c    -1.000000E+21     1.044258E+00     1.000000E+21
#         125  traj.phases.propelled_ascent.indep_states.states:r_123        c    -1.000000E+21     1.063424E+00     1.000000E+21
#         126  traj.phases.propelled_ascent.indep_states.states:r_124        c    -1.000000E+21     1.090238E+00     1.000000E+21
#         127  traj.phases.propelled_ascent.indep_states.states:r_125        c    -1.000000E+21     1.098814E+00     1.000000E+21
#         128  traj.phases.propelled_ascent.indep_states.states:r_126        c    -1.000000E+21     1.118619E+00     1.000000E+21
#         129  traj.phases.propelled_ascent.indep_states.states:r_127        c    -1.000000E+21     1.146327E+00     1.000000E+21
#         130  traj.phases.propelled_ascent.indep_states.states:r_128        c    -1.000000E+21     1.155190E+00     1.000000E+21
#         131  traj.phases.propelled_ascent.indep_states.states:r_129        c    -1.000000E+21     1.175656E+00     1.000000E+21
#         132  traj.phases.propelled_ascent.indep_states.states:r_130        c    -1.000000E+21     1.204293E+00     1.000000E+21
#         133  traj.phases.propelled_ascent.indep_states.states:r_131        c    -1.000000E+21     1.213453E+00     1.000000E+21
#         134  traj.phases.propelled_ascent.indep_states.states:r_132        c    -1.000000E+21     1.234608E+00     1.000000E+21
#         135  traj.phases.propelled_ascent.indep_states.states:r_133        c    -1.000000E+21     1.264211E+00     1.000000E+21
#         136  traj.phases.propelled_ascent.indep_states.states:r_134        c    -1.000000E+21     1.273682E+00     1.000000E+21
#         137  traj.phases.propelled_ascent.indep_states.states:r_135        c    -1.000000E+21     1.295554E+00     1.000000E+21
#         138  traj.phases.propelled_ascent.indep_states.states:r_136        c    -1.000000E+21     1.326166E+00     1.000000E+21
#         139  traj.phases.propelled_ascent.indep_states.states:r_137        c    -1.000000E+21     1.335961E+00     1.000000E+21
#         140  traj.phases.propelled_ascent.indep_states.states:r_138        c    -1.000000E+21     1.358584E+00     1.000000E+21
#         141  traj.phases.propelled_ascent.indep_states.states:r_139        c    -1.000000E+21     1.390253E+00     1.000000E+21
#         142  traj.phases.propelled_ascent.indep_states.states:r_140        c    -1.000000E+21     1.400388E+00     1.000000E+21
#         143  traj.phases.propelled_ascent.indep_states.states:r_141        c    -1.000000E+21     1.423799E+00     1.000000E+21
#         144  traj.phases.propelled_ascent.indep_states.states:r_142        c    -1.000000E+21     1.456579E+00     1.000000E+21
#         145  traj.phases.propelled_ascent.indep_states.states:r_143        c    -1.000000E+21     1.467071E+00     1.000000E+21
#         146  traj.phases.propelled_ascent.indep_states.states:r_144        c    -1.000000E+21     1.491313E+00     1.000000E+21
#         147  traj.phases.propelled_ascent.indep_states.states:r_145        c    -1.000000E+21     1.525267E+00     1.000000E+21
#         148  traj.phases.propelled_ascent.indep_states.states:r_146        c    -1.000000E+21     1.536137E+00     1.000000E+21
#         149  traj.phases.propelled_ascent.indep_states.states:r_147        c    -1.000000E+21     1.561259E+00     1.000000E+21
#         150  traj.phases.propelled_ascent.indep_states.states:r_148        c    -1.000000E+21     1.596457E+00     1.000000E+21
#         151  traj.phases.propelled_ascent.indep_states.states:r_149        c    -1.000000E+21     1.607730E+00     1.000000E+21
#         152  traj.phases.propelled_ascent.indep_states.states:h_0          c    -1.000000E+21     1.315315E-04     1.000000E+21
#         153  traj.phases.propelled_ascent.indep_states.states:h_1          c    -1.000000E+21     5.534232E-04     1.000000E+21
#         154  traj.phases.propelled_ascent.indep_states.states:h_2          c    -1.000000E+21     7.443465E-04     1.000000E+21
#         155  traj.phases.propelled_ascent.indep_states.states:h_3          c    -1.000000E+21     1.281982E-03     1.000000E+21
#         156  traj.phases.propelled_ascent.indep_states.states:h_4          c    -1.000000E+21     2.253520E-03     1.000000E+21
#         157  traj.phases.propelled_ascent.indep_states.states:h_5          c    -1.000000E+21     2.615917E-03     1.000000E+21
#         158  traj.phases.propelled_ascent.indep_states.states:h_6          c    -1.000000E+21     3.544309E-03     1.000000E+21
#         159  traj.phases.propelled_ascent.indep_states.states:h_7          c    -1.000000E+21     5.048648E-03     1.000000E+21
#         160  traj.phases.propelled_ascent.indep_states.states:h_8          c    -1.000000E+21     5.578283E-03     1.000000E+21
#         161  traj.phases.propelled_ascent.indep_states.states:h_9          c    -1.000000E+21     6.887314E-03     1.000000E+21
#         162  traj.phases.propelled_ascent.indep_states.states:h_10         c    -1.000000E+21     8.911904E-03     1.000000E+21
#         163  traj.phases.propelled_ascent.indep_states.states:h_11         c    -1.000000E+21     9.605081E-03     1.000000E+21
#         164  traj.phases.propelled_ascent.indep_states.states:h_12         c    -1.000000E+21     1.128671E-02     1.000000E+21
#         165  traj.phases.propelled_ascent.indep_states.states:h_13         c    -1.000000E+21     1.382131E-02     1.000000E+21
#         166  traj.phases.propelled_ascent.indep_states.states:h_14         c    -1.000000E+21     1.467497E-02     1.000000E+21
#         167  traj.phases.propelled_ascent.indep_states.states:h_15         c    -1.000000E+21     1.672248E-02     1.000000E+21
#         168  traj.phases.propelled_ascent.indep_states.states:h_16         c    -1.000000E+21     1.975847E-02     1.000000E+21
#         169  traj.phases.propelled_ascent.indep_states.states:h_17         c    -1.000000E+21     2.077003E-02     1.000000E+21
#         170  traj.phases.propelled_ascent.indep_states.states:h_18         c    -1.000000E+21     2.317775E-02     1.000000E+21
#         171  traj.phases.propelled_ascent.indep_states.states:h_19         c    -1.000000E+21     2.670778E-02     1.000000E+21
#         172  traj.phases.propelled_ascent.indep_states.states:h_20         c    -1.000000E+21     2.787502E-02     1.000000E+21
#         173  traj.phases.propelled_ascent.indep_states.states:h_21         c    -1.000000E+21     3.063807E-02     1.000000E+21
#         174  traj.phases.propelled_ascent.indep_states.states:h_22         c    -1.000000E+21     3.465585E-02     1.000000E+21
#         175  traj.phases.propelled_ascent.indep_states.states:h_23         c    -1.000000E+21     3.597688E-02     1.000000E+21
#         176  traj.phases.propelled_ascent.indep_states.states:h_24         c    -1.000000E+21     3.909110E-02     1.000000E+21
#         177  traj.phases.propelled_ascent.indep_states.states:h_25         c    -1.000000E+21     4.359126E-02     1.000000E+21
#         178  traj.phases.propelled_ascent.indep_states.states:h_26         c    -1.000000E+21     4.506447E-02     1.000000E+21
#         179  traj.phases.propelled_ascent.indep_states.states:h_27         c    -1.000000E+21     4.852630E-02     1.000000E+21
#         180  traj.phases.propelled_ascent.indep_states.states:h_28         c    -1.000000E+21     5.350427E-02     1.000000E+21
#         181  traj.phases.propelled_ascent.indep_states.states:h_29         c    -1.000000E+21     5.512829E-02     1.000000E+21
#         182  traj.phases.propelled_ascent.indep_states.states:h_30         c    -1.000000E+21     5.893474E-02     1.000000E+21
#         183  traj.phases.propelled_ascent.indep_states.states:h_31         c    -1.000000E+21     6.438669E-02     1.000000E+21
#         184  traj.phases.propelled_ascent.indep_states.states:h_32         c    -1.000000E+21     6.616037E-02     1.000000E+21
#         185  traj.phases.propelled_ascent.indep_states.states:h_33         c    -1.000000E+21     7.030895E-02     1.000000E+21
#         186  traj.phases.propelled_ascent.indep_states.states:h_34         c    -1.000000E+21     7.623171E-02     1.000000E+21
#         187  traj.phases.propelled_ascent.indep_states.states:h_35         c    -1.000000E+21     7.815412E-02     1.000000E+21
#         188  traj.phases.propelled_ascent.indep_states.states:h_36         c    -1.000000E+21     8.264281E-02     1.000000E+21
#         189  traj.phases.propelled_ascent.indep_states.states:h_37         c    -1.000000E+21     8.903384E-02     1.000000E+21
#         190  traj.phases.propelled_ascent.indep_states.states:h_38         c    -1.000000E+21     9.110423E-02     1.000000E+21
#         191  traj.phases.propelled_ascent.indep_states.states:h_39         c    -1.000000E+21     9.593144E-02     1.000000E+21
#         192  traj.phases.propelled_ascent.indep_states.states:h_40         c    -1.000000E+21     1.027888E-01     1.000000E+21
#         193  traj.phases.propelled_ascent.indep_states.states:h_41         c    -1.000000E+21     1.050066E-01     1.000000E+21
#         194  traj.phases.propelled_ascent.indep_states.states:h_42         c    -1.000000E+21     1.101712E-01     1.000000E+21
#         195  traj.phases.propelled_ascent.indep_states.states:h_43         c    -1.000000E+21     1.174935E-01     1.000000E+21
#         196  traj.phases.propelled_ascent.indep_states.states:h_44         c    -1.000000E+21     1.198583E-01     1.000000E+21
#         197  traj.phases.propelled_ascent.indep_states.states:h_45         c    -1.000000E+21     1.253594E-01     1.000000E+21
#         198  traj.phases.propelled_ascent.indep_states.states:h_46         c    -1.000000E+21     1.331458E-01     1.000000E+21
#         199  traj.phases.propelled_ascent.indep_states.states:h_47         c    -1.000000E+21     1.356575E-01     1.000000E+21
#         200  traj.phases.propelled_ascent.indep_states.states:h_48         c    -1.000000E+21     1.414947E-01     1.000000E+21
#         201  traj.phases.propelled_ascent.indep_states.states:h_49         c    -1.000000E+21     1.497449E-01     1.000000E+21
#         202  traj.phases.propelled_ascent.indep_states.states:h_50         c    -1.000000E+21     1.524034E-01     1.000000E+21
#         203  traj.phases.propelled_ascent.indep_states.states:h_51         c    -1.000000E+21     1.585767E-01     1.000000E+21
#         204  traj.phases.propelled_ascent.indep_states.states:h_52         c    -1.000000E+21     1.672908E-01     1.000000E+21
#         205  traj.phases.propelled_ascent.indep_states.states:h_53         c    -1.000000E+21     1.700962E-01     1.000000E+21
#         206  traj.phases.propelled_ascent.indep_states.states:h_54         c    -1.000000E+21     1.766060E-01     1.000000E+21
#         207  traj.phases.propelled_ascent.indep_states.states:h_55         c    -1.000000E+21     1.857847E-01     1.000000E+21
#         208  traj.phases.propelled_ascent.indep_states.states:h_56         c    -1.000000E+21     1.887372E-01     1.000000E+21
#         209  traj.phases.propelled_ascent.indep_states.states:h_57         c    -1.000000E+21     1.955842E-01     1.000000E+21
#         210  traj.phases.propelled_ascent.indep_states.states:h_58         c    -1.000000E+21     2.052287E-01     1.000000E+21
#         211  traj.phases.propelled_ascent.indep_states.states:h_59         c    -1.000000E+21     2.083288E-01     1.000000E+21
#         212  traj.phases.propelled_ascent.indep_states.states:h_60         c    -1.000000E+21     2.155140E-01     1.000000E+21
#         213  traj.phases.propelled_ascent.indep_states.states:h_61         c    -1.000000E+21     2.256259E-01     1.000000E+21
#         214  traj.phases.propelled_ascent.indep_states.states:h_62         c    -1.000000E+21     2.288741E-01     1.000000E+21
#         215  traj.phases.propelled_ascent.indep_states.states:h_63         c    -1.000000E+21     2.363990E-01     1.000000E+21
#         216  traj.phases.propelled_ascent.indep_states.states:h_64         c    -1.000000E+21     2.469806E-01     1.000000E+21
#         217  traj.phases.propelled_ascent.indep_states.states:h_65         c    -1.000000E+21     2.503777E-01     1.000000E+21
#         218  traj.phases.propelled_ascent.indep_states.states:h_66         c    -1.000000E+21     2.582440E-01     1.000000E+21
#         219  traj.phases.propelled_ascent.indep_states.states:h_67         c    -1.000000E+21     2.692979E-01     1.000000E+21
#         220  traj.phases.propelled_ascent.indep_states.states:h_68         c    -1.000000E+21     2.728448E-01     1.000000E+21
#         221  traj.phases.propelled_ascent.indep_states.states:h_69         c    -1.000000E+21     2.810547E-01     1.000000E+21
#         222  traj.phases.propelled_ascent.indep_states.states:h_70         c    -1.000000E+21     2.925841E-01     1.000000E+21
#         223  traj.phases.propelled_ascent.indep_states.states:h_71         c    -1.000000E+21     2.962818E-01     1.000000E+21
#         224  traj.phases.propelled_ascent.indep_states.states:h_72         c    -1.000000E+21     3.048379E-01     1.000000E+21
#         225  traj.phases.propelled_ascent.indep_states.states:h_73         c    -1.000000E+21     3.168465E-01     1.000000E+21
#         226  traj.phases.propelled_ascent.indep_states.states:h_74         c    -1.000000E+21     3.206963E-01     1.000000E+21
#         227  traj.phases.propelled_ascent.indep_states.states:h_75         c    -1.000000E+21     3.296015E-01     1.000000E+21
#         228  traj.phases.propelled_ascent.indep_states.states:h_76         c    -1.000000E+21     3.420936E-01     1.000000E+21
#         229  traj.phases.propelled_ascent.indep_states.states:h_77         c    -1.000000E+21     3.460970E-01     1.000000E+21
#         230  traj.phases.propelled_ascent.indep_states.states:h_78         c    -1.000000E+21     3.553545E-01     1.000000E+21
#         231  traj.phases.propelled_ascent.indep_states.states:h_79         c    -1.000000E+21     3.683350E-01     1.000000E+21
#         232  traj.phases.propelled_ascent.indep_states.states:h_80         c    -1.000000E+21     3.724935E-01     1.000000E+21
#         233  traj.phases.propelled_ascent.indep_states.states:h_81         c    -1.000000E+21     3.821072E-01     1.000000E+21
#         234  traj.phases.propelled_ascent.indep_states.states:h_82         c    -1.000000E+21     3.955816E-01     1.000000E+21
#         235  traj.phases.propelled_ascent.indep_states.states:h_83         c    -1.000000E+21     3.998970E-01     1.000000E+21
#         236  traj.phases.propelled_ascent.indep_states.states:h_84         c    -1.000000E+21     4.098711E-01     1.000000E+21
#         237  traj.phases.propelled_ascent.indep_states.states:h_85         c    -1.000000E+21     4.238454E-01     1.000000E+21
#         238  traj.phases.propelled_ascent.indep_states.states:h_86         c    -1.000000E+21     4.283197E-01     1.000000E+21
#         239  traj.phases.propelled_ascent.indep_states.states:h_87         c    -1.000000E+21     4.386590E-01     1.000000E+21
#         240  traj.phases.propelled_ascent.indep_states.states:h_88         c    -1.000000E+21     4.531400E-01     1.000000E+21
#         241  traj.phases.propelled_ascent.indep_states.states:h_89         c    -1.000000E+21     4.577754E-01     1.000000E+21
#         242  traj.phases.propelled_ascent.indep_states.states:h_90         c    -1.000000E+21     4.684849E-01     1.000000E+21
#         243  traj.phases.propelled_ascent.indep_states.states:h_91         c    -1.000000E+21     4.834802E-01     1.000000E+21
#         244  traj.phases.propelled_ascent.indep_states.states:h_92         c    -1.000000E+21     4.882791E-01     1.000000E+21
#         245  traj.phases.propelled_ascent.indep_states.states:h_93         c    -1.000000E+21     4.993647E-01     1.000000E+21
#         246  traj.phases.propelled_ascent.indep_states.states:h_94         c    -1.000000E+21     5.148824E-01     1.000000E+21
#         247  traj.phases.propelled_ascent.indep_states.states:h_95         c    -1.000000E+21     5.198476E-01     1.000000E+21
#         248  traj.phases.propelled_ascent.indep_states.states:h_96         c    -1.000000E+21     5.313156E-01     1.000000E+21
#         249  traj.phases.propelled_ascent.indep_states.states:h_97         c    -1.000000E+21     5.473648E-01     1.000000E+21
#         250  traj.phases.propelled_ascent.indep_states.states:h_98         c    -1.000000E+21     5.524992E-01     1.000000E+21
#         251  traj.phases.propelled_ascent.indep_states.states:h_99         c    -1.000000E+21     5.643565E-01     1.000000E+21
#         252  traj.phases.propelled_ascent.indep_states.states:h_100        c    -1.000000E+21     5.809472E-01     1.000000E+21
#         253  traj.phases.propelled_ascent.indep_states.states:h_101        c    -1.000000E+21     5.862541E-01     1.000000E+21
#         254  traj.phases.propelled_ascent.indep_states.states:h_102        c    -1.000000E+21     5.985083E-01     1.000000E+21
#         255  traj.phases.propelled_ascent.indep_states.states:h_103        c    -1.000000E+21     6.156515E-01     1.000000E+21
#         256  traj.phases.propelled_ascent.indep_states.states:h_104        c    -1.000000E+21     6.211344E-01     1.000000E+21
#         257  traj.phases.propelled_ascent.indep_states.states:h_105        c    -1.000000E+21     6.337939E-01     1.000000E+21
#         258  traj.phases.propelled_ascent.indep_states.states:h_106        c    -1.000000E+21     6.515016E-01     1.000000E+21
#         259  traj.phases.propelled_ascent.indep_states.states:h_107        c    -1.000000E+21     6.571644E-01     1.000000E+21
#         260  traj.phases.propelled_ascent.indep_states.states:h_108        c    -1.000000E+21     6.702384E-01     1.000000E+21
#         261  traj.phases.propelled_ascent.indep_states.states:h_109        c    -1.000000E+21     6.885237E-01     1.000000E+21
#         262  traj.phases.propelled_ascent.indep_states.states:h_110        c    -1.000000E+21     6.943707E-01     1.000000E+21
#         263  traj.phases.propelled_ascent.indep_states.states:h_111        c    -1.000000E+21     7.078693E-01     1.000000E+21
#         264  traj.phases.propelled_ascent.indep_states.states:h_112        c    -1.000000E+21     7.267466E-01     1.000000E+21
#         265  traj.phases.propelled_ascent.indep_states.states:h_113        c    -1.000000E+21     7.327827E-01     1.000000E+21
#         266  traj.phases.propelled_ascent.indep_states.states:h_114        c    -1.000000E+21     7.467169E-01     1.000000E+21
#         267  traj.phases.propelled_ascent.indep_states.states:h_115        c    -1.000000E+21     7.662022E-01     1.000000E+21
#         268  traj.phases.propelled_ascent.indep_states.states:h_116        c    -1.000000E+21     7.724324E-01     1.000000E+21
#         269  traj.phases.propelled_ascent.indep_states.states:h_117        c    -1.000000E+21     7.868143E-01     1.000000E+21
#         270  traj.phases.propelled_ascent.indep_states.states:h_118        c    -1.000000E+21     8.069251E-01     1.000000E+21
#         271  traj.phases.propelled_ascent.indep_states.states:h_119        c    -1.000000E+21     8.133552E-01     1.000000E+21
#         272  traj.phases.propelled_ascent.indep_states.states:h_120        c    -1.000000E+21     8.281984E-01     1.000000E+21
#         273  traj.phases.propelled_ascent.indep_states.states:h_121        c    -1.000000E+21     8.489540E-01     1.000000E+21
#         274  traj.phases.propelled_ascent.indep_states.states:h_122        c    -1.000000E+21     8.555902E-01     1.000000E+21
#         275  traj.phases.propelled_ascent.indep_states.states:h_123        c    -1.000000E+21     8.709094E-01     1.000000E+21
#         276  traj.phases.propelled_ascent.indep_states.states:h_124        c    -1.000000E+21     8.923311E-01     1.000000E+21
#         277  traj.phases.propelled_ascent.indep_states.states:h_125        c    -1.000000E+21     8.991805E-01     1.000000E+21
#         278  traj.phases.propelled_ascent.indep_states.states:h_126        c    -1.000000E+21     9.149922E-01     1.000000E+21
#         279  traj.phases.propelled_ascent.indep_states.states:h_127        c    -1.000000E+21     9.371038E-01     1.000000E+21
#         280  traj.phases.propelled_ascent.indep_states.states:h_128        c    -1.000000E+21     9.441740E-01     1.000000E+21
#         281  traj.phases.propelled_ascent.indep_states.states:h_129        c    -1.000000E+21     9.604964E-01     1.000000E+21
#         282  traj.phases.propelled_ascent.indep_states.states:h_130        c    -1.000000E+21     9.833242E-01     1.000000E+21
#         283  traj.phases.propelled_ascent.indep_states.states:h_131        c    -1.000000E+21     9.906240E-01     1.000000E+21
#         284  traj.phases.propelled_ascent.indep_states.states:h_132        c    -1.000000E+21     1.007477E+00     1.000000E+21
#         285  traj.phases.propelled_ascent.indep_states.states:h_133        c    -1.000000E+21     1.031051E+00     1.000000E+21
#         286  traj.phases.propelled_ascent.indep_states.states:h_134        c    -1.000000E+21     1.038590E+00     1.000000E+21
#         287  traj.phases.propelled_ascent.indep_states.states:h_135        c    -1.000000E+21     1.055997E+00     1.000000E+21
#         288  traj.phases.propelled_ascent.indep_states.states:h_136        c    -1.000000E+21     1.080349E+00     1.000000E+21
#         289  traj.phases.propelled_ascent.indep_states.states:h_137        c    -1.000000E+21     1.088138E+00     1.000000E+21
#         290  traj.phases.propelled_ascent.indep_states.states:h_138        c    -1.000000E+21     1.106125E+00     1.000000E+21
#         291  traj.phases.propelled_ascent.indep_states.states:h_139        c    -1.000000E+21     1.131293E+00     1.000000E+21
#         292  traj.phases.propelled_ascent.indep_states.states:h_140        c    -1.000000E+21     1.139345E+00     1.000000E+21
#         293  traj.phases.propelled_ascent.indep_states.states:h_141        c    -1.000000E+21     1.157940E+00     1.000000E+21
#         294  traj.phases.propelled_ascent.indep_states.states:h_142        c    -1.000000E+21     1.183967E+00     1.000000E+21
#         295  traj.phases.propelled_ascent.indep_states.states:h_143        c    -1.000000E+21     1.192295E+00     1.000000E+21
#         296  traj.phases.propelled_ascent.indep_states.states:h_144        c    -1.000000E+21     1.211532E+00     1.000000E+21
#         297  traj.phases.propelled_ascent.indep_states.states:h_145        c    -1.000000E+21     1.238465E+00     1.000000E+21
#         298  traj.phases.propelled_ascent.indep_states.states:h_146        c    -1.000000E+21     1.247085E+00     1.000000E+21
#         299  traj.phases.propelled_ascent.indep_states.states:h_147        c    -1.000000E+21     1.267003E+00     1.000000E+21
#         300  traj.phases.propelled_ascent.indep_states.states:h_148        c    -1.000000E+21     1.294899E+00     1.000000E+21
#         301  traj.phases.propelled_ascent.indep_states.states:h_149        c    -1.000000E+21     1.303830E+00     1.000000E+21
#         302  traj.phases.propelled_ascent.indep_states.states:gam_0        c     0.000000E+00     5.121176E-01     9.444444E-01
#         303  traj.phases.propelled_ascent.indep_states.states:gam_1        c     0.000000E+00     4.914509E-01     9.444444E-01
#         304  traj.phases.propelled_ascent.indep_states.states:gam_2        c     0.000000E+00     4.852958E-01     9.444444E-01
#         305  traj.phases.propelled_ascent.indep_states.states:gam_3        c     0.000000E+00     4.820503E-01     9.444444E-01
#         306  traj.phases.propelled_ascent.indep_states.states:gam_4        c     0.000000E+00     4.783108E-01     9.444444E-01
#         307  traj.phases.propelled_ascent.indep_states.states:gam_5        c     0.000000E+00     4.744143E-01     9.444444E-01
#         308  traj.phases.propelled_ascent.indep_states.states:gam_6        c     0.000000E+00     4.733549E-01     9.444444E-01
#         309  traj.phases.propelled_ascent.indep_states.states:gam_7        c     0.000000E+00     4.712087E-01     9.444444E-01
#         310  traj.phases.propelled_ascent.indep_states.states:gam_8        c     0.000000E+00     4.686927E-01     9.444444E-01
#         311  traj.phases.propelled_ascent.indep_states.states:gam_9        c     0.000000E+00     4.679760E-01     9.444444E-01
#         312  traj.phases.propelled_ascent.indep_states.states:gam_10       c     0.000000E+00     4.664584E-01     9.444444E-01
#         313  traj.phases.propelled_ascent.indep_states.states:gam_11       c     0.000000E+00     4.645920E-01     9.444444E-01
#         314  traj.phases.propelled_ascent.indep_states.states:gam_12       c     0.000000E+00     4.640461E-01     9.444444E-01
#         315  traj.phases.propelled_ascent.indep_states.states:gam_13       c     0.000000E+00     4.628669E-01     9.444444E-01
#         316  traj.phases.propelled_ascent.indep_states.states:gam_14       c     0.000000E+00     4.613782E-01     9.444444E-01
#         317  traj.phases.propelled_ascent.indep_states.states:gam_15       c     0.000000E+00     4.609357E-01     9.444444E-01
#         318  traj.phases.propelled_ascent.indep_states.states:gam_16       c     0.000000E+00     4.599685E-01     9.444444E-01
#         319  traj.phases.propelled_ascent.indep_states.states:gam_17       c     0.000000E+00     4.587272E-01     9.444444E-01
#         320  traj.phases.propelled_ascent.indep_states.states:gam_18       c     0.000000E+00     4.583542E-01     9.444444E-01
#         321  traj.phases.propelled_ascent.indep_states.states:gam_19       c     0.000000E+00     4.575327E-01     9.444444E-01
#         322  traj.phases.propelled_ascent.indep_states.states:gam_20       c     0.000000E+00     4.564663E-01     9.444444E-01
#         323  traj.phases.propelled_ascent.indep_states.states:gam_21       c     0.000000E+00     4.561434E-01     9.444444E-01
#         324  traj.phases.propelled_ascent.indep_states.states:gam_22       c     0.000000E+00     4.554282E-01     9.444444E-01
#         325  traj.phases.propelled_ascent.indep_states.states:gam_23       c     0.000000E+00     4.544922E-01     9.444444E-01
#         326  traj.phases.propelled_ascent.indep_states.states:gam_24       c     0.000000E+00     4.542071E-01     9.444444E-01
#         327  traj.phases.propelled_ascent.indep_states.states:gam_25       c     0.000000E+00     4.535732E-01     9.444444E-01
#         328  traj.phases.propelled_ascent.indep_states.states:gam_26       c     0.000000E+00     4.527382E-01     9.444444E-01
#         329  traj.phases.propelled_ascent.indep_states.states:gam_27       c     0.000000E+00     4.524828E-01     9.444444E-01
#         330  traj.phases.propelled_ascent.indep_states.states:gam_28       c     0.000000E+00     4.519130E-01     9.444444E-01
# ...
#        1126  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00   -7.029713E-15    0.000000E+00              9.00000E+100
#        1127  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    4.135125E-16    0.000000E+00              9.00000E+100
#        1128  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00   -9.355721E-15    0.000000E+00              9.00000E+100
#        1129  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    5.789175E-15    0.000000E+00              9.00000E+100
#        1130  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00   -7.805049E-15    0.000000E+00              9.00000E+100
#        1131  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    2.067563E-16    0.000000E+00              9.00000E+100
#        1132  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    1.654050E-15    0.000000E+00              9.00000E+100
#        1133  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    3.411478E-15    0.000000E+00              9.00000E+100
#        1134  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    1.953847E-14    0.000000E+00              9.00000E+100
#        1135  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00   -4.031747E-15    0.000000E+00              9.00000E+100
#        1136  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    1.281889E-14    0.000000E+00              9.00000E+100
#        1137  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    7.133091E-15    0.000000E+00              9.00000E+100
#        1138  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    6.461133E-15    0.000000E+00              9.00000E+100
#        1139  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    9.510788E-15    0.000000E+00              9.00000E+100
#        1140  traj.linkages.propelled_ascent:time_final|ballistic_ascent:time_initial    e   0.000000E+00    0.000000E+00    0.000000E+00              9.00000E+100
#        1141  traj.linkages.propelled_ascent:r_final|ballistic_ascent:r_initial          e   0.000000E+00    0.000000E+00    0.000000E+00              9.00000E+100
#        1142  traj.linkages.propelled_ascent:h_final|ballistic_ascent:h_initial          e   0.000000E+00    0.000000E+00    0.000000E+00              9.00000E+100
#        1143  traj.linkages.propelled_ascent:gam_final|ballistic_ascent:gam_initial      e   0.000000E+00   -7.105427E-15    0.000000E+00              9.00000E+100
#        1144  traj.linkages.propelled_ascent:v_final|ballistic_ascent:v_initial          e   0.000000E+00    0.000000E+00    0.000000E+00              9.00000E+100
#        1145  traj.linkages.ballistic_ascent:time_final|descent:time_initial             e   0.000000E+00    4.440892E-16    0.000000E+00              9.00000E+100
#        1146  traj.linkages.ballistic_ascent:r_final|descent:r_initial                   e   0.000000E+00    0.000000E+00    0.000000E+00              9.00000E+100
#        1147  traj.linkages.ballistic_ascent:h_final|descent:h_initial                   e   0.000000E+00    0.000000E+00    0.000000E+00              9.00000E+100
#        1148  traj.linkages.ballistic_ascent:gam_final|descent:gam_initial               e   0.000000E+00    1.098290E-20    0.000000E+00              9.00000E+100
#        1149  traj.linkages.ballistic_ascent:v_final|descent:v_initial                   e   0.000000E+00    0.000000E+00    0.000000E+00              9.00000E+100
#
# --------------------------------------------------------------------------------
# Launch angle: 46.0906 deg
# Flight angle at end of propulsion: 38.3884 deg
# Empty mass: 0.1891 kg
# Water volume: 1.0264 L
# Maximum range: 85.1142 m
# Maximum height: 23.0872 m
# Maximum velocity: 41.3132 m/s
#
# Simulating trajectory traj
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# /Users/dkilkenny/Desktop/OpenMDAO_Clone/openmdao/core/problem.py:440: OMDeprecationWarning:Problem 'value' will be deprecated in 4.0. Please use 'val' in the future.
# Done simulating trajectory traj

# %%
from openmdao.utils.assert_utils import assert_near_equal

# Check results (tolerance is relative unless value is zero)
assert_near_equal(summary['Launch angle'].value, 46, 0.02)
assert_near_equal(summary['Flight angle at end of propulsion'].value, 38, 0.02)
assert_near_equal(summary['Empty mass'].value, 0.189, 1e-2)
assert_near_equal(summary['Water volume'].value, 1.026, 1e-2)
assert_near_equal(summary['Maximum range'].value, 85.11, 1e-2)
assert_near_equal(summary['Maximum height'].value, 23.08, 1e-2)
assert_near_equal(summary['Maximum velocity'].value, 41.31, 1e-2)
# Out:
# 7.822391668503415e-05

# %% [markdown]
# ## References
#
# ```{bibliography}
# :filter: docname in docnames
# ```
