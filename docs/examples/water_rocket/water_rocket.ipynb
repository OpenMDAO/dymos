# %%
# This cell is mandatory in all Dymos documentation notebooks.
missing_packages = []
try:
    import openmdao.api as om
except ImportError:
    if 'google.colab' in str(get_ipython()):
        # !python -m pip install openmdao[notebooks]
    else:
        missing_packages.append('openmdao')
try:
    import dymos as dm
except ImportError:
    if 'google.colab' in str(get_ipython()):
        # !python -m pip install dymos
    else:
        missing_packages.append('dymos')
try:
    import pyoptsparse
except ImportError:
    if 'google.colab' in str(get_ipython()):
        # !pip install -q condacolab
        import condacolab
        condacolab.install_miniconda()
        # !conda install -c conda-forge pyoptsparse
    else:
        missing_packages.append('pyoptsparse')
if missing_packages:
    raise EnvironmentError('This notebook requires the following packages '
                           'please install them and restart this notebook\'s runtime: {",".join(missing_packages)}')

# %% [markdown]
# # Water Rocket
#
# Author: Bernardo Bahia Monteiro (bbahia@umich.edu)
#
# In this example, we will optimize a water rocket for range and height at the apogee, using design variables that are easily modifiable just before launch: the empty mass, the initial water volume and the launch angle.
# This example builds on [multi-phase cannonball](../multi_phase_cannonball/multi_phase_cannonball.md) ane is adapted from _Optimization of a Water Rocket in OpenMDAO/Dymos_ {cite}`bbahia_2020`.
#
# ## Nomenclature
#
# | Symbol               | definition                             |
# |----------------------|----------------------------------------|
# | $v_\text{out}$       | water exit speed at the nozzle         |
# | $A_\text{out}$       | nozzle area                            |
# | $V_w$                | water volume in the rocket             |
# | $p$                  | pressure in the rocket                 |
# | $p_a$                | ambient pressure                       |
# | $\dot{\,}$           | time derivative                        |
# | $k$                  | polytropic constant                    |
# | $V_b$                | internal volume of the rocket          |
# | $\rho_w$             | water density                          |
# | $T$                  | thrust                                 |
# | $q$                  | dynamic pressure                       |
# | $S$                  | cross sectional area                   |
# | $(\cdot)_0$          | value of $(\cdot)$ at $t=0$            |
# | $t$                  | time                                   |

# %% [markdown]
# ## Problem Formulation
#
# A natural objective function for a water rocket is the maximum height achieved by the rocket during flight, or the horizontal distance it travels, i.e. its range.
# The design of a water rocket is somewhat constrained by the soda bottle used as its engine.
# This means that the volume available for water and air is fixed, the initial launch pressure is limited by the bottle's strength (since the pressure is directly related to the energy available for the rocket, it is easy to see that it should be as high as possible) and the nozzle throat area is also fixed.
# Given these manufacturing constraints, the design variables we are left with are the empty mass (it can be easily changed through adding ballast), the water volume at the launch, and the launch angle.
# With this considerations in mind, a natural formulation for the water rocket problem is
#
# \begin{align}
#     \text{maximize}   &\quad \text{range or height} \\
#     \text{w.r.t.}     &\quad \text{empty mass, initial water volume, launch angle, trajectory} \\
#     \text{subject to} &\quad \text{flight dynamics} \\
#                       &\quad \text{fluid dynamics inside the rocket} \\
#                       &\quad 0 < \text{initial water volume} < \text{volume of bottle} \\
#                       &\quad 0^\circ < \text{launch angle} < 90^\circ \\
#                       &\quad 0 < \text{empty mass}
# \end{align}

# %% [markdown]
# ##  Model
#
# The water rocket model is divided into three basic components: a *water engine*, responsible for modelling the fluid dynamics inside the rocket and returning its thrust;  the *aerodynamics*, responsible for calculating the atmospheric drag of the rocket; and the *equations of motion*, responsible for propagating the rocket's trajectory in time, using Newton's laws and the forces provided by the other two components.
#
# In order to integrate these three basic components, some additional interfacing components are necessary: an atmospheric model to provide values of ambient pressure for the water engine and air density to the calculation of the dynamic pressure for the aerodynamic model, and a component that calculates the instantaneous mass of the rocket by summing the water mass with the rocket's empty mass.
# The high level layout of this model is shown in below.
#
# <figure>
#   <img src="figures/water_rocket_overview.svg"/>
#   <figcaption>N2 diagram for the water rocket model</figcaption>
# </figure>
#
# `atmos`, `dynamic_pressure`, `aero` and `eom` are the same models used in [multi-phase cannonball](../multi_phase_cannonball/multi_phase_cannonball.md).
# The remaining components are discussed below.
#
# ```{Warning}
# The `eom` component has a singularity in the flight path angle derivative when the flight speed is zero.
# This happens because the rotational dynamics are not modelled.
# This can cause convergence problems if the launch velocity is set to zero or the launch angle is set to $90^\circ$
# ```
#
# ```{Note}
# Since the range of altitudes achieved by the water rocket is very small (100m), the air density and pressure are practically constant, thus the use of an atmospheric model is not necessary. However, using it makes it easier to reuse code from [multi-phase cannonball (../multi_phase_cannonball/multi_phase_cannonball.md).
# ```
#
# ### Water engine
#
# The water engine is modelled by assuming that the air expansion in the rocket
# follows an adiabatic process and the water flow is incompressible and inviscid,
# i.e.  it follows Bernoulli's equation. We also make the following simplifying
# assumptions:
#
# 1. The thrust developed after the water is depleted is negligible
# 2. The area inside the bottle is much smaller than the nozzle area
# 3. The inertial forces do not affect the fluid dynamics inside the bottle
#
# This simplified modelling can be found in Prusa[@Prusa2000].
# A more rigorous formulation, which drops all these simplifying assumptions can be found in Wheeler[@Wheeler2002], Gommes[@Gommes2010], and Barria-Perotti[@BarrioPerotti2010].
#
# The first assumption leads to an underestimation of the rocket performance, since the air left in the bottle after it is out of water is known to generate appreciable thrust[@Thorncroft2009].
# This simplified model, however, produces physically meaningful results.
#
# There are two states in this dynamical model, the water volume in the rocket $V_w$ and the gauge pressure inside the rocket $p$.
# The constitutive equations and the N2 diagram showing the model organization are shown below.
#
# ### Constitutive equations of the water engine model
# | Component              | Equation                                                    |
# | -----------------------|-------------------------------------------------------------|
# | water_exhaust_speed    | $v_\text{out} = \sqrt{2(p-p_a)/\rho_w}$                     |
# | water_flow_rate        | $\dot{V}_w = -v_\text{out} A_\text{out}$                    |
# | pressure_rate          | $\dot{p} = kp\frac{\dot{V_w}}{(V_b-V_w)}$                   |
# | water_thrust           | $T = (\rho_w v_\text{out})(v_\text{out}A_\text{out})$       |
#
# <figure>
#   <img src="figures/water_rocket_waterengine.svg"/>
#   <figcaption>N2 diagram for the water engine group</figcaption>
# </figure>
#
# ### Water engine
#
# The water engine is modelled by assuming that the air expansion in the rocket
# follows an adiabatic process and the water flow is incompressible and inviscid,
# i.e.  it follows Bernoulli's equation. We also make the following simplifying
# assumptions:
#
# 1. The thrust developed after the water is depleted is negligible
# 2. The area inside the bottle is much smaller than the nozzle area
# 3. The inertial forces do not affect the fluid dynamics inside the bottle
#
# This simplified modelling can be found in Prusa {cite}`Prusa2000`.
# A more rigorous formulation, which drops all these simplifying assumptions can be found in Wheeler {cite}`Wheeler2002`, Gommes {cite}`Gommes2010`, and Barria-Perotti {cite}`BarrioPerotti2010`.
#
# The first assumption leads to an underestimation of the rocket performance, since the air left in the bottle after it is out of water is known to generate appreciable thrust {cite}`Thorncroft2009`.
# This simplified model, however, produces physically meaningful results.
#
# There are two states in this dynamical model, the water volume in the rocket $V_w$ and the gauge pressure inside the rocket $p$.
# The constitutive equations and the N2 diagram showing the model organization are shown below.
#
# ### Constitutive equations of the water engine model
# | Component              | Equation                                                    |
# | -----------------------|-------------------------------------------------------------|
# | water_exhaust_speed    | $v_\text{out} = \sqrt{2(p-p_a)/\rho_w}$                     |
# | water_flow_rate        | $\dot{V}_w = -v_\text{out} A_\text{out}$                    |
# | pressure_rate          | $\dot{p} = kp\frac{\dot{V_w}}{(V_b-V_w)}$                   |
# | water_thrust           | $T = (\rho_w v_\text{out})(v_\text{out}A_\text{out})$       |
#
# <figure>
#   <img src="figures/water_rocket_waterengine.svg"/>
#   <figcaption>N2 diagram for the water engine group</figcaption>
# </figure>

# %%
import numpy as np

import openmdao.api as om


class WaterEngine(om.Group):
    """
    Computes thrust and water flow for a water.

    Simplifications:
     - the pressure due to the water column in the non inertial frame (i.e.
       under a+g acceleration) is insignificant compared to the air pressure
     - the water does not have appreciable speed inside the bottle
    """
    def initialize(self):
        self.options.declare('num_nodes', types=int)

    def setup(self):
        nn = self.options['num_nodes']

        self.add_subsystem(name='water_exhaust_speed',
                           subsys=_WaterExhaustSpeed(num_nodes=nn),
                           promotes=['p', 'p_a', 'rho_w'])

        self.add_subsystem(name='water_flow_rate',
                           subsys=_WaterFlowRate(num_nodes=nn),
                           promotes=['A_out', 'Vdot'])

        self.add_subsystem(name='pressure_rate',
                           subsys=_PressureRate(num_nodes=nn),
                           promotes=['p', 'k', 'V_b', 'V_w', 'Vdot', 'pdot'])

        self.add_subsystem(name='water_thrust',
                           subsys=_WaterThrust(num_nodes=nn),
                           promotes=['rho_w', 'A_out', 'F'])

        self.connect('water_exhaust_speed.v_out', 'water_flow_rate.v_out')
        self.connect('water_exhaust_speed.v_out', 'water_thrust.v_out')

# %%
class _WaterExhaustSpeed(om.ExplicitComponent):
    def initialize(self):
        self.options.declare('num_nodes', types=int)

    def setup(self):
        nn = self.options['num_nodes']

        self.add_input(name='rho_w', val=1e3*np.ones(nn), desc='water density', units='kg/m**3')
        self.add_input(name='p', val=6.5e5*np.ones(nn), desc='air pressure', units='N/m**2')  # 5.5bar = 80 psi
        self.add_input(name='p_a', val=1.01e5*np.ones(nn), desc='air pressure', units='N/m**2')

        self.add_output(name='v_out', shape=(nn,), desc='water exhaust speed', units='m/s')

        ar = np.arange(nn)

        self.declare_partials(of='*', wrt='*', rows=ar, cols=ar)

    def compute(self, inputs, outputs):
        p = inputs['p']
        p_a = inputs['p_a']
        rho_w = inputs['rho_w']

        outputs['v_out'] = np.sqrt(2*(p-p_a)/rho_w)

    def compute_partials(self, inputs, partials):
        p = inputs['p']
        p_a = inputs['p_a']
        rho_w = inputs['rho_w']

        v_out = np.sqrt(2*(p-p_a)/rho_w)

        partials['v_out', 'p'] = 1/v_out/rho_w
        partials['v_out', 'p_a'] = -1/v_out/rho_w
        partials['v_out', 'rho_w'] = dv_outdrho_w = 1/v_out*(-(p-p_a)/rho_w**2)

# %%
class _PressureRate(om.ExplicitComponent):
    def initialize(self):
        self.options.declare('num_nodes', types=int)

    def setup(self):
        nn = self.options['num_nodes']

        self.add_input(name='p', val=np.ones(nn), desc='air pressure', units='N/m**2')
        self.add_input(name='k', val=1.4*np.ones(nn), desc='polytropic coefficient for expansion', units=None)
        self.add_input(name='V_b', val=2e-3*np.ones(nn), desc='bottle volume', units='m**3')
        self.add_input(name='V_w', val=1e-3*np.ones(nn), desc='water volume', units='m**3')
        self.add_input(name='Vdot', shape=(nn,), desc='water flow', units='m**3/s')

        self.add_output(name='pdot', shape=(nn,), desc='pressure derivative', units='N/m**2/s')

        ar = np.arange(nn)

        self.declare_partials(of='*', wrt='*', rows=ar, cols=ar)

    def compute(self, inputs, outputs):
        p = inputs['p']
        k = inputs['k']
        V_b = inputs['V_b']
        V_w = inputs['V_w']
        Vdot = inputs['Vdot']

        pdot = p*k*Vdot/(V_b-V_w)

        outputs['pdot'] = pdot

    def compute_partials(self, inputs, partials):
        p = inputs['p']
        k = inputs['k']
        V_b = inputs['V_b']
        V_w = inputs['V_w']
        Vdot = inputs['Vdot']

        partials['pdot', 'p'] = k*Vdot/(V_b-V_w)
        partials['pdot', 'k'] = p*Vdot/(V_b-V_w)
        partials['pdot', 'V_b'] = -p*k*Vdot/(V_b-V_w)**2
        partials['pdot', 'V_w'] = p*k*Vdot/(V_b-V_w)**2
        partials['pdot', 'Vdot'] = p*k/(V_b-V_w)

# %%
class _WaterFlowRate(om.ExplicitComponent):
    """ Computer water flow rate"""
    def initialize(self):
        self.options.declare('num_nodes', types=int)

    def setup(self):
        nn = self.options['num_nodes']

        self.add_input(name='A_out', val=np.ones(nn), desc='nozzle outlet area', units='m**2')
        self.add_input(name='v_out', val=np.zeros(nn), desc='water exhaust speed', units='m/s')

        self.add_output(name='Vdot', shape=(nn,), desc='water flow', units='m**3/s')

        ar = np.arange(nn)

        self.declare_partials(of='*', wrt='*', rows=ar, cols=ar)

    def compute(self, inputs, outputs):
        A_out = inputs['A_out']
        v_out = inputs['v_out']

        outputs['Vdot'] = -v_out*A_out

    def compute_partials(self, inputs, partials):
        A_out = inputs['A_out']
        v_out = inputs['v_out']

        partials['Vdot', 'A_out'] = -v_out
        partials['Vdot', 'v_out'] = -A_out

# %% [markdown]
# The `_MassAdder` component calculates the rocket's instantaneous mass by
# summing the water mass with the rockets empty mass, i.e.
#
# \begin{align}
#     m = m_\text{empty}+\rho_w V_w
# \end{align}

# %%
class _MassAdder(om.ExplicitComponent):

    def initialize(self):
        self.options.declare('num_nodes', types=int)

    def setup(self):
        nn = self.options['num_nodes']

        self.add_input('m_empty', val=np.zeros(nn), desc='empty mass', units='kg')
        self.add_input('V_w', val=1e-3*np.ones(nn), desc='water volume', units='m**3')
        self.add_input('rho_w', val=1e3*np.ones(nn), desc="water density", units='kg/m**3')

        self.add_output('m', val=np.zeros(nn), desc='total mass', units='kg')

        ar = np.arange(nn)
        self.declare_partials('*', '*', cols=ar, rows=ar)

    def compute(self, inputs, outputs):
        outputs['m'] = inputs['m_empty'] + inputs['rho_w']*inputs['V_w']

    def compute_partials(self, inputs, jacobian):
        jacobian['m', 'm_empty'] = 1
        jacobian['m', 'rho_w'] = inputs['V_w']
        jacobian['m', 'V_w'] = inputs['rho_w']

# %% [markdown]
# Now these components are joined in a single group

# %%
class WaterPropulsionODE(om.Group):

    def initialize(self):
        self.options.declare('num_nodes', types=int)
        self.options.declare('ballistic', types=bool, default=False,
                             desc='If True, neglect propulsion system.')

    def setup(self):
        nn = self.options['num_nodes']

        self.add_subsystem(name='atmos',
                           subsys=USatm1976Comp(num_nodes=nn))

        if not self.options['ballistic']:
            self.add_subsystem(name='water_engine',
                               subsys=WaterEngine(num_nodes=nn))

            self.add_subsystem(name='mass_adder',
                               subsys=_MassAdder(num_nodes=nn))

        self.add_subsystem(name='dynamic_pressure',
                           subsys=DynamicPressureComp(num_nodes=nn))

        self.add_subsystem(name='aero',
                           subsys=LiftDragForceComp(num_nodes=nn))

        self.add_subsystem(name='eom',
                           subsys=FlightPathEOM2D(num_nodes=nn))

        self.connect('atmos.rho', 'dynamic_pressure.rho')
        self.connect('dynamic_pressure.q', 'aero.q')

        self.connect('aero.f_drag', 'eom.D')
        self.connect('aero.f_lift', 'eom.L')

        if not self.options['ballistic']:
            self.connect('atmos.pres', 'water_engine.p_a')
            self.connect('water_engine.F', 'eom.T')
            self.connect('mass_adder.m', 'eom.m')

# %% [markdown]
# ## Phases
#
# The flight of the water rocket is split in three distinct phases: propelled ascent, ballistic ascent and ballistic descent.
# If the simplification of no thrust without water were lifted, there would be an extra "air propelled ascent" phase between the propelled ascent and ballistic ascent phases.
#
# **Propelled ascent:** is the flight phase where the rocket still has water inside, and hence it is producing thrust.
# The thrust is given by the water engine model, and fed into the flight dynamic equations.
# It starts at launch and finishes when the water is depleted, i.e. $V_w=0$.
#
# **Ballistic ascent:** is the flight phase where the rocket is ascending ($\gamma>0$) but produces no thrust.
# This phase begins at the end of thepropelled ascent phase and ends at the apogee, defined by $\gamma=0$.
#
# **Descent:** is the phase where the rocket is descending without thrust.
# It begins at the end of the ballistic ascent phase and ends with ground impact, i.e. $h=0$.

# %%
def new_propelled_ascent_phase(transcription):
    propelled_ascent = dm.Phase(ode_class=WaterPropulsionODE,
                                transcription=transcription)

    # All initial states except flight path angle and water volume are fixed
    # Final flight path angle is fixed (we will set it to zero so that the phase ends at apogee)
    # Final water volume is fixed (we will set it to zero so that phase ends when bottle empties)
    propelled_ascent.set_time_options(
        fix_initial=True, duration_bounds=(0.001, 0.5), duration_ref=0.1, units='s')
    propelled_ascent.add_state('r', units='m', rate_source='eom.r_dot',
                               fix_initial=True, fix_final=False, ref=1.0, defect_ref=1.0)
    propelled_ascent.add_state('h', units='m', rate_source='eom.h_dot', targets=['atmos.h'],
                               fix_initial=True, fix_final=False, ref=1.0, defect_ref=1.0)
    propelled_ascent.add_state('gam', units='deg', rate_source='eom.gam_dot', targets=['eom.gam'],
                               fix_initial=False, fix_final=False, lower=0, upper=85.0, ref=90)
    propelled_ascent.add_state('v', units='m/s', rate_source='eom.v_dot', targets=['dynamic_pressure.v', 'eom.v'],
                               fix_initial=True, fix_final=False, ref=100, defect_ref=100)

    propelled_ascent.add_state('p', units='bar', rate_source='water_engine.pdot',
                               targets=['water_engine.p'], fix_initial=True, fix_final=False,
                               lower=1.02)
    propelled_ascent.add_state('V_w', units='L', rate_source='water_engine.Vdot',
                               targets=['water_engine.V_w', 'mass_adder.V_w'],
                               fix_initial=False, fix_final=True, ref=10, defect_ref=10, lower=0)

    propelled_ascent.add_parameter(
        'S', targets=['aero.S'], units='m**2')
    propelled_ascent.add_parameter(
        'm_empty', targets=['mass_adder.m_empty'], units='kg')
    propelled_ascent.add_parameter(
        'V_b', targets=['water_engine.V_b'], units='m**3')

    propelled_ascent.add_timeseries_output('water_engine.F', 'T', units='N')

    return propelled_ascent

# %%
def new_ballistic_ascent_phase(transcription):
    ballistic_ascent = dm.Phase(ode_class=WaterPropulsionODE, transcription=transcription,
                                ode_init_kwargs={'ballistic': True})

    # All initial states are free (they will be  linked to the final stages of propelled_ascent).
    # Final flight path angle is fixed (we will set it to zero so that the phase ends at apogee)
    ballistic_ascent.set_time_options(
        fix_initial=False, initial_bounds=(0.001, 1), duration_bounds=(0.001, 10),
        duration_ref=1, units='s')

    ballistic_ascent.add_state('r', units='m', rate_source='eom.r_dot', fix_initial=False,
                               fix_final=False)
    ballistic_ascent.add_state('h', units='m', rate_source='eom.h_dot', targets=['atmos.h'],
                               fix_initial=False, fix_final=False)
    ballistic_ascent.add_state('gam', units='deg', rate_source='eom.gam_dot', targets=['eom.gam'],
                               fix_initial=False, fix_final=True, upper=89)
    ballistic_ascent.add_state('v', units='m/s', rate_source='eom.v_dot',
                               targets=['dynamic_pressure.v', 'eom.v'], fix_initial=False,
                               fix_final=False)

    ballistic_ascent.add_parameter('S', targets=['aero.S'], units='m**2')
    ballistic_ascent.add_parameter('m_empty', targets=['eom.m'], units='kg')

    return ballistic_ascent

# %%
def new_descent_phase(transcription):
    descent = dm.Phase(ode_class=WaterPropulsionODE, transcription=transcription,
                       ode_init_kwargs={'ballistic': True})

    # All initial states and time are free (they will be linked to the final states of ballistic_ascent).
    # Final altitude is fixed (we will set it to zero so that the phase ends at ground impact)
    descent.set_time_options(initial_bounds=(.5, 100), duration_bounds=(.5, 100),
                             duration_ref=10, units='s')

    descent.add_state('r', units='m', rate_source='eom.r_dot', fix_initial=False, fix_final=False)
    descent.add_state('h', units='m', rate_source='eom.h_dot', targets=['atmos.h'],
                      fix_initial=False, fix_final=True)
    descent.add_state('gam', units='deg', rate_source='eom.gam_dot', targets=['eom.gam'],
                      fix_initial=False, fix_final=False)
    descent.add_state('v', units='m/s', rate_source='eom.v_dot',
                      targets=['dynamic_pressure.v', 'eom.v'], fix_initial=False, fix_final=False)

    descent.add_parameter('S', targets=['aero.S'], units='m**2')
    descent.add_parameter('mass', targets=['eom.m'], units='kg')

    return descent

# %% [markdown]
# ##  Model parameters
#
# The model requires a few constant parameters.
# The values used are shown in the following table.
#
# Values for parameters in the water rocket model
#
# |   Parameter        | Value                | Unit         | Reference                                           |
# |--------------------|----------------------|--------------|-----------------------------------------------------|
# | $C_D$              | 0.3450               | -            | {cite}`BarrioPerotti2009`                           |
# | $S$                | $\pi 106^2/4$        | $mm^2$       | {cite}`BarrioPerotti2009`                           |
# | $k$                | 1.2                  | -            | {cite}`Thorncroft2009` {cite}`Fischer2020` {cite}`Romanelli2013`   |
# | $A_\text{out}$     | $\pi22^2/4$          | $mm^2$       | {cite}`aircommand_nozzle`                                |
# | $V_b$              | 2                    | L            |                                                     |
# | $\rho_w$           | 1000                 | $kg/m^3$     |                                                     |
# | $p_0$              | 6.5                  | bar          |                                                     |
# | $v_0$              | 0.1                  | $m/s$        |                                                     |
# | $h_0$              | 0                    | $m$          |                                                     |
# | $r_0$              | 0                    | $m$          |                                                     |
#
# Values for the bottle volume $V_b$, its cross-sectional area $S$ and the nozzle area $A_\text{out}$ are determined by the soda bottle that makes the rocket primary structure, and thus are not easily modifiable by the designer.
# The polytropic coefficient $k$ is a function of the moist air characteristics inside the rocket.
# The initial speed $v_0$ must be set to a value higher than zero, otherwise the flight dynamic equations become singular.
# This issue arises from the angular dynamics of the rocket not being modelled.
# The drag coefficient $C_D$ is sensitive to the aerodynamic design, but can be optimized by a single discipline analysis.
# The initial pressure $p_0$ should be maximized in order to obtain the maximum range or height for the rocket.
# It is limited by the structural properties of the bottle, which are modifiable by the designer, since the bottle needs to be available commercially.
# Finally, the starting point of the rocket is set to the origin.
#
# ## Putting it all together
#
# The different phases must be combined in a single trajectory, and linked in a sequence.
# Here we also define the design variables.

# %%
def new_water_rocket_trajectory(objective):
    tx_prop = dm.Radau(num_segments=50, order=3, compressed=True)
    tx_bal = dm.Radau(num_segments=10, order=3, compressed=True)
    tx_desc = dm.Radau(num_segments=10, order=3, compressed=True)
    traj = dm.Trajectory()

    # Add phases to trajectory
    propelled_ascent = traj.add_phase('propelled_ascent', new_propelled_ascent_phase(tx_prop))
    ballistic_ascent = traj.add_phase('ballistic_ascent', new_ballistic_ascent_phase(tx_bal))
    descent = traj.add_phase('descent', new_descent_phase(tx_desc))

    # Link phases
    traj.link_phases(phases=['propelled_ascent', 'ballistic_ascent'], vars=['*'])
    traj.link_phases(phases=['ballistic_ascent', 'descent'], vars=['*'])

    # Set objective function
    if objective == 'height':
        ballistic_ascent.add_objective('h', loc='final', ref=-1.0)
    elif objective == 'range':
        descent.add_objective('r', loc='final', ref=-1.0)
    else:
        raise ValueError(f"objective='{objective}' is not defined. Try using 'height' or 'range'")

    # Add design parameters to the trajectory.
    traj.add_parameter('CD',
                       targets={'propelled_ascent': ['aero.CD'],
                                'ballistic_ascent': ['aero.CD'],
                                'descent': ['aero.CD']},
                       val=0.3450, units=None, opt=False)
    traj.add_parameter('CL',
                       targets={'propelled_ascent': ['aero.CL'],
                                'ballistic_ascent': ['aero.CL'],
                                'descent': ['aero.CL']},
                       val=0.0, units=None, opt=False)
    traj.add_parameter('T',
                       targets={'ballistic_ascent': ['eom.T'],
                                'descent': ['eom.T']},
                       val=0.0, units='N', opt=False)
    traj.add_parameter('alpha',
                       targets={'propelled_ascent': ['eom.alpha'],
                                'ballistic_ascent': ['eom.alpha'],
                                'descent': ['eom.alpha']},
                       val=0.0, units='deg', opt=False)

    traj.add_parameter('m_empty', units='kg', val=0.15,
                       targets={'propelled_ascent': 'm_empty',
                                'ballistic_ascent': 'm_empty',
                                'descent': 'mass'},
                       lower=0, upper=1, ref=0.1,
                       opt=True)
    traj.add_parameter('V_b', units='m**3', val=2e-3,
                       targets={'propelled_ascent': 'V_b'},
                       opt=False)

    traj.add_parameter('S', units='m**2', val=np.pi*106e-3**2/4, opt=False)
    traj.add_parameter('A_out', units='m**2', val=np.pi*22e-3**2/4.,
                       targets={'propelled_ascent': ['water_engine.A_out']},
                       opt=False)
    traj.add_parameter('k', units=None, val=1.2, opt=False,
                       targets={'propelled_ascent': ['water_engine.k']})

    return traj, {'propelled_ascent': propelled_ascent,
                  'ballistic_ascent': ballistic_ascent,
                  'descent': descent}

# %% [markdown]
# ## Helper Functions to Access the Results

# %%
def summarize_results(water_rocket_problem):
    p = water_rocket_problem
    Entry = namedtuple('Entry', 'value unit')
    summary = {
        'Launch angle': Entry(p.get_val('traj.propelled_ascent.timeseries.states:gam',  units='deg')[0, 0], 'deg'),
        'Flight angle at end of propulsion': Entry(p.get_val('traj.propelled_ascent.timeseries.states:gam',
                                                   units='deg')[-1, 0], 'deg'),
        'Empty mass': Entry(p.get_val('traj.parameters:m_empty', units='kg')[0], 'kg'),
        'Water volume': Entry(p.get_val('traj.propelled_ascent.timeseries.states:V_w', 'L')[0, 0], 'L'),
        'Maximum range': Entry(p.get_val('traj.descent.timeseries.states:r', units='m')[-1, 0], 'm'),
        'Maximum height': Entry(p.get_val('traj.ballistic_ascent.timeseries.states:h', units='m')[-1, 0], 'm'),
        'Maximum velocity': Entry(p.get_val('traj.propelled_ascent.timeseries.states:v', units='m/s')[-1, 0], 'm/s'),
    }

    return summary

# %%
def plot_propelled_ascent(p, exp_out):
    fig, ax = plt.subplots(5, 1, sharex=True, figsize=(4, 8))
    t_imp = p.get_val('traj.propelled_ascent.time', 's')
    t_exp = exp_out.get_val('traj.propelled_ascent.time', 's')

    ax[0].plot(t_imp, p.get_val('traj.propelled_ascent.timeseries.states:p', 'bar'), 'ro', markerfacecolor='None')
    ax[0].plot(t_exp, exp_out.get_val('traj.propelled_ascent.timeseries.states:p', 'bar'), 'r-')
    ax[0].set_ylabel('p (bar)')
    ax[0].set_ylim(bottom=0)

    ax[1].plot(t_imp, p.get_val('traj.propelled_ascent.timeseries.states:V_w', 'L'), 'ro', markerfacecolor='None')
    ax[1].plot(t_exp, exp_out.get_val('traj.propelled_ascent.timeseries.states:V_w', 'L'), 'r-')
    ax[1].set_ylabel('$V_w$ (L)')
    ax[1].set_ylim(0, p.get_val('traj.parameters:V_b', 'L')[0])

    ax[2].plot(t_imp, p.get_val('traj.propelled_ascent.timeseries.T', 'N'), 'ro', markerfacecolor='None')
    ax[2].plot(t_exp, exp_out.get_val('traj.propelled_ascent.timeseries.T', 'N'), 'r-')
    ax[2].set_ylabel('T (N)')
    ax[2].set_ylim(bottom=0)

    ax[3].plot(t_imp, p.get_val('traj.propelled_ascent.timeseries.states:v', 'm/s'), 'ro', markerfacecolor='None')
    ax[3].plot(t_exp, exp_out.get_val('traj.propelled_ascent.timeseries.states:v', 'm/s'), 'r-')
    ax[3].set_ylabel('v (m/s)')
    ax[3].set_ylim(bottom=0)

    ax[4].plot(t_imp, p.get_val('traj.propelled_ascent.timeseries.states:gam', 'deg'), 'ro', markerfacecolor='None')
    ax[4].plot(t_exp, exp_out.get_val('traj.propelled_ascent.timeseries.states:gam', 'deg'), 'r-')
    ax[4].set_ylabel('$\gamma$ (deg)')
    ax[4].yaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins='auto', steps=[1, 1.5, 3, 4.5, 6, 9, 10]))

    ax[-1].set_xlabel('t (s)')

    fig.tight_layout()

# %%
def plot_states(p, exp_out):
    fig, axes = plt.subplots(nrows=4, ncols=1, figsize=(4, 8), sharex=True)

    states = ['r', 'h', 'v', 'gam']
    units = ['m', 'm', 'm/s', 'deg']
    phases = ['propelled_ascent', 'ballistic_ascent', 'descent']

    time_imp = {'ballistic_ascent': p.get_val('traj.ballistic_ascent.timeseries.time'),
                'propelled_ascent': p.get_val('traj.propelled_ascent.timeseries.time'),
                'descent': p.get_val('traj.descent.timeseries.time')}

    time_exp = {'ballistic_ascent': exp_out.get_val('traj.ballistic_ascent.timeseries.time'),
                'propelled_ascent': exp_out.get_val('traj.propelled_ascent.timeseries.time'),
                'descent': exp_out.get_val('traj.descent.timeseries.time')}

    x_imp = {phase: {state: p.get_val(f"traj.{phase}.timeseries.states:{state}", unit)
                     for state, unit in zip(states, units)
                     }
             for phase in phases
             }

    x_exp = {phase: {state: exp_out.get_val(f"traj.{phase}.timeseries.states:{state}", unit)
                     for state, unit in zip(states, units)
                     }
             for phase in phases
             }

    for i, (state, unit) in enumerate(zip(states, units)):
        axes[i].set_ylabel(f"{state} ({unit})" if state != 'gam' else f'$\gamma$ ({unit})')

        axes[i].plot(time_imp['propelled_ascent'], x_imp['propelled_ascent'][state], 'ro', markerfacecolor='None')
        axes[i].plot(time_imp['ballistic_ascent'], x_imp['ballistic_ascent'][state], 'mo', markerfacecolor='None')
        axes[i].plot(time_imp['descent'], x_imp['descent'][state], 'bo', markerfacecolor='None')
        axes[i].plot(time_exp['propelled_ascent'], x_exp['propelled_ascent'][state], 'r-', label='Propelled Ascent')
        axes[i].plot(time_exp['ballistic_ascent'], x_exp['ballistic_ascent'][state], 'm-', label='Ballistic Ascent')
        axes[i].plot(time_exp['descent'], x_exp['descent'][state], 'b-', label='Descent')

        if state == 'gam':
            axes[i].yaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins='auto', steps=[1, 1.5, 3, 4.5, 6, 9, 10]))
            axes[i].set_yticks(np.arange(-90, 91, 45))

    axes[i].set_xlabel('t (s)')
    axes[0].legend()

    fig.tight_layout()

# %%
def plot_trajectory(p, exp_out):
    fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(6, 8))

    time_imp = {'ballistic_ascent': p.get_val('traj.ballistic_ascent.timeseries.time'),
                'propelled_ascent': p.get_val('traj.propelled_ascent.timeseries.time'),
                'descent': p.get_val('traj.descent.timeseries.time')}

    time_exp = {'ballistic_ascent': exp_out.get_val('traj.ballistic_ascent.timeseries.time'),
                'propelled_ascent': exp_out.get_val('traj.propelled_ascent.timeseries.time'),
                'descent': exp_out.get_val('traj.descent.timeseries.time')}

    r_imp = {'ballistic_ascent': p.get_val('traj.ballistic_ascent.timeseries.states:r'),
             'propelled_ascent': p.get_val('traj.propelled_ascent.timeseries.states:r'),
             'descent': p.get_val('traj.descent.timeseries.states:r')}

    r_exp = {'ballistic_ascent': exp_out.get_val('traj.ballistic_ascent.timeseries.states:r'),
             'propelled_ascent': exp_out.get_val('traj.propelled_ascent.timeseries.states:r'),
             'descent': exp_out.get_val('traj.descent.timeseries.states:r')}

    h_imp = {'ballistic_ascent': p.get_val('traj.ballistic_ascent.timeseries.states:h'),
             'propelled_ascent': p.get_val('traj.propelled_ascent.timeseries.states:h'),
             'descent': p.get_val('traj.descent.timeseries.states:h')}

    h_exp = {'ballistic_ascent': exp_out.get_val('traj.ballistic_ascent.timeseries.states:h'),
             'propelled_ascent': exp_out.get_val('traj.propelled_ascent.timeseries.states:h'),
             'descent': exp_out.get_val('traj.descent.timeseries.states:h')}

    axes.plot(r_imp['propelled_ascent'], h_imp['propelled_ascent'], 'ro', markerfacecolor='None')
    axes.plot(r_imp['ballistic_ascent'], h_imp['ballistic_ascent'], 'mo', markerfacecolor='None')
    axes.plot(r_imp['descent'], h_imp['descent'], 'bo', markerfacecolor='None')

    axes.plot(r_exp['propelled_ascent'], h_exp['propelled_ascent'], 'r-')
    axes.plot(r_exp['ballistic_ascent'], h_exp['ballistic_ascent'], 'm-')
    axes.plot(r_exp['descent'], h_exp['descent'], 'b-')

    axes.set_xlabel('r (m)')
    axes.set_ylabel('h (m)')
    axes.set_aspect('equal', 'box')

    fig.tight_layout()

# %% [markdown]
# ## Optimizing for Height

# %%
from dymos.models.atmosphere import USatm1976Comp
from dymos.examples.aircraft_steady_flight.dynamic_pressure_comp import DynamicPressureComp
from dymos.examples.min_time_climb.aero.lift_drag_force_comp import LiftDragForceComp
from dymos.models.eom.flight_path_eom_2d import FlightPathEOM2D
from dymos.examples.water_rocket.water_engine_comp import _WaterThrust
from dymos.examples.water_rocket.phases import set_sane_initial_guesses
from dymos.examples.water_rocket.water_propulsion_ode import WaterPropulsionODE
import matplotlib.pyplot as plt
import matplotlib as mpl
from collections import namedtuple

p = om.Problem(model=om.Group())

traj, phases = new_water_rocket_trajectory(objective='height')
traj = p.model.add_subsystem('traj', traj)

p.driver = om.pyOptSparseDriver(optimizer='IPOPT')
p.driver.opt_settings['print_level'] = 4
p.driver.opt_settings['max_iter'] = 1000
p.driver.opt_settings['nlp_scaling_method'] = 'gradient-based'
p.driver.declare_coloring()

# Finish Problem Setup
p.model.linear_solver = om.DirectSolver()

p.setup()
set_sane_initial_guesses(p, phases)

p.run_driver()

summary = summarize_results(p)
for key, entry in summary.items():
    print(f'{key}: {entry.value:6.4f} {entry.unit}')

exp_out = traj.simulate(times_per_seg=200)

# NOTE: only the last figure is shown in the generated docs
plot_propelled_ascent(p, exp_out)
plot_trajectory(p, exp_out)
plot_states(p, exp_out)

plt.show()
# Out:
# --- Linkage Report [traj] ---
#     --- propelled_ascent - ballistic_ascent ---
#         time         [final] ==  time         [initial]
#         states:r     [final] ==  states:r     [initial]
#         states:h     [final] ==  states:h     [initial]
#         states:gam   [final] ==  states:gam   [initial]
#         states:v     [final] ==  states:v     [initial]
#     --- ballistic_ascent - descent ---
#         time         [final] ==  time         [initial]
#         states:r     [final] ==  states:r     [initial]
#         states:h     [final] ==  states:h     [initial]
#         states:gam   [final*] ==  states:gam   [initial]
#         states:v     [final] ==  states:v     [initial]
#
# * : This quantity is fixed or is an input.
#
#
# --- Constraint Report [traj] ---
#     --- propelled_ascent ---
#         None
#     --- ballistic_ascent ---
#         None
#     --- descent ---
#         None
#
# Full total jacobian was computed 3 times, taking 1.792480 seconds.
# Total jacobian shape: (1151, 1153)
#
#
# Jacobian shape: (1151, 1153)  ( 0.71% nonzero)
# FWD solves: 21   REV solves: 0
# Total colors vs. total size: 21 vs 1153  (98.2% improvement)
#
# Sparsity computed using tolerance: 1e-25
# Time to compute sparsity: 1.792480 sec.
# Time to compute coloring: 2.035076 sec.
# /Users/rfalck/anaconda3/envs/py39/lib/python3.9/site-packages/pyoptsparse/pyOpt_optimization.py:234: UserWarning: The argument `type=` is deprecated. Use `varType` in the future.
#   warnings.warn("The argument `type=` is deprecated. Use `varType` in the future.")
# List of user-set options:
#
#                                     Name   Value                used
#                         file_print_level = 5                     yes
#                    hessian_approximation = limited-memory        yes
#                            linear_solver = mumps                 yes
#                                 max_iter = 1000                  yes
#                       nlp_scaling_method = gradient-based        yes
#                              output_file = IPOPT.out             yes
#                              print_level = 4                     yes
#                       print_user_options = yes                   yes
#                                       sb = yes                   yes
# Total number of variables............................:     1153
#                      variables with only lower bounds:      300
#                 variables with lower and upper bounds:      157
#                      variables with only upper bounds:       30
# Total number of equality constraints.................:     1150
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
#
# Number of Iterations....: 43
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -5.4144372589916571e+01   -5.4144372589916571e+01
# Dual infeasibility......:   2.8650228856008653e-09    2.8650228856008653e-09
# Constraint violation....:   6.3264732058838121e-11    6.3264732058838121e-11
# Complementarity.........:   1.0000566696406665e-11    1.0000566696406665e-11
# Overall NLP error.......:   2.8650228856008653e-09    2.8650228856008653e-09
#
#
# Number of objective function evaluations             = 45
# Number of objective gradient evaluations             = 44
# Number of equality constraint evaluations            = 45
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 44
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 0
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.481
# Total CPU secs in NLP function evaluations           =      3.060
#
# EXIT: Optimal Solution Found.
#
#
# Optimization Problem -- Optimization using pyOpt_sparse
# ================================================================================
#     Objective Function: _objfunc
#
#     Solution:
# --------------------------------------------------------------------------------
#     Total Time:                    3.6931
#        User Objective Time :       0.1683
#        User Sensitivity Time :     2.0969
#        Interface Time :            0.9546
#        Opt Solver Time:            0.4733
#     Calls to Objective Function :      46
#     Calls to Sens Function :           45
#
#
#    Objectives
#       Index  Name                                                          Value
#           0  traj.phases.ballistic_ascent.indep_states.states:h    -5.414437E+01
#
#    Variables (c - continuous, i - integer, d - discrete)
#       Index  Name                                                       Type      Lower Bound            Value      Upper Bound     Status
#           0  traj.parameters:m_empty_0                                     c     0.000000E+00     1.419491E+00     1.000000E+01
#           1  traj.phases.propelled_ascent.time_extents.t_duration_0        c     1.000000E-02     8.557419E-01     5.000000E+00
#           2  traj.phases.propelled_ascent.indep_states.states:r_0          c    -1.000000E+21     1.221269E-05     1.000000E+21
#           3  traj.phases.propelled_ascent.indep_states.states:r_1          c    -1.000000E+21     5.188040E-05     1.000000E+21
#           4  traj.phases.propelled_ascent.indep_states.states:r_2          c    -1.000000E+21     6.997729E-05     1.000000E+21
#           5  traj.phases.propelled_ascent.indep_states.states:r_3          c    -1.000000E+21     1.217088E-04     1.000000E+21
#           6  traj.phases.propelled_ascent.indep_states.states:r_4          c    -1.000000E+21     2.164692E-04     1.000000E+21
#           7  traj.phases.propelled_ascent.indep_states.states:r_5          c    -1.000000E+21     2.521305E-04     1.000000E+21
#           8  traj.phases.propelled_ascent.indep_states.states:r_6          c    -1.000000E+21     3.440898E-04     1.000000E+21
#           9  traj.phases.propelled_ascent.indep_states.states:r_7          c    -1.000000E+21     4.945646E-04     1.000000E+21
#          10  traj.phases.propelled_ascent.indep_states.states:r_8          c    -1.000000E+21     5.479004E-04     1.000000E+21
#          11  traj.phases.propelled_ascent.indep_states.states:r_9          c    -1.000000E+21     6.803960E-04     1.000000E+21
#          12  traj.phases.propelled_ascent.indep_states.states:r_10         c    -1.000000E+21     8.869338E-04     1.000000E+21
#          13  traj.phases.propelled_ascent.indep_states.states:r_11         c    -1.000000E+21     9.580418E-04     1.000000E+21
#          14  traj.phases.propelled_ascent.indep_states.states:r_12         c    -1.000000E+21     1.131282E-03     1.000000E+21
#          15  traj.phases.propelled_ascent.indep_states.states:r_13         c    -1.000000E+21     1.394143E-03     1.000000E+21
#          16  traj.phases.propelled_ascent.indep_states.states:r_14         c    -1.000000E+21     1.483101E-03     1.000000E+21
#          17  traj.phases.propelled_ascent.indep_states.states:r_15         c    -1.000000E+21     1.697257E-03     1.000000E+21
#          18  traj.phases.propelled_ascent.indep_states.states:r_16         c    -1.000000E+21     2.016670E-03     1.000000E+21
#          19  traj.phases.propelled_ascent.indep_states.states:r_17         c    -1.000000E+21     2.123550E-03     1.000000E+21
#          20  traj.phases.propelled_ascent.indep_states.states:r_18         c    -1.000000E+21     2.378786E-03     1.000000E+21
#          21  traj.phases.propelled_ascent.indep_states.states:r_19         c    -1.000000E+21     2.754975E-03     1.000000E+21
#          22  traj.phases.propelled_ascent.indep_states.states:r_20         c    -1.000000E+21     2.879847E-03     1.000000E+21
#          23  traj.phases.propelled_ascent.indep_states.states:r_21         c    -1.000000E+21     3.176329E-03     1.000000E+21
#          24  traj.phases.propelled_ascent.indep_states.states:r_22         c    -1.000000E+21     3.609530E-03     1.000000E+21
#          25  traj.phases.propelled_ascent.indep_states.states:r_23         c    -1.000000E+21     3.752471E-03     1.000000E+21
#          26  traj.phases.propelled_ascent.indep_states.states:r_24         c    -1.000000E+21     4.090376E-03     1.000000E+21
#          27  traj.phases.propelled_ascent.indep_states.states:r_25         c    -1.000000E+21     4.580842E-03     1.000000E+21
#          28  traj.phases.propelled_ascent.indep_states.states:r_26         c    -1.000000E+21     4.741935E-03     1.000000E+21
#          29  traj.phases.propelled_ascent.indep_states.states:r_27         c    -1.000000E+21     5.121457E-03     1.000000E+21
#          30  traj.phases.propelled_ascent.indep_states.states:r_28         c    -1.000000E+21     5.669467E-03     1.000000E+21
#          31  traj.phases.propelled_ascent.indep_states.states:r_29         c    -1.000000E+21     5.848803E-03     1.000000E+21
#          32  traj.phases.propelled_ascent.indep_states.states:r_30         c    -1.000000E+21     6.270155E-03     1.000000E+21
#          33  traj.phases.propelled_ascent.indep_states.states:r_31         c    -1.000000E+21     6.876016E-03     1.000000E+21
#          34  traj.phases.propelled_ascent.indep_states.states:r_32         c    -1.000000E+21     7.073695E-03     1.000000E+21
#          35  traj.phases.propelled_ascent.indep_states.states:r_33         c    -1.000000E+21     7.537114E-03     1.000000E+21
#          36  traj.phases.propelled_ascent.indep_states.states:r_34         c    -1.000000E+21     8.201167E-03     1.000000E+21
#          37  traj.phases.propelled_ascent.indep_states.states:r_35         c    -1.000000E+21     8.417300E-03     1.000000E+21
#          38  traj.phases.propelled_ascent.indep_states.states:r_36         c    -1.000000E+21     8.923047E-03     1.000000E+21
#          39  traj.phases.propelled_ascent.indep_states.states:r_37         c    -1.000000E+21     9.645666E-03     1.000000E+21
#          40  traj.phases.propelled_ascent.indep_states.states:r_38         c    -1.000000E+21     9.880376E-03     1.000000E+21
#          41  traj.phases.propelled_ascent.indep_states.states:r_39         c    -1.000000E+21     1.042874E-02     1.000000E+21
#          42  traj.phases.propelled_ascent.indep_states.states:r_40         c    -1.000000E+21     1.121033E-02     1.000000E+21
#          43  traj.phases.propelled_ascent.indep_states.states:r_41         c    -1.000000E+21     1.146376E-02     1.000000E+21
#          44  traj.phases.propelled_ascent.indep_states.states:r_42         c    -1.000000E+21     1.205505E-02     1.000000E+21
#          45  traj.phases.propelled_ascent.indep_states.states:r_43         c    -1.000000E+21     1.289608E-02     1.000000E+21
#          46  traj.phases.propelled_ascent.indep_states.states:r_44         c    -1.000000E+21     1.316836E-02     1.000000E+21
#          47  traj.phases.propelled_ascent.indep_states.states:r_45         c    -1.000000E+21     1.380292E-02     1.000000E+21
#          48  traj.phases.propelled_ascent.indep_states.states:r_46         c    -1.000000E+21     1.470387E-02     1.000000E+21
#          49  traj.phases.propelled_ascent.indep_states.states:r_47         c    -1.000000E+21     1.499517E-02     1.000000E+21
#          50  traj.phases.propelled_ascent.indep_states.states:r_48         c    -1.000000E+21     1.567339E-02     1.000000E+21
#          51  traj.phases.propelled_ascent.indep_states.states:r_49         c    -1.000000E+21     1.663481E-02     1.000000E+21
#          52  traj.phases.propelled_ascent.indep_states.states:r_50         c    -1.000000E+21     1.694530E-02     1.000000E+21
#          53  traj.phases.propelled_ascent.indep_states.states:r_51         c    -1.000000E+21     1.766758E-02     1.000000E+21
#          54  traj.phases.propelled_ascent.indep_states.states:r_52         c    -1.000000E+21     1.869004E-02     1.000000E+21
#          55  traj.phases.propelled_ascent.indep_states.states:r_53         c    -1.000000E+21     1.901992E-02     1.000000E+21
#          56  traj.phases.propelled_ascent.indep_states.states:r_54         c    -1.000000E+21     1.978671E-02     1.000000E+21
#          57  traj.phases.propelled_ascent.indep_states.states:r_55         c    -1.000000E+21     2.087085E-02     1.000000E+21
#          58  traj.phases.propelled_ascent.indep_states.states:r_56         c    -1.000000E+21     2.122032E-02     1.000000E+21
#          59  traj.phases.propelled_ascent.indep_states.states:r_57         c    -1.000000E+21     2.203209E-02     1.000000E+21
#          60  traj.phases.propelled_ascent.indep_states.states:r_58         c    -1.000000E+21     2.317861E-02     1.000000E+21
#          61  traj.phases.propelled_ascent.indep_states.states:r_59         c    -1.000000E+21     2.354789E-02     1.000000E+21
#          62  traj.phases.propelled_ascent.indep_states.states:r_60         c    -1.000000E+21     2.440517E-02     1.000000E+21
#          63  traj.phases.propelled_ascent.indep_states.states:r_61         c    -1.000000E+21     2.561480E-02     1.000000E+21
#          64  traj.phases.propelled_ascent.indep_states.states:r_62         c    -1.000000E+21     2.600414E-02     1.000000E+21
#          65  traj.phases.propelled_ascent.indep_states.states:r_63         c    -1.000000E+21     2.690748E-02     1.000000E+21
#          66  traj.phases.propelled_ascent.indep_states.states:r_64         c    -1.000000E+21     2.818102E-02     1.000000E+21
#          67  traj.phases.propelled_ascent.indep_states.states:r_65         c    -1.000000E+21     2.859067E-02     1.000000E+21
#          68  traj.phases.propelled_ascent.indep_states.states:r_66         c    -1.000000E+21     2.954069E-02     1.000000E+21
#          69  traj.phases.propelled_ascent.indep_states.states:r_67         c    -1.000000E+21     3.087901E-02     1.000000E+21
#          70  traj.phases.propelled_ascent.indep_states.states:r_68         c    -1.000000E+21     3.130925E-02     1.000000E+21
#          71  traj.phases.propelled_ascent.indep_states.states:r_69         c    -1.000000E+21     3.230660E-02     1.000000E+21
#          72  traj.phases.propelled_ascent.indep_states.states:r_70         c    -1.000000E+21     3.371062E-02     1.000000E+21
#          73  traj.phases.propelled_ascent.indep_states.states:r_71         c    -1.000000E+21     3.416175E-02     1.000000E+21
#          74  traj.phases.propelled_ascent.indep_states.states:r_72         c    -1.000000E+21     3.520713E-02     1.000000E+21
#          75  traj.phases.propelled_ascent.indep_states.states:r_73         c    -1.000000E+21     3.667786E-02     1.000000E+21
#          76  traj.phases.propelled_ascent.indep_states.states:r_74         c    -1.000000E+21     3.715021E-02     1.000000E+21
#          77  traj.phases.propelled_ascent.indep_states.states:r_75         c    -1.000000E+21     3.824438E-02     1.000000E+21
#          78  traj.phases.propelled_ascent.indep_states.states:r_76         c    -1.000000E+21     3.978288E-02     1.000000E+21
#          79  traj.phases.propelled_ascent.indep_states.states:r_77         c    -1.000000E+21     4.027680E-02     1.000000E+21
#          80  traj.phases.propelled_ascent.indep_states.states:r_78         c    -1.000000E+21     4.142057E-02     1.000000E+21
#          81  traj.phases.propelled_ascent.indep_states.states:r_79         c    -1.000000E+21     4.302801E-02     1.000000E+21
#          82  traj.phases.propelled_ascent.indep_states.states:r_80         c    -1.000000E+21     4.354387E-02     1.000000E+21
#          83  traj.phases.propelled_ascent.indep_states.states:r_81         c    -1.000000E+21     4.473811E-02     1.000000E+21
#          84  traj.phases.propelled_ascent.indep_states.states:r_82         c    -1.000000E+21     4.641574E-02     1.000000E+21
#          85  traj.phases.propelled_ascent.indep_states.states:r_83         c    -1.000000E+21     4.695395E-02     1.000000E+21
#          86  traj.phases.propelled_ascent.indep_states.states:r_84         c    -1.000000E+21     4.819961E-02     1.000000E+21
#          87  traj.phases.propelled_ascent.indep_states.states:r_85         c    -1.000000E+21     4.994877E-02     1.000000E+21
#          88  traj.phases.propelled_ascent.indep_states.states:r_86         c    -1.000000E+21     5.050976E-02     1.000000E+21
#          89  traj.phases.propelled_ascent.indep_states.states:r_87         c    -1.000000E+21     5.180786E-02     1.000000E+21
#          90  traj.phases.propelled_ascent.indep_states.states:r_88         c    -1.000000E+21     5.362999E-02     1.000000E+21
#          91  traj.phases.propelled_ascent.indep_states.states:r_89         c    -1.000000E+21     5.421424E-02     1.000000E+21
#          92  traj.phases.propelled_ascent.indep_states.states:r_90         c    -1.000000E+21     5.556587E-02     1.000000E+21
#          93  traj.phases.propelled_ascent.indep_states.states:r_91         c    -1.000000E+21     5.746253E-02     1.000000E+21
#          94  traj.phases.propelled_ascent.indep_states.states:r_92         c    -1.000000E+21     5.807054E-02     1.000000E+21
#          95  traj.phases.propelled_ascent.indep_states.states:r_93         c    -1.000000E+21     5.947688E-02     1.000000E+21
#          96  traj.phases.propelled_ascent.indep_states.states:r_94         c    -1.000000E+21     6.144977E-02     1.000000E+21
#          97  traj.phases.propelled_ascent.indep_states.states:r_95         c    -1.000000E+21     6.208208E-02     1.000000E+21
#          98  traj.phases.propelled_ascent.indep_states.states:r_96         c    -1.000000E+21     6.354441E-02     1.000000E+21
#          99  traj.phases.propelled_ascent.indep_states.states:r_97         c    -1.000000E+21     6.559535E-02     1.000000E+21
#         100  traj.phases.propelled_ascent.indep_states.states:r_98         c    -1.000000E+21     6.625255E-02     1.000000E+21
#         101  traj.phases.propelled_ascent.indep_states.states:r_99         c    -1.000000E+21     6.777226E-02     1.000000E+21
#         102  traj.phases.propelled_ascent.indep_states.states:r_100        c    -1.000000E+21     6.990322E-02     1.000000E+21
#         103  traj.phases.propelled_ascent.indep_states.states:r_101        c    -1.000000E+21     7.058596E-02     1.000000E+21
#         104  traj.phases.propelled_ascent.indep_states.states:r_102        c    -1.000000E+21     7.216454E-02     1.000000E+21
#         105  traj.phases.propelled_ascent.indep_states.states:r_103        c    -1.000000E+21     7.437765E-02     1.000000E+21
#         106  traj.phases.propelled_ascent.indep_states.states:r_104        c    -1.000000E+21     7.508663E-02     1.000000E+21
#         107  traj.phases.propelled_ascent.indep_states.states:r_105        c    -1.000000E+21     7.672571E-02     1.000000E+21
#         108  traj.phases.propelled_ascent.indep_states.states:r_106        c    -1.000000E+21     7.902331E-02     1.000000E+21
#         109  traj.phases.propelled_ascent.indep_states.states:r_107        c    -1.000000E+21     7.975927E-02     1.000000E+21
#         110  traj.phases.propelled_ascent.indep_states.states:r_108        c    -1.000000E+21     8.146063E-02     1.000000E+21
#         111  traj.phases.propelled_ascent.indep_states.states:r_109        c    -1.000000E+21     8.384525E-02     1.000000E+21
#         112  traj.phases.propelled_ascent.indep_states.states:r_110        c    -1.000000E+21     8.460902E-02     1.000000E+21
#         113  traj.phases.propelled_ascent.indep_states.states:r_111        c    -1.000000E+21     8.637458E-02     1.000000E+21
#         114  traj.phases.propelled_ascent.indep_states.states:r_112        c    -1.000000E+21     8.884899E-02     1.000000E+21
#         115  traj.phases.propelled_ascent.indep_states.states:r_113        c    -1.000000E+21     8.964148E-02     1.000000E+21
#         116  traj.phases.propelled_ascent.indep_states.states:r_114        c    -1.000000E+21     9.147336E-02     1.000000E+21
#         117  traj.phases.propelled_ascent.indep_states.states:r_115        c    -1.000000E+21     9.404059E-02     1.000000E+21
#         118  traj.phases.propelled_ascent.indep_states.states:r_116        c    -1.000000E+21     9.486279E-02     1.000000E+21
#         119  traj.phases.propelled_ascent.indep_states.states:r_117        c    -1.000000E+21     9.676330E-02     1.000000E+21
#         120  traj.phases.propelled_ascent.indep_states.states:r_118        c    -1.000000E+21     9.942668E-02     1.000000E+21
#         121  traj.phases.propelled_ascent.indep_states.states:r_119        c    -1.000000E+21     1.002797E-01     1.000000E+21
#         122  traj.phases.propelled_ascent.indep_states.states:r_120        c    -1.000000E+21     1.022514E-01     1.000000E+21
#         123  traj.phases.propelled_ascent.indep_states.states:r_121        c    -1.000000E+21     1.050146E-01     1.000000E+21
#         124  traj.phases.propelled_ascent.indep_states.states:r_122        c    -1.000000E+21     1.058996E-01     1.000000E+21
#         125  traj.phases.propelled_ascent.indep_states.states:r_123        c    -1.000000E+21     1.079453E-01     1.000000E+21
#         126  traj.phases.propelled_ascent.indep_states.states:r_124        c    -1.000000E+21     1.108124E-01     1.000000E+21
#         127  traj.phases.propelled_ascent.indep_states.states:r_125        c    -1.000000E+21     1.117307E-01     1.000000E+21
#         128  traj.phases.propelled_ascent.indep_states.states:r_126        c    -1.000000E+21     1.138536E-01     1.000000E+21
#         129  traj.phases.propelled_ascent.indep_states.states:r_127        c    -1.000000E+21     1.168292E-01     1.000000E+21
#         130  traj.phases.propelled_ascent.indep_states.states:r_128        c    -1.000000E+21     1.177823E-01     1.000000E+21
#         131  traj.phases.propelled_ascent.indep_states.states:r_129        c    -1.000000E+21     1.199858E-01     1.000000E+21
#         132  traj.phases.propelled_ascent.indep_states.states:r_130        c    -1.000000E+21     1.230749E-01     1.000000E+21
#         133  traj.phases.propelled_ascent.indep_states.states:r_131        c    -1.000000E+21     1.240645E-01     1.000000E+21
#         134  traj.phases.propelled_ascent.indep_states.states:r_132        c    -1.000000E+21     1.263526E-01     1.000000E+21
#         135  traj.phases.propelled_ascent.indep_states.states:r_133        c    -1.000000E+21     1.295609E-01     1.000000E+21
#         136  traj.phases.propelled_ascent.indep_states.states:r_134        c    -1.000000E+21     1.305888E-01     1.000000E+21
#         137  traj.phases.propelled_ascent.indep_states.states:r_135        c    -1.000000E+21     1.329659E-01     1.000000E+21
#         138  traj.phases.propelled_ascent.indep_states.states:r_136        c    -1.000000E+21     1.362998E-01     1.000000E+21
#         139  traj.phases.propelled_ascent.indep_states.states:r_137        c    -1.000000E+21     1.373683E-01     1.000000E+21
#         140  traj.phases.propelled_ascent.indep_states.states:r_138        c    -1.000000E+21     1.398395E-01     1.000000E+21
#         141  traj.phases.propelled_ascent.indep_states.states:r_139        c    -1.000000E+21     1.433064E-01     1.000000E+21
#         142  traj.phases.propelled_ascent.indep_states.states:r_140        c    -1.000000E+21     1.444178E-01     1.000000E+21
#         143  traj.phases.propelled_ascent.indep_states.states:r_141        c    -1.000000E+21     1.469888E-01     1.000000E+21
#         144  traj.phases.propelled_ascent.indep_states.states:r_142        c    -1.000000E+21     1.505972E-01     1.000000E+21
#         145  traj.phases.propelled_ascent.indep_states.states:r_143        c    -1.000000E+21     1.517543E-01     1.000000E+21
#         146  traj.phases.propelled_ascent.indep_states.states:r_144        c    -1.000000E+21     1.544319E-01     1.000000E+21
#         147  traj.phases.propelled_ascent.indep_states.states:r_145        c    -1.000000E+21     1.581916E-01     1.000000E+21
#         148  traj.phases.propelled_ascent.indep_states.states:r_146        c    -1.000000E+21     1.593977E-01     1.000000E+21
#         149  traj.phases.propelled_ascent.indep_states.states:r_147        c    -1.000000E+21     1.621897E-01     1.000000E+21
#         150  traj.phases.propelled_ascent.indep_states.states:r_148        c    -1.000000E+21     1.661124E-01     1.000000E+21
#         151  traj.phases.propelled_ascent.indep_states.states:r_149        c    -1.000000E+21     1.673714E-01     1.000000E+21
#         152  traj.phases.propelled_ascent.indep_states.states:h_0          c    -1.000000E+21     1.358587E-04     1.000000E+21
#         153  traj.phases.propelled_ascent.indep_states.states:h_1          c    -1.000000E+21     5.703084E-04     1.000000E+21
#         154  traj.phases.propelled_ascent.indep_states.states:h_2          c    -1.000000E+21     7.673812E-04     1.000000E+21
#         155  traj.phases.propelled_ascent.indep_states.states:h_3          c    -1.000000E+21     1.326374E-03     1.000000E+21
#         156  traj.phases.propelled_ascent.indep_states.states:h_4          c    -1.000000E+21     2.343546E-03     1.000000E+21
#         157  traj.phases.propelled_ascent.indep_states.states:h_5          c    -1.000000E+21     2.724798E-03     1.000000E+21
#         158  traj.phases.propelled_ascent.indep_states.states:h_6          c    -1.000000E+21     3.705142E-03     1.000000E+21
#         159  traj.phases.propelled_ascent.indep_states.states:h_7          c    -1.000000E+21     5.302833E-03     1.000000E+21
#         160  traj.phases.propelled_ascent.indep_states.states:h_8          c    -1.000000E+21     5.867629E-03     1.000000E+21
#         161  traj.phases.propelled_ascent.indep_states.states:h_9          c    -1.000000E+21     7.267961E-03     1.000000E+21
#         162  traj.phases.propelled_ascent.indep_states.states:h_10         c    -1.000000E+21     9.444519E-03     1.000000E+21
#         163  traj.phases.propelled_ascent.indep_states.states:h_11         c    -1.000000E+21     1.019239E-02     1.000000E+21
#         164  traj.phases.propelled_ascent.indep_states.states:h_12         c    -1.000000E+21     1.201173E-02     1.000000E+21
#         165  traj.phases.propelled_ascent.indep_states.states:h_13         c    -1.000000E+21     1.476601E-02     1.000000E+21
#         166  traj.phases.propelled_ascent.indep_states.states:h_14         c    -1.000000E+21     1.569664E-02     1.000000E+21
#         167  traj.phases.propelled_ascent.indep_states.states:h_15         c    -1.000000E+21     1.793437E-02     1.000000E+21
#         168  traj.phases.propelled_ascent.indep_states.states:h_16         c    -1.000000E+21     2.126573E-02     1.000000E+21
#         169  traj.phases.propelled_ascent.indep_states.states:h_17         c    -1.000000E+21     2.237898E-02     1.000000E+21
#         170  traj.phases.propelled_ascent.indep_states.states:h_18         c    -1.000000E+21     2.503483E-02     1.000000E+21
#         171  traj.phases.propelled_ascent.indep_states.states:h_19         c    -1.000000E+21     2.894310E-02     1.000000E+21
#         172  traj.phases.propelled_ascent.indep_states.states:h_20         c    -1.000000E+21     3.023895E-02     1.000000E+21
#         173  traj.phases.propelled_ascent.indep_states.states:h_21         c    -1.000000E+21     3.331299E-02     1.000000E+21
#         174  traj.phases.propelled_ascent.indep_states.states:h_22         c    -1.000000E+21     3.779848E-02     1.000000E+21
#         175  traj.phases.propelled_ascent.indep_states.states:h_23         c    -1.000000E+21     3.927708E-02     1.000000E+21
#         176  traj.phases.propelled_ascent.indep_states.states:h_24         c    -1.000000E+21     4.276974E-02     1.000000E+21
#         177  traj.phases.propelled_ascent.indep_states.states:h_25         c    -1.000000E+21     4.783321E-02     1.000000E+21
#         178  traj.phases.propelled_ascent.indep_states.states:h_26         c    -1.000000E+21     4.949484E-02     1.000000E+21
#         179  traj.phases.propelled_ascent.indep_states.states:h_27         c    -1.000000E+21     5.340686E-02     1.000000E+21
#         180  traj.phases.propelled_ascent.indep_states.states:h_28         c    -1.000000E+21     5.904953E-02     1.000000E+21
#         181  traj.phases.propelled_ascent.indep_states.states:h_29         c    -1.000000E+21     6.089463E-02     1.000000E+21
#         182  traj.phases.propelled_ascent.indep_states.states:h_30         c    -1.000000E+21     6.522709E-02     1.000000E+21
#         183  traj.phases.propelled_ascent.indep_states.states:h_31         c    -1.000000E+21     7.145066E-02     1.000000E+21
#         184  traj.phases.propelled_ascent.indep_states.states:h_32         c    -1.000000E+21     7.347981E-02     1.000000E+21
#         185  traj.phases.propelled_ascent.indep_states.states:h_33         c    -1.000000E+21     7.823412E-02     1.000000E+21
#         186  traj.phases.propelled_ascent.indep_states.states:h_34         c    -1.000000E+21     8.504071E-02     1.000000E+21
#         187  traj.phases.propelled_ascent.indep_states.states:h_35         c    -1.000000E+21     8.725464E-02     1.000000E+21
#         188  traj.phases.propelled_ascent.indep_states.states:h_36         c    -1.000000E+21     9.243255E-02     1.000000E+21
#         189  traj.phases.propelled_ascent.indep_states.states:h_37         c    -1.000000E+21     9.982478E-02     1.000000E+21
#         190  traj.phases.propelled_ascent.indep_states.states:h_38         c    -1.000000E+21     1.022244E-01     1.000000E+21
#         191  traj.phases.propelled_ascent.indep_states.states:h_39         c    -1.000000E+21     1.078279E-01     1.000000E+21
#         192  traj.phases.propelled_ascent.indep_states.states:h_40         c    -1.000000E+21     1.158089E-01     1.000000E+21
#         193  traj.phases.propelled_ascent.indep_states.states:h_41         c    -1.000000E+21     1.183951E-01     1.000000E+21
#         194  traj.phases.propelled_ascent.indep_states.states:h_42         c    -1.000000E+21     1.244268E-01     1.000000E+21
#         195  traj.phases.propelled_ascent.indep_states.states:h_43         c    -1.000000E+21     1.330000E-01     1.000000E+21
#         196  traj.phases.propelled_ascent.indep_states.states:h_44         c    -1.000000E+21     1.357741E-01     1.000000E+21
#         197  traj.phases.propelled_ascent.indep_states.states:h_45         c    -1.000000E+21     1.422366E-01     1.000000E+21
#         198  traj.phases.propelled_ascent.indep_states.states:h_46         c    -1.000000E+21     1.514061E-01     1.000000E+21
#         199  traj.phases.propelled_ascent.indep_states.states:h_47         c    -1.000000E+21     1.543694E-01     1.000000E+21
#         200  traj.phases.propelled_ascent.indep_states.states:h_48         c    -1.000000E+21     1.612660E-01     1.000000E+21
#         201  traj.phases.propelled_ascent.indep_states.states:h_49         c    -1.000000E+21     1.710363E-01     1.000000E+21
#         202  traj.phases.propelled_ascent.indep_states.states:h_50         c    -1.000000E+21     1.741902E-01     1.000000E+21
#         203  traj.phases.propelled_ascent.indep_states.states:h_51         c    -1.000000E+21     1.815243E-01     1.000000E+21
#         204  traj.phases.propelled_ascent.indep_states.states:h_52         c    -1.000000E+21     1.919005E-01     1.000000E+21
#         205  traj.phases.propelled_ascent.indep_states.states:h_53         c    -1.000000E+21     1.952467E-01     1.000000E+21
#         206  traj.phases.propelled_ascent.indep_states.states:h_54         c    -1.000000E+21     2.030222E-01     1.000000E+21
#         207  traj.phases.propelled_ascent.indep_states.states:h_55         c    -1.000000E+21     2.140099E-01     1.000000E+21
#         208  traj.phases.propelled_ascent.indep_states.states:h_56         c    -1.000000E+21     2.175503E-01     1.000000E+21
#         209  traj.phases.propelled_ascent.indep_states.states:h_57         c    -1.000000E+21     2.257715E-01     1.000000E+21
#         210  traj.phases.propelled_ascent.indep_states.states:h_58         c    -1.000000E+21     2.373768E-01     1.000000E+21
#         211  traj.phases.propelled_ascent.indep_states.states:h_59         c    -1.000000E+21     2.411133E-01     1.000000E+21
#         212  traj.phases.propelled_ascent.indep_states.states:h_60         c    -1.000000E+21     2.497849E-01     1.000000E+21
#         213  traj.phases.propelled_ascent.indep_states.states:h_61         c    -1.000000E+21     2.620146E-01     1.000000E+21
#         214  traj.phases.propelled_ascent.indep_states.states:h_62         c    -1.000000E+21     2.659495E-01     1.000000E+21
#         215  traj.phases.propelled_ascent.indep_states.states:h_63         c    -1.000000E+21     2.750766E-01     1.000000E+21
#         216  traj.phases.propelled_ascent.indep_states.states:h_64         c    -1.000000E+21     2.879380E-01     1.000000E+21
#         217  traj.phases.propelled_ascent.indep_states.states:h_65         c    -1.000000E+21     2.920736E-01     1.000000E+21
#         218  traj.phases.propelled_ascent.indep_states.states:h_66         c    -1.000000E+21     3.016619E-01     1.000000E+21
#         219  traj.phases.propelled_ascent.indep_states.states:h_67         c    -1.000000E+21     3.151630E-01     1.000000E+21
#         220  traj.phases.propelled_ascent.indep_states.states:h_68         c    -1.000000E+21     3.195020E-01     1.000000E+21
#         221  traj.phases.propelled_ascent.indep_states.states:h_69         c    -1.000000E+21     3.295574E-01     1.000000E+21
#         222  traj.phases.propelled_ascent.indep_states.states:h_70         c    -1.000000E+21     3.437070E-01     1.000000E+21
#         223  traj.phases.propelled_ascent.indep_states.states:h_71         c    -1.000000E+21     3.482521E-01     1.000000E+21
#         224  traj.phases.propelled_ascent.indep_states.states:h_72         c    -1.000000E+21     3.587813E-01     1.000000E+21
#         225  traj.phases.propelled_ascent.indep_states.states:h_73         c    -1.000000E+21     3.735887E-01     1.000000E+21
#         226  traj.phases.propelled_ascent.indep_states.states:h_74         c    -1.000000E+21     3.783430E-01     1.000000E+21
#         227  traj.phases.propelled_ascent.indep_states.states:h_75         c    -1.000000E+21     3.893532E-01     1.000000E+21
#         228  traj.phases.propelled_ascent.indep_states.states:h_76         c    -1.000000E+21     4.048287E-01     1.000000E+21
#         229  traj.phases.propelled_ascent.indep_states.states:h_77         c    -1.000000E+21     4.097955E-01     1.000000E+21
#         230  traj.phases.propelled_ascent.indep_states.states:h_78         c    -1.000000E+21     4.212944E-01     1.000000E+21
#         231  traj.phases.propelled_ascent.indep_states.states:h_79         c    -1.000000E+21     4.374489E-01     1.000000E+21
#         232  traj.phases.propelled_ascent.indep_states.states:h_80         c    -1.000000E+21     4.426318E-01     1.000000E+21
#         233  traj.phases.propelled_ascent.indep_states.states:h_81         c    -1.000000E+21     4.546277E-01     1.000000E+21
#         234  traj.phases.propelled_ascent.indep_states.states:h_82         c    -1.000000E+21     4.714732E-01     1.000000E+21
#         235  traj.phases.propelled_ascent.indep_states.states:h_83         c    -1.000000E+21     4.768760E-01     1.000000E+21
#         236  traj.phases.propelled_ascent.indep_states.states:h_84         c    -1.000000E+21     4.893781E-01     1.000000E+21
#         237  traj.phases.propelled_ascent.indep_states.states:h_85         c    -1.000000E+21     5.069274E-01     1.000000E+21
#         238  traj.phases.propelled_ascent.indep_states.states:h_86         c    -1.000000E+21     5.125544E-01     1.000000E+21
#         239  traj.phases.propelled_ascent.indep_states.states:h_87         c    -1.000000E+21     5.255723E-01     1.000000E+21
#         240  traj.phases.propelled_ascent.indep_states.states:h_88         c    -1.000000E+21     5.438395E-01     1.000000E+21
#         241  traj.phases.propelled_ascent.indep_states.states:h_89         c    -1.000000E+21     5.496952E-01     1.000000E+21
#         242  traj.phases.propelled_ascent.indep_states.states:h_90         c    -1.000000E+21     5.632395E-01     1.000000E+21
#         243  traj.phases.propelled_ascent.indep_states.states:h_91         c    -1.000000E+21     5.822395E-01     1.000000E+21
#         244  traj.phases.propelled_ascent.indep_states.states:h_92         c    -1.000000E+21     5.883288E-01     1.000000E+21
#         245  traj.phases.propelled_ascent.indep_states.states:h_93         c    -1.000000E+21     6.024110E-01     1.000000E+21
#         246  traj.phases.propelled_ascent.indep_states.states:h_94         c    -1.000000E+21     6.221602E-01     1.000000E+21
#         247  traj.phases.propelled_ascent.indep_states.states:h_95         c    -1.000000E+21     6.284884E-01     1.000000E+21
#         248  traj.phases.propelled_ascent.indep_states.states:h_96         c    -1.000000E+21     6.431209E-01     1.000000E+21
#         249  traj.phases.propelled_ascent.indep_states.states:h_97         c    -1.000000E+21     6.636370E-01     1.000000E+21
#         250  traj.phases.propelled_ascent.indep_states.states:h_98         c    -1.000000E+21     6.702098E-01     1.000000E+21
#         251  traj.phases.propelled_ascent.indep_states.states:h_99         c    -1.000000E+21     6.854059E-01     1.000000E+21
#         252  traj.phases.propelled_ascent.indep_states.states:h_100        c    -1.000000E+21     7.067082E-01     1.000000E+21
#         253  traj.phases.propelled_ascent.indep_states.states:h_101        c    -1.000000E+21     7.135318E-01     1.000000E+21
#         254  traj.phases.propelled_ascent.indep_states.states:h_102        c    -1.000000E+21     7.293063E-01     1.000000E+21
#         255  traj.phases.propelled_ascent.indep_states.states:h_103        c    -1.000000E+21     7.514155E-01     1.000000E+21
#         256  traj.phases.propelled_ascent.indep_states.states:h_104        c    -1.000000E+21     7.584968E-01     1.000000E+21
#         257  traj.phases.propelled_ascent.indep_states.states:h_105        c    -1.000000E+21     7.748654E-01     1.000000E+21
#         258  traj.phases.propelled_ascent.indep_states.states:h_106        c    -1.000000E+21     7.978043E-01     1.000000E+21
#         259  traj.phases.propelled_ascent.indep_states.states:h_107        c    -1.000000E+21     8.051506E-01     1.000000E+21
#         260  traj.phases.propelled_ascent.indep_states.states:h_108        c    -1.000000E+21     8.221307E-01     1.000000E+21
#         261  traj.phases.propelled_ascent.indep_states.states:h_109        c    -1.000000E+21     8.459241E-01     1.000000E+21
#         262  traj.phases.propelled_ascent.indep_states.states:h_110        c    -1.000000E+21     8.535435E-01     1.000000E+21
#         263  traj.phases.propelled_ascent.indep_states.states:h_111        c    -1.000000E+21     8.711540E-01     1.000000E+21
#         264  traj.phases.propelled_ascent.indep_states.states:h_112        c    -1.000000E+21     8.958289E-01     1.000000E+21
#         265  traj.phases.propelled_ascent.indep_states.states:h_113        c    -1.000000E+21     9.037303E-01     1.000000E+21
#         266  traj.phases.propelled_ascent.indep_states.states:h_114        c    -1.000000E+21     9.219919E-01     1.000000E+21
#         267  traj.phases.propelled_ascent.indep_states.states:h_115        c    -1.000000E+21     9.475781E-01     1.000000E+21
#         268  traj.phases.propelled_ascent.indep_states.states:h_116        c    -1.000000E+21     9.557711E-01     1.000000E+21
#         269  traj.phases.propelled_ascent.indep_states.states:h_117        c    -1.000000E+21     9.747065E-01     1.000000E+21
#         270  traj.phases.propelled_ascent.indep_states.states:h_118        c    -1.000000E+21     1.001237E+00     1.000000E+21
#         271  traj.phases.propelled_ascent.indep_states.states:h_119        c    -1.000000E+21     1.009732E+00     1.000000E+21
#         272  traj.phases.propelled_ascent.indep_states.states:h_120        c    -1.000000E+21     1.029366E+00     1.000000E+21
#         273  traj.phases.propelled_ascent.indep_states.states:h_121        c    -1.000000E+21     1.056877E+00     1.000000E+21
#         274  traj.phases.propelled_ascent.indep_states.states:h_122        c    -1.000000E+21     1.065686E+00     1.000000E+21
#         275  traj.phases.propelled_ascent.indep_states.states:h_123        c    -1.000000E+21     1.086047E+00     1.000000E+21
#         276  traj.phases.propelled_ascent.indep_states.states:h_124        c    -1.000000E+21     1.114578E+00     1.000000E+21
#         277  traj.phases.propelled_ascent.indep_states.states:h_125        c    -1.000000E+21     1.123714E+00     1.000000E+21
#         278  traj.phases.propelled_ascent.indep_states.states:h_126        c    -1.000000E+21     1.144833E+00     1.000000E+21
#         279  traj.phases.propelled_ascent.indep_states.states:h_127        c    -1.000000E+21     1.174428E+00     1.000000E+21
#         280  traj.phases.propelled_ascent.indep_states.states:h_128        c    -1.000000E+21     1.183906E+00     1.000000E+21
#         281  traj.phases.propelled_ascent.indep_states.states:h_129        c    -1.000000E+21     1.205817E+00     1.000000E+21
#         282  traj.phases.propelled_ascent.indep_states.states:h_130        c    -1.000000E+21     1.236526E+00     1.000000E+21
#         283  traj.phases.propelled_ascent.indep_states.states:h_131        c    -1.000000E+21     1.246363E+00     1.000000E+21
#         284  traj.phases.propelled_ascent.indep_states.states:h_132        c    -1.000000E+21     1.269104E+00     1.000000E+21
#         285  traj.phases.propelled_ascent.indep_states.states:h_133        c    -1.000000E+21     1.300985E+00     1.000000E+21
#         286  traj.phases.propelled_ascent.indep_states.states:h_134        c    -1.000000E+21     1.311198E+00     1.000000E+21
#         287  traj.phases.propelled_ascent.indep_states.states:h_135        c    -1.000000E+21     1.334813E+00     1.000000E+21
#         288  traj.phases.propelled_ascent.indep_states.states:h_136        c    -1.000000E+21     1.367928E+00     1.000000E+21
#         289  traj.phases.propelled_ascent.indep_states.states:h_137        c    -1.000000E+21     1.378539E+00     1.000000E+21
#         290  traj.phases.propelled_ascent.indep_states.states:h_138        c    -1.000000E+21     1.403078E+00     1.000000E+21
#         291  traj.phases.propelled_ascent.indep_states.states:h_139        c    -1.000000E+21     1.437500E+00     1.000000E+21
#         292  traj.phases.propelled_ascent.indep_states.states:h_140        c    -1.000000E+21     1.448533E+00     1.000000E+21
#         293  traj.phases.propelled_ascent.indep_states.states:h_141        c    -1.000000E+21     1.474053E+00     1.000000E+21
#         294  traj.phases.propelled_ascent.indep_states.states:h_142        c    -1.000000E+21     1.509865E+00     1.000000E+21
#         295  traj.phases.propelled_ascent.indep_states.states:h_143        c    -1.000000E+21     1.521347E+00     1.000000E+21
#         296  traj.phases.propelled_ascent.indep_states.states:h_144        c    -1.000000E+21     1.547915E+00     1.000000E+21
#         297  traj.phases.propelled_ascent.indep_states.states:h_145        c    -1.000000E+21     1.585215E+00     1.000000E+21
#         298  traj.phases.propelled_ascent.indep_states.states:h_146        c    -1.000000E+21     1.597179E+00     1.000000E+21
#         299  traj.phases.propelled_ascent.indep_states.states:h_147        c    -1.000000E+21     1.624870E+00     1.000000E+21
#         300  traj.phases.propelled_ascent.indep_states.states:h_148        c    -1.000000E+21     1.663772E+00     1.000000E+21
#         301  traj.phases.propelled_ascent.indep_states.states:h_149        c    -1.000000E+21     1.676257E+00     1.000000E+21
#         302  traj.phases.propelled_ascent.indep_states.states:gam_0        c     0.000000E+00     9.444444E-01     9.444444E-01          u
#         303  traj.phases.propelled_ascent.indep_states.states:gam_1        c     0.000000E+00     9.424387E-01     9.444444E-01
#         304  traj.phases.propelled_ascent.indep_states.states:gam_2        c     0.000000E+00     9.417793E-01     9.444444E-01
#         305  traj.phases.propelled_ascent.indep_states.states:gam_3        c     0.000000E+00     9.414614E-01     9.444444E-01
#         306  traj.phases.propelled_ascent.indep_states.states:gam_4        c     0.000000E+00     9.410793E-01     9.444444E-01
#         307  traj.phases.propelled_ascent.indep_states.states:gam_5        c     0.000000E+00     9.406810E-01     9.444444E-01
#         308  traj.phases.propelled_ascent.indep_states.states:gam_6        c     0.000000E+00     9.405727E-01     9.444444E-01
#         309  traj.phases.propelled_ascent.indep_states.states:gam_7        c     0.000000E+00     9.403535E-01     9.444444E-01
# ...
#        1054  traj.phases.descent.collocation_constraint.defects:h                       e   0.000000E+00   -5.849015E-14    0.000000E+00              9.00000E+100
#        1055  traj.phases.descent.collocation_constraint.defects:h                       e   0.000000E+00   -3.313890E-15    0.000000E+00              9.00000E+100
#        1056  traj.phases.descent.collocation_constraint.defects:h                       e   0.000000E+00   -2.071181E-14    0.000000E+00              9.00000E+100
#        1057  traj.phases.descent.collocation_constraint.defects:h                       e   0.000000E+00    2.684251E-14    0.000000E+00              9.00000E+100
#        1058  traj.phases.descent.collocation_constraint.defects:h                       e   0.000000E+00    1.259278E-14    0.000000E+00              9.00000E+100
#        1059  traj.phases.descent.collocation_constraint.defects:h                       e   0.000000E+00   -1.590667E-14    0.000000E+00              9.00000E+100
#        1060  traj.phases.descent.collocation_constraint.defects:h                       e   0.000000E+00   -6.627779E-15    0.000000E+00              9.00000E+100
#        1061  traj.phases.descent.collocation_constraint.defects:h                       e   0.000000E+00   -3.645279E-14    0.000000E+00              9.00000E+100
#        1062  traj.phases.descent.collocation_constraint.defects:h                       e   0.000000E+00   -7.621946E-14    0.000000E+00              9.00000E+100
#        1063  traj.phases.descent.collocation_constraint.defects:h                       e   0.000000E+00   -9.544002E-14    0.000000E+00              9.00000E+100
#        1064  traj.phases.descent.collocation_constraint.defects:h                       e   0.000000E+00   -1.438228E-13    0.000000E+00              9.00000E+100
#        1065  traj.phases.descent.collocation_constraint.defects:h                       e   0.000000E+00   -1.531017E-13    0.000000E+00              9.00000E+100
#        1066  traj.phases.descent.collocation_constraint.defects:h                       e   0.000000E+00   -2.173912E-13    0.000000E+00              9.00000E+100
#        1067  traj.phases.descent.collocation_constraint.defects:h                       e   0.000000E+00   -2.843317E-13    0.000000E+00              9.00000E+100
#        1068  traj.phases.descent.collocation_constraint.defects:h                       e   0.000000E+00   -3.267495E-13    0.000000E+00              9.00000E+100
#        1069  traj.phases.descent.collocation_constraint.defects:h                       e   0.000000E+00   -3.903762E-13    0.000000E+00              9.00000E+100
#        1070  traj.phases.descent.collocation_constraint.defects:h                       e   0.000000E+00   -4.838279E-13    0.000000E+00              9.00000E+100
#        1071  traj.phases.descent.collocation_constraint.defects:h                       e   0.000000E+00   -5.096762E-13    0.000000E+00              9.00000E+100
#        1072  traj.phases.descent.collocation_constraint.defects:h                       e   0.000000E+00   -5.865585E-13    0.000000E+00              9.00000E+100
#        1073  traj.phases.descent.collocation_constraint.defects:h                       e   0.000000E+00   -6.879635E-13    0.000000E+00              9.00000E+100
#        1074  traj.phases.descent.collocation_constraint.defects:h                       e   0.000000E+00   -7.204396E-13    0.000000E+00              9.00000E+100
#        1075  traj.phases.descent.collocation_constraint.defects:h                       e   0.000000E+00   -7.926824E-13    0.000000E+00              9.00000E+100
#        1076  traj.phases.descent.collocation_constraint.defects:h                       e   0.000000E+00   -8.861341E-13    0.000000E+00              9.00000E+100
#        1077  traj.phases.descent.collocation_constraint.defects:h                       e   0.000000E+00   -9.146335E-13    0.000000E+00              9.00000E+100
#        1078  traj.phases.descent.collocation_constraint.defects:h                       e   0.000000E+00   -9.908530E-13    0.000000E+00              9.00000E+100
#        1079  traj.phases.descent.collocation_constraint.defects:h                       e   0.000000E+00   -1.082979E-12    0.000000E+00              9.00000E+100
#        1080  traj.phases.descent.collocation_constraint.defects:gam                     e   0.000000E+00    6.050367E-11    0.000000E+00              9.00000E+100
#        1081  traj.phases.descent.collocation_constraint.defects:gam                     e   0.000000E+00    1.172852E-11    0.000000E+00              9.00000E+100
#        1082  traj.phases.descent.collocation_constraint.defects:gam                     e   0.000000E+00   -9.541351E-12    0.000000E+00              9.00000E+100
#        1083  traj.phases.descent.collocation_constraint.defects:gam                     e   0.000000E+00   -7.250791E-12    0.000000E+00              9.00000E+100
#        1084  traj.phases.descent.collocation_constraint.defects:gam                     e   0.000000E+00   -3.906413E-12    0.000000E+00              9.00000E+100
#        1085  traj.phases.descent.collocation_constraint.defects:gam                     e   0.000000E+00   -1.831918E-12    0.000000E+00              9.00000E+100
#        1086  traj.phases.descent.collocation_constraint.defects:gam                     e   0.000000E+00   -1.609225E-12    0.000000E+00              9.00000E+100
#        1087  traj.phases.descent.collocation_constraint.defects:gam                     e   0.000000E+00   -1.139315E-12    0.000000E+00              9.00000E+100
#        1088  traj.phases.descent.collocation_constraint.defects:gam                     e   0.000000E+00   -8.211819E-13    0.000000E+00              9.00000E+100
#        1089  traj.phases.descent.collocation_constraint.defects:gam                     e   0.000000E+00   -8.039496E-13    0.000000E+00              9.00000E+100
#        1090  traj.phases.descent.collocation_constraint.defects:gam                     e   0.000000E+00   -6.694057E-13    0.000000E+00              9.00000E+100
#        1091  traj.phases.descent.collocation_constraint.defects:gam                     e   0.000000E+00   -5.754569E-13    0.000000E+00              9.00000E+100
#        1092  traj.phases.descent.collocation_constraint.defects:gam                     e   0.000000E+00   -5.356903E-13    0.000000E+00              9.00000E+100
#        1093  traj.phases.descent.collocation_constraint.defects:gam                     e   0.000000E+00   -5.482830E-13    0.000000E+00              9.00000E+100
#        1094  traj.phases.descent.collocation_constraint.defects:gam                     e   0.000000E+00   -4.945980E-13    0.000000E+00              9.00000E+100
#        1095  traj.phases.descent.collocation_constraint.defects:gam                     e   0.000000E+00   -4.694125E-13    0.000000E+00              9.00000E+100
#        1096  traj.phases.descent.collocation_constraint.defects:gam                     e   0.000000E+00   -4.897100E-13    0.000000E+00              9.00000E+100
#        1097  traj.phases.descent.collocation_constraint.defects:gam                     e   0.000000E+00   -4.693296E-13    0.000000E+00              9.00000E+100
#        1098  traj.phases.descent.collocation_constraint.defects:gam                     e   0.000000E+00   -4.683355E-13    0.000000E+00              9.00000E+100
#        1099  traj.phases.descent.collocation_constraint.defects:gam                     e   0.000000E+00   -4.361907E-13    0.000000E+00              9.00000E+100
#        1100  traj.phases.descent.collocation_constraint.defects:gam                     e   0.000000E+00   -4.732234E-13    0.000000E+00              9.00000E+100
#        1101  traj.phases.descent.collocation_constraint.defects:gam                     e   0.000000E+00   -4.608792E-13    0.000000E+00              9.00000E+100
#        1102  traj.phases.descent.collocation_constraint.defects:gam                     e   0.000000E+00   -3.955956E-13    0.000000E+00              9.00000E+100
#        1103  traj.phases.descent.collocation_constraint.defects:gam                     e   0.000000E+00   -3.942700E-13    0.000000E+00              9.00000E+100
#        1104  traj.phases.descent.collocation_constraint.defects:gam                     e   0.000000E+00   -4.013120E-13    0.000000E+00              9.00000E+100
#        1105  traj.phases.descent.collocation_constraint.defects:gam                     e   0.000000E+00   -3.745110E-13    0.000000E+00              9.00000E+100
#        1106  traj.phases.descent.collocation_constraint.defects:gam                     e   0.000000E+00   -3.342472E-13    0.000000E+00              9.00000E+100
#        1107  traj.phases.descent.collocation_constraint.defects:gam                     e   0.000000E+00   -3.932759E-13    0.000000E+00              9.00000E+100
#        1108  traj.phases.descent.collocation_constraint.defects:gam                     e   0.000000E+00   -3.485383E-13    0.000000E+00              9.00000E+100
#        1109  traj.phases.descent.collocation_constraint.defects:gam                     e   0.000000E+00   -3.630366E-13    0.000000E+00              9.00000E+100
#        1110  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    4.650060E-14    0.000000E+00              9.00000E+100
#        1111  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00   -6.031279E-14    0.000000E+00              9.00000E+100
#        1112  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    3.817601E-13    0.000000E+00              9.00000E+100
#        1113  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    4.748804E-13    0.000000E+00              9.00000E+100
#        1114  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    7.413171E-13    0.000000E+00              9.00000E+100
#        1115  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    1.201948E-12    0.000000E+00              9.00000E+100
#        1116  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    1.363666E-12    0.000000E+00              9.00000E+100
#        1117  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    1.781878E-12    0.000000E+00              9.00000E+100
#        1118  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    2.410192E-12    0.000000E+00              9.00000E+100
#        1119  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    2.613002E-12    0.000000E+00              9.00000E+100
#        1120  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    3.090699E-12    0.000000E+00              9.00000E+100
#        1121  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    3.738233E-12    0.000000E+00              9.00000E+100
#        1122  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    3.935741E-12    0.000000E+00              9.00000E+100
#        1123  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    4.370523E-12    0.000000E+00              9.00000E+100
#        1124  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    4.904888E-12    0.000000E+00              9.00000E+100
#        1125  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    5.096431E-12    0.000000E+00              9.00000E+100
#        1126  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    5.417215E-12    0.000000E+00              9.00000E+100
#        1127  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    5.806929E-12    0.000000E+00              9.00000E+100
#        1128  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    5.908002E-12    0.000000E+00              9.00000E+100
#        1129  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    6.130364E-12    0.000000E+00              9.00000E+100
#        1130  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    6.351070E-12    0.000000E+00              9.00000E+100
#        1131  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    6.393322E-12    0.000000E+00              9.00000E+100
#        1132  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    6.507982E-12    0.000000E+00              9.00000E+100
#        1133  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    6.594972E-12    0.000000E+00              9.00000E+100
#        1134  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    6.603422E-12    0.000000E+00              9.00000E+100
#        1135  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    6.609553E-12    0.000000E+00              9.00000E+100
#        1136  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    6.585527E-12    0.000000E+00              9.00000E+100
#        1137  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    6.585941E-12    0.000000E+00              9.00000E+100
#        1138  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    6.518255E-12    0.000000E+00              9.00000E+100
#        1139  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    6.432426E-12    0.000000E+00              9.00000E+100
#        1140  traj.linkages.propelled_ascent:time_final|ballistic_ascent:time_initial    e   0.000000E+00    0.000000E+00    0.000000E+00              9.00000E+100
#        1141  traj.linkages.propelled_ascent:r_final|ballistic_ascent:r_initial          e   0.000000E+00    0.000000E+00    0.000000E+00              9.00000E+100
#        1142  traj.linkages.propelled_ascent:h_final|ballistic_ascent:h_initial          e   0.000000E+00    0.000000E+00    0.000000E+00              9.00000E+100
#        1143  traj.linkages.propelled_ascent:gam_final|ballistic_ascent:gam_initial      e   0.000000E+00    0.000000E+00    0.000000E+00              9.00000E+100
#        1144  traj.linkages.propelled_ascent:v_final|ballistic_ascent:v_initial          e   0.000000E+00    7.105427E-15    0.000000E+00              9.00000E+100
#        1145  traj.linkages.ballistic_ascent:time_final|descent:time_initial             e   0.000000E+00    4.440892E-16    0.000000E+00              9.00000E+100
#        1146  traj.linkages.ballistic_ascent:r_final|descent:r_initial                   e   0.000000E+00    0.000000E+00    0.000000E+00              9.00000E+100
#        1147  traj.linkages.ballistic_ascent:h_final|descent:h_initial                   e   0.000000E+00    0.000000E+00    0.000000E+00              9.00000E+100
#        1148  traj.linkages.ballistic_ascent:gam_final|descent:gam_initial               e   0.000000E+00    8.255463E-27    0.000000E+00              9.00000E+100
#        1149  traj.linkages.ballistic_ascent:v_final|descent:v_initial                   e   0.000000E+00    0.000000E+00    0.000000E+00              9.00000E+100
#
# --------------------------------------------------------------------------------
# Launch angle: 85.0000 deg
# Flight angle at end of propulsion: 84.2411 deg
# Empty mass: 0.1419 kg
# Water volume: 0.8519 L
# Maximum range: 15.7173 m
# Maximum height: 54.1444 m
# Maximum velocity: 47.4431 m/s

# %%
from openmdao.utils.assert_utils import assert_near_equal

# Check results (tolerance is relative unless value is zero)
assert_near_equal(summary['Launch angle'].value, 85, .02)
assert_near_equal(summary['Flight angle at end of propulsion'].value, 85, .02)
assert_near_equal(summary['Empty mass'].value, 0.142, 1e-2)
assert_near_equal(summary['Water volume'].value, 0.852, 1e-2)
assert_near_equal(summary['Maximum range'].value, 15.78, 1e-2)
assert_near_equal(summary['Maximum height'].value, 54.133184, 1e-2)
assert_near_equal(summary['Maximum velocity'].value, 47.4, 1e-2)

# %% [markdown]
# # Optimizing for Range

# %%
p = om.Problem(model=om.Group())

traj, phases = new_water_rocket_trajectory(objective='range')
traj = p.model.add_subsystem('traj', traj)

p.driver = om.pyOptSparseDriver(optimizer='SNOPT')
p.driver.opt_settings['Verify level'] = 3
p.driver.opt_settings['iSumm'] = 6
# p.driver.opt_settings['print_level'] = 5
# p.driver.opt_settings['max_iter'] = 1000
# p.driver.opt_settings['nlp_scaling_method'] = 'gradient-based'
p.driver.declare_coloring(tol=1.0E-12)

# Finish Problem Setup
p.model.linear_solver = om.DirectSolver()

p.setup()
set_sane_initial_guesses(p, phases)

p.run_driver()

summary = summarize_results(p)
for key, entry in summary.items():
    print(f'{key}: {entry.value:6.4f} {entry.unit}')

exp_out = traj.simulate(times_per_seg=200)

# NOTE: only the last figure is shown in the generated docs
plot_propelled_ascent(p, exp_out)
plot_trajectory(p, exp_out)
plot_states(p, exp_out)

plt.show()

# Check results (tolerance is relative unless value is zero)
# Out:
# --- Linkage Report [traj] ---
#     --- propelled_ascent - ballistic_ascent ---
#         time         [final] ==  time         [initial]
#         states:r     [final] ==  states:r     [initial]
#         states:h     [final] ==  states:h     [initial]
#         states:gam   [final] ==  states:gam   [initial]
#         states:v     [final] ==  states:v     [initial]
#     --- ballistic_ascent - descent ---
#         time         [final] ==  time         [initial]
#         states:r     [final] ==  states:r     [initial]
#         states:h     [final] ==  states:h     [initial]
#         states:gam   [final*] ==  states:gam   [initial]
#         states:v     [final] ==  states:v     [initial]
#
# * : This quantity is fixed or is an input.
#
#
# --- Constraint Report [traj] ---
#     --- propelled_ascent ---
#         None
#     --- ballistic_ascent ---
#         None
#     --- descent ---
#         None
# /Users/rfalck/Codes/OpenMDAO.git/openmdao/core/problem.py:1533: DerivativesWarning:The following components requested complex step, but force_alloc_complex has not been set to True, so finite difference was used: ['traj.phases.propelled_ascent.rhs_all.dynamic_pressure', 'traj.phases.descent.rhs_all.dynamic_pressure', 'traj.phases.descent.rhs_all.aero', 'traj.phases.descent.rhs_all.eom', 'traj.phases.ballistic_ascent.rhs_all.eom', 'traj.phases.descent.rhs_all.atmos', 'traj.phases.propelled_ascent.rhs_all.mass_adder', 'traj.phases.propelled_ascent.rhs_all.eom', 'traj.phases.propelled_ascent.rhs_all.water_engine.water_thrust', 'traj.phases.propelled_ascent.rhs_all.water_engine.water_flow_rate', 'traj.phases.propelled_ascent.rhs_all.atmos', 'traj.phases.ballistic_ascent.rhs_all.atmos', 'traj.phases.ballistic_ascent.rhs_all.dynamic_pressure', 'traj.phases.propelled_ascent.rhs_all.water_engine.water_exhaust_speed', 'traj.phases.propelled_ascent.rhs_all.aero', 'traj.phases.ballistic_ascent.rhs_all.aero', 'traj.phases.propelled_ascent.rhs_all.water_engine.pressure_rate']
# To enable complex step, specify 'force_alloc_complex=True' when calling setup on the problem, e.g. 'problem.setup(force_alloc_complex=True)'
# ---------------------------------------------------------------------
# Component: USatm1976Comp 'traj.phases.propelled_ascent.rhs_all.atmos'
# ---------------------------------------------------------------------
# '<output>'  wrt '<variable>' | calc mag.  | check mag. | a(cal-chk) | r(cal-chk)
# --------------------------------------------------------------------------------
#
# 'drhos_dh'  wrt 'h'          | 2.2257e-11 | 2.1713e-11 | 5.4407e-13 | 2.5057e-02 >REL_TOL
# 'pres'      wrt 'h'          | 7.5055e-03 | 7.5055e-03 | 9.8086e-09 | 1.3068e-06 >REL_TOL
# 'rho'       wrt 'h'          | 9.8330e-07 | 9.8330e-07 | 2.4921e-12 | 2.5345e-06 >REL_TOL
# 'sos'       wrt 'h'          | 5.4279e-02 | 5.4279e-02 | 1.5435e-06 | 2.8437e-05 >ABS_TOL >REL_TOL
# 'temp'      wrt 'h'          | 5.0431e-02 | 5.0431e-02 | 5.4071e-07 | 1.0722e-05 >REL_TOL
# 'viscosity' wrt 'h'          | 2.8284e-11 | 2.8284e-11 | 1.8458e-16 | 6.5260e-06 >REL_TOL
# -----------------------------------------------------------------------------------------------------
# Component: _WaterExhaustSpeed 'traj.phases.propelled_ascent.rhs_all.water_engine.water_exhaust_speed'
# -----------------------------------------------------------------------------------------------------
# '<output>' wrt '<variable>' | calc mag.  | check mag. | a(cal-chk) | r(cal-chk)
# -------------------------------------------------------------------------------
#
# 'v_out'    wrt 'p'          | 5.1377e-04 | 5.1377e-04 | 2.6289e-08 | 5.1168e-05 >REL_TOL
# 'v_out'    wrt 'p_a'        | 5.1377e-04 | 5.1376e-04 | 3.0760e-08 | 5.9872e-05 >REL_TOL
# 'v_out'    wrt 'rho_w'      | 1.9961e-01 | 1.9961e-01 | 2.7784e-08 | 1.3919e-07
# ---------------------------------------------------------------------------------------------
# Component: _WaterFlowRate 'traj.phases.propelled_ascent.rhs_all.water_engine.water_flow_rate'
# ---------------------------------------------------------------------------------------------
# '<output>' wrt '<variable>' | calc mag.  | check mag. | a(cal-chk) | r(cal-chk)
# -------------------------------------------------------------------------------
#
# 'Vdot'     wrt 'A_out'      | 3.9922e+02 | 3.9922e+02 | 1.3345e-11 | 3.3428e-14
# 'Vdot'     wrt 'v_out'      | 5.3759e-03 | 5.3759e-03 | 1.1160e-11 | 2.0759e-09
# ------------------------------------------------------------------------------------------
# Component: _PressureRate 'traj.phases.propelled_ascent.rhs_all.water_engine.pressure_rate'
# ------------------------------------------------------------------------------------------
# '<output>' wrt '<variable>' | calc mag.  | check mag. | a(cal-chk) | r(cal-chk)
# -------------------------------------------------------------------------------
#
# 'pdot'     wrt 'V_b'        | 7.8234e+13 | 8.8915e+13 | 1.1086e+13 | 1.2468e-01 >ABS_TOL >REL_TOL
# 'pdot'     wrt 'V_w'        | 7.8234e+13 | 7.0104e+13 | 8.6206e+12 | 1.2297e-01 >ABS_TOL >REL_TOL
# 'pdot'     wrt 'Vdot'       | 7.3485e+10 | 7.3485e+10 | 4.4710e-02 | 6.0842e-13 >ABS_TOL
# 'pdot'     wrt 'k'          | 5.8481e+08 | 5.8481e+08 | 3.3187e-02 | 5.6748e-11 >ABS_TOL
# 'pdot'     wrt 'p'          | 1.6837e+03 | 1.6838e+03 | 1.2019e-01 | 7.1380e-05 >ABS_TOL >REL_TOL
# ----------------------------------------------------------------------------------------
# Component: _WaterThrust 'traj.phases.propelled_ascent.rhs_all.water_engine.water_thrust'
# ----------------------------------------------------------------------------------------
# '<output>' wrt '<variable>' | calc mag.  | check mag. | a(cal-chk) | r(cal-chk)
# -------------------------------------------------------------------------------
#
# 'F'        wrt 'A_out'      | 1.1532e+07 | 1.1532e+07 | 4.3204e-07 | 3.7463e-14
# 'F'        wrt 'rho_w'      | 4.3839e+00 | 4.3839e+00 | 4.2311e-07 | 9.6514e-08
# 'F'        wrt 'v_out'      | 3.0351e+02 | 3.0351e+02 | 5.5809e-06 | 1.8388e-08 >ABS_TOL
# -----------------------------------------------------------------------
# Component: _MassAdder 'traj.phases.propelled_ascent.rhs_all.mass_adder'
# -----------------------------------------------------------------------
# '<output>' wrt '<variable>' | calc mag.  | check mag. | a(cal-chk) | r(cal-chk)
# -------------------------------------------------------------------------------
#
# 'm'        wrt 'V_w'        | 1.4142e+04 | 1.4142e+04 | 5.9489e-09 | 4.2065e-13
# 'm'        wrt 'm_empty'    | 1.4142e+01 | 1.4142e+01 | 8.1010e-09 | 5.7283e-10
# 'm'        wrt 'rho_w'      | 7.3378e-02 | 7.3378e-02 | 5.9546e-09 | 8.1150e-08
# --------------------------------------------------------------------------------------
# Component: DynamicPressureComp 'traj.phases.propelled_ascent.rhs_all.dynamic_pressure'
# --------------------------------------------------------------------------------------
# '<output>' wrt '<variable>' | calc mag.  | check mag. | a(cal-chk) | r(cal-chk)
# -------------------------------------------------------------------------------
#
# 'q'        wrt 'rho'        | 3.1722e+04 | 3.1722e+04 | 3.7205e-06 | 1.1728e-10 >ABS_TOL
# 'q'        wrt 'v'          | 1.0016e+03 | 1.0016e+03 | 7.6222e-06 | 7.6097e-09 >ABS_TOL
# ------------------------------------------------------------------------
# Component: LiftDragForceComp 'traj.phases.propelled_ascent.rhs_all.aero'
# ------------------------------------------------------------------------
# '<output>' wrt '<variable>' | calc mag.  | check mag. | a(cal-chk) | r(cal-chk)
# -------------------------------------------------------------------------------
#
# 'f_drag'   wrt 'CD'         | 3.4269e+02 | 3.4269e+02 | 1.1658e-08 | 3.4018e-11
# 'f_drag'   wrt 'CL'         | 0.0000e+00 | 0.0000e+00 | 0.0000e+00 | nan
# 'f_drag'   wrt 'S'          | 1.3397e+04 | 1.3397e+04 | 1.3343e-08 | 9.9592e-13
# 'f_drag'   wrt 'q'          | 4.3056e-02 | 4.3056e-02 | 1.3603e-08 | 3.1593e-07
# 'f_lift'   wrt 'CD'         | 0.0000e+00 | 0.0000e+00 | 0.0000e+00 | nan
# 'f_lift'   wrt 'CL'         | 3.4269e+02 | 3.4269e+02 | 2.7047e-14 | 7.8924e-17
# 'f_lift'   wrt 'S'          | 0.0000e+00 | 0.0000e+00 | 0.0000e+00 | nan
# 'f_lift'   wrt 'q'          | 0.0000e+00 | 0.0000e+00 | 0.0000e+00 | nan
# ---------------------------------------------------------------------
# Component: FlightPathEOM2D 'traj.phases.propelled_ascent.rhs_all.eom'
# ---------------------------------------------------------------------
# '<output>' wrt '<variable>' | calc mag.  | check mag. | a(cal-chk) | r(cal-chk)
# -------------------------------------------------------------------------------
#
# 'gam_dot'  wrt 'D'          | 0.0000e+00 | 0.0000e+00 | 0.0000e+00 | nan
# 'gam_dot'  wrt 'L'          | 1.1184e+00 | 1.1184e+00 | 1.3063e-09 | 1.1680e-09
# 'gam_dot'  wrt 'T'          | 0.0000e+00 | 0.0000e+00 | 0.0000e+00 | nan
# 'gam_dot'  wrt 'alpha'      | 4.6367e+02 | 4.6367e+02 | 1.3983e-09 | 3.0157e-12
# 'gam_dot'  wrt 'gam'        | 9.8022e+01 | 9.8022e+01 | 8.6331e-06 | 8.8073e-08 >ABS_TOL
# 'gam_dot'  wrt 'm'          | 0.0000e+00 | 0.0000e+00 | 0.0000e+00 | nan
# 'gam_dot'  wrt 'v'          | 1.7031e+02 | 1.7031e+02 | 1.7029e-03 | 9.9987e-06 >ABS_TOL >REL_TOL
# 'h_dot'    wrt 'D'          | 0.0000e+00 | 0.0000e+00 | 0.0000e+00 | nan
# 'h_dot'    wrt 'L'          | 0.0000e+00 | 0.0000e+00 | 0.0000e+00 | nan
# 'h_dot'    wrt 'T'          | 0.0000e+00 | 0.0000e+00 | 0.0000e+00 | nan
# 'h_dot'    wrt 'alpha'      | 0.0000e+00 | 0.0000e+00 | 0.0000e+00 | nan
# 'h_dot'    wrt 'gam'        | 1.4207e+02 | 1.4207e+02 | 4.0289e-04 | 2.8358e-06 >ABS_TOL >REL_TOL
# 'h_dot'    wrt 'm'          | 0.0000e+00 | 0.0000e+00 | 0.0000e+00 | nan
# 'h_dot'    wrt 'v'          | 1.3927e+01 | 1.3927e+01 | 6.7245e-08 | 4.8283e-09
# 'r_dot'    wrt 'D'          | 0.0000e+00 | 0.0000e+00 | 0.0000e+00 | nan
# 'r_dot'    wrt 'L'          | 0.0000e+00 | 0.0000e+00 | 0.0000e+00 | nan
# 'r_dot'    wrt 'T'          | 0.0000e+00 | 0.0000e+00 | 0.0000e+00 | nan
# 'r_dot'    wrt 'alpha'      | 0.0000e+00 | 0.0000e+00 | 0.0000e+00 | nan
# 'r_dot'    wrt 'gam'        | 8.0574e+02 | 8.0574e+02 | 7.0965e-05 | 8.8075e-08 >ABS_TOL
# 'r_dot'    wrt 'm'          | 0.0000e+00 | 0.0000e+00 | 0.0000e+00 | nan
# 'r_dot'    wrt 'v'          | 2.4558e+00 | 2.4558e+00 | 1.1420e-08 | 4.6501e-09
# 'v_dot'    wrt 'D'          | 1.2943e+01 | 1.2943e+01 | 1.3706e-07 | 1.0590e-08
# 'v_dot'    wrt 'L'          | 0.0000e+00 | 0.0000e+00 | 0.0000e+00 | nan
# 'v_dot'    wrt 'T'          | 1.2943e+01 | 1.2943e+01 | 1.4078e-07 | 1.0877e-08
# 'v_dot'    wrt 'alpha'      | 0.0000e+00 | 1.3005e-03 | 1.3005e-03 | 1.0000e+00 >ABS_TOL >REL_TOL
# 'v_dot'    wrt 'gam'        | 2.4083e+01 | 2.4083e+01 | 6.8283e-05 | 2.8353e-06 >ABS_TOL >REL_TOL
# 'v_dot'    wrt 'm'          | 1.0167e+04 | 1.0167e+04 | 6.0313e-02 | 5.9324e-06 >ABS_TOL >REL_TOL
# 'v_dot'    wrt 'v'          | 0.0000e+00 | 0.0000e+00 | 0.0000e+00 | nan
# ---------------------------------------------------------------------
# Component: USatm1976Comp 'traj.phases.ballistic_ascent.rhs_all.atmos'
# ---------------------------------------------------------------------
# '<output>'  wrt '<variable>' | calc mag.  | check mag. | a(cal-chk) | r(cal-chk)
# --------------------------------------------------------------------------------
#
# 'drhos_dh'  wrt 'h'          | 9.9681e-12 | 9.7580e-12 | 2.1161e-13 | 2.1686e-02 >REL_TOL
# 'pres'      wrt 'h'          | 3.3406e-03 | 3.3406e-03 | 4.5195e-09 | 1.3529e-06 >REL_TOL
# 'rho'       wrt 'h'          | 4.3813e-07 | 4.3813e-07 | 1.0623e-12 | 2.4247e-06 >REL_TOL
# 'sos'       wrt 'h'          | 2.4288e-02 | 2.4288e-02 | 6.5082e-07 | 2.6796e-05 >REL_TOL
# 'temp'      wrt 'h'          | 2.2553e-02 | 2.2553e-02 | 2.5706e-07 | 1.1398e-05 >REL_TOL
# 'viscosity' wrt 'h'          | 1.2649e-11 | 1.2649e-11 | 2.2814e-17 | 1.8036e-06 >REL_TOL
# --------------------------------------------------------------------------------------
# Component: DynamicPressureComp 'traj.phases.ballistic_ascent.rhs_all.dynamic_pressure'
# --------------------------------------------------------------------------------------
# '<output>' wrt '<variable>' | calc mag.  | check mag. | a(cal-chk) | r(cal-chk)
# -------------------------------------------------------------------------------
#
# 'q'        wrt 'rho'        | 6.1812e+03 | 6.1812e+03 | 7.4220e-07 | 1.2007e-10
# 'q'        wrt 'v'          | 3.1994e+02 | 3.1994e+02 | 3.1299e-06 | 9.7826e-09 >ABS_TOL
# ------------------------------------------------------------------------
# Component: LiftDragForceComp 'traj.phases.ballistic_ascent.rhs_all.aero'
# ------------------------------------------------------------------------
# '<output>' wrt '<variable>' | calc mag.  | check mag. | a(cal-chk) | r(cal-chk)
# -------------------------------------------------------------------------------
#
# 'f_drag'   wrt 'CD'         | 6.6622e+01 | 6.6622e+01 | 2.1929e-09 | 3.2915e-11
# 'f_drag'   wrt 'CL'         | 0.0000e+00 | 0.0000e+00 | 0.0000e+00 | nan
# 'f_drag'   wrt 'S'          | 2.6046e+03 | 2.6046e+03 | 3.4714e-09 | 1.3328e-12
# 'f_drag'   wrt 'q'          | 1.9255e-02 | 1.9255e-02 | 2.2926e-09 | 1.1906e-07
# 'f_lift'   wrt 'CD'         | 0.0000e+00 | 0.0000e+00 | 0.0000e+00 | nan
# 'f_lift'   wrt 'CL'         | 6.6622e+01 | 6.6622e+01 | 5.3475e-15 | 8.0267e-17
# 'f_lift'   wrt 'S'          | 0.0000e+00 | 0.0000e+00 | 0.0000e+00 | nan
# 'f_lift'   wrt 'q'          | 0.0000e+00 | 0.0000e+00 | 0.0000e+00 | nan
# ---------------------------------------------------------------------
# Component: FlightPathEOM2D 'traj.phases.ballistic_ascent.rhs_all.eom'
# ---------------------------------------------------------------------
# '<output>' wrt '<variable>' | calc mag.  | check mag. | a(cal-chk) | r(cal-chk)
# -------------------------------------------------------------------------------
#
# 'gam_dot'  wrt 'D'          | 0.0000e+00 | 0.0000e+00 | 0.0000e+00 | nan
# 'gam_dot'  wrt 'L'          | 1.2279e+00 | 1.2279e+00 | 6.0719e-11 | 4.9450e-11
# 'gam_dot'  wrt 'T'          | 0.0000e+00 | 0.0000e+00 | 0.0000e+00 | nan
# 'gam_dot'  wrt 'alpha'      | 0.0000e+00 | 0.0000e+00 | 0.0000e+00 | nan
# 'gam_dot'  wrt 'gam'        | 8.9020e-01 | 8.9020e-01 | 7.8581e-07 | 8.8274e-07
# 'gam_dot'  wrt 'm'          | 0.0000e+00 | 0.0000e+00 | 0.0000e+00 | nan
# 'gam_dot'  wrt 'v'          | 5.9947e-02 | 5.9947e-02 | 2.4915e-09 | 4.1562e-08
# 'h_dot'    wrt 'D'          | 0.0000e+00 | 0.0000e+00 | 0.0000e+00 | nan
# 'h_dot'    wrt 'L'          | 0.0000e+00 | 0.0000e+00 | 0.0000e+00 | nan
# 'h_dot'    wrt 'T'          | 0.0000e+00 | 0.0000e+00 | 0.0000e+00 | nan
# 'h_dot'    wrt 'alpha'      | 0.0000e+00 | 0.0000e+00 | 0.0000e+00 | nan
# 'h_dot'    wrt 'gam'        | 1.6376e+02 | 1.6376e+02 | 1.0238e-04 | 6.2519e-07 >ABS_TOL
# 'h_dot'    wrt 'm'          | 0.0000e+00 | 0.0000e+00 | 0.0000e+00 | nan
# 'h_dot'    wrt 'v'          | 4.1670e+00 | 4.1670e+00 | 1.5322e-08 | 3.6770e-09
# 'r_dot'    wrt 'D'          | 0.0000e+00 | 0.0000e+00 | 0.0000e+00 | nan
# 'r_dot'    wrt 'L'          | 0.0000e+00 | 0.0000e+00 | 0.0000e+00 | nan
# 'r_dot'    wrt 'T'          | 0.0000e+00 | 0.0000e+00 | 0.0000e+00 | nan
# 'r_dot'    wrt 'alpha'      | 0.0000e+00 | 0.0000e+00 | 0.0000e+00 | nan
# 'r_dot'    wrt 'gam'        | 2.0476e+02 | 2.0476e+02 | 8.1880e-05 | 3.9989e-07 >ABS_TOL
# 'r_dot'    wrt 'm'          | 0.0000e+00 | 0.0000e+00 | 0.0000e+00 | nan
# 'r_dot'    wrt 'v'          | 4.7578e+00 | 4.7578e+00 | 1.3130e-08 | 2.7597e-09
# 'v_dot'    wrt 'D'          | 4.2164e+01 | 4.2164e+01 | 1.5821e-08 | 3.7523e-10
# 'v_dot'    wrt 'L'          | 0.0000e+00 | 0.0000e+00 | 0.0000e+00 | nan
# 'v_dot'    wrt 'T'          | 4.2164e+01 | 4.2164e+01 | 1.8288e-08 | 4.3375e-10
# 'v_dot'    wrt 'alpha'      | 0.0000e+00 | 0.0000e+00 | 0.0000e+00 | nan
# 'v_dot'    wrt 'gam'        | 4.6658e+01 | 4.6658e+01 | 2.0437e-05 | 4.3802e-07 >ABS_TOL
# 'v_dot'    wrt 'm'          | 1.0215e+03 | 1.0215e+03 | 6.8102e-03 | 6.6667e-06 >ABS_TOL >REL_TOL
# 'v_dot'    wrt 'v'          | 0.0000e+00 | 0.0000e+00 | 0.0000e+00 | nan
# ------------------------------------------------------------
# Component: USatm1976Comp 'traj.phases.descent.rhs_all.atmos'
# ------------------------------------------------------------
# '<output>'  wrt '<variable>' | calc mag.  | check mag. | a(cal-chk) | r(cal-chk)
# --------------------------------------------------------------------------------
#
# 'drhos_dh'  wrt 'h'          | 9.9536e-12 | 9.7103e-12 | 2.4332e-13 | 2.5057e-02 >REL_TOL
# 'pres'      wrt 'h'          | 3.3566e-03 | 3.3566e-03 | 3.9930e-09 | 1.1896e-06 >REL_TOL
# 'rho'       wrt 'h'          | 4.3975e-07 | 4.3975e-07 | 1.1230e-12 | 2.5538e-06 >REL_TOL
# 'sos'       wrt 'h'          | 2.4274e-02 | 2.4274e-02 | 7.8410e-07 | 3.2302e-05 >REL_TOL
# 'temp'      wrt 'h'          | 2.2553e-02 | 2.2553e-02 | 2.5706e-07 | 1.1398e-05 >REL_TOL
# 'viscosity' wrt 'h'          | 1.2649e-11 | 1.2649e-11 | 2.2814e-17 | 1.8036e-06 >REL_TOL
# -----------------------------------------------------------------------------
# Component: DynamicPressureComp 'traj.phases.descent.rhs_all.dynamic_pressure'
# -----------------------------------------------------------------------------
# '<output>' wrt '<variable>' | calc mag.  | check mag. | a(cal-chk) | r(cal-chk)
# -------------------------------------------------------------------------------
#
# 'q'        wrt 'rho'        | 6.2839e+03 | 6.2839e+03 | 6.0332e-07 | 9.6010e-11
# 'q'        wrt 'v'          | 3.2409e+02 | 3.2409e+02 | 3.4230e-06 | 1.0562e-08 >ABS_TOL
# ---------------------------------------------------------------
# Component: LiftDragForceComp 'traj.phases.descent.rhs_all.aero'
# ---------------------------------------------------------------
# '<output>' wrt '<variable>' | calc mag.  | check mag. | a(cal-chk) | r(cal-chk)
# -------------------------------------------------------------------------------
#
# 'f_drag'   wrt 'CD'         | 6.7923e+01 | 6.7923e+01 | 2.0887e-09 | 3.0751e-11
# 'f_drag'   wrt 'CL'         | 0.0000e+00 | 0.0000e+00 | 0.0000e+00 | nan
# 'f_drag'   wrt 'S'          | 2.6554e+03 | 2.6554e+03 | 2.6241e-09 | 9.8822e-13
# 'f_drag'   wrt 'q'          | 1.9255e-02 | 1.9255e-02 | 2.2796e-09 | 1.1839e-07
# 'f_lift'   wrt 'CD'         | 0.0000e+00 | 0.0000e+00 | 0.0000e+00 | nan
# 'f_lift'   wrt 'CL'         | 6.7923e+01 | 6.7923e+01 | 3.4968e-15 | 5.1481e-17
# 'f_lift'   wrt 'S'          | 0.0000e+00 | 0.0000e+00 | 0.0000e+00 | nan
# 'f_lift'   wrt 'q'          | 0.0000e+00 | 0.0000e+00 | 0.0000e+00 | nan
# ------------------------------------------------------------
# Component: FlightPathEOM2D 'traj.phases.descent.rhs_all.eom'
# ------------------------------------------------------------
# '<output>' wrt '<variable>' | calc mag.  | check mag. | a(cal-chk) | r(cal-chk)
# -------------------------------------------------------------------------------
#
# 'gam_dot'  wrt 'D'          | 0.0000e+00 | 0.0000e+00 | 0.0000e+00 | nan
# 'gam_dot'  wrt 'L'          | 1.2117e+00 | 1.2117e+00 | 7.4594e-11 | 6.1560e-11
# 'gam_dot'  wrt 'T'          | 0.0000e+00 | 0.0000e+00 | 0.0000e+00 | nan
# 'gam_dot'  wrt 'alpha'      | 0.0000e+00 | 0.0000e+00 | 0.0000e+00 | nan
# 'gam_dot'  wrt 'gam'        | 5.6295e-01 | 5.6295e-01 | 8.4560e-07 | 1.5021e-06 >REL_TOL
# 'gam_dot'  wrt 'm'          | 0.0000e+00 | 0.0000e+00 | 0.0000e+00 | nan
# 'gam_dot'  wrt 'v'          | 6.0354e-02 | 6.0354e-02 | 2.4256e-09 | 4.0190e-08
# 'h_dot'    wrt 'D'          | 0.0000e+00 | 0.0000e+00 | 0.0000e+00 | nan
# 'h_dot'    wrt 'L'          | 0.0000e+00 | 0.0000e+00 | 0.0000e+00 | nan
# 'h_dot'    wrt 'T'          | 0.0000e+00 | 0.0000e+00 | 0.0000e+00 | nan
# 'h_dot'    wrt 'alpha'      | 0.0000e+00 | 0.0000e+00 | 0.0000e+00 | nan
# 'h_dot'    wrt 'gam'        | 2.2643e+02 | 2.2643e+02 | 6.8475e-05 | 3.0241e-07 >ABS_TOL
# 'h_dot'    wrt 'm'          | 0.0000e+00 | 0.0000e+00 | 0.0000e+00 | nan
# 'h_dot'    wrt 'v'          | 2.7166e+00 | 2.7166e+00 | 1.2801e-08 | 4.7123e-09
# 'r_dot'    wrt 'D'          | 0.0000e+00 | 0.0000e+00 | 0.0000e+00 | nan
# 'r_dot'    wrt 'L'          | 0.0000e+00 | 0.0000e+00 | 0.0000e+00 | nan
# 'r_dot'    wrt 'T'          | 0.0000e+00 | 0.0000e+00 | 0.0000e+00 | nan
# 'r_dot'    wrt 'alpha'      | 0.0000e+00 | 0.0000e+00 | 0.0000e+00 | nan
# 'r_dot'    wrt 'gam'        | 1.3694e+02 | 1.3694e+02 | 1.1321e-04 | 8.2673e-07 >ABS_TOL
# 'r_dot'    wrt 'm'          | 0.0000e+00 | 0.0000e+00 | 0.0000e+00 | nan
# 'r_dot'    wrt 'v'          | 5.7114e+00 | 5.7114e+00 | 1.8927e-08 | 3.3139e-09
# 'v_dot'    wrt 'D'          | 4.2164e+01 | 4.2164e+01 | 1.6102e-08 | 3.8188e-10
# 'v_dot'    wrt 'L'          | 0.0000e+00 | 0.0000e+00 | 0.0000e+00 | nan
# 'v_dot'    wrt 'T'          | 4.2164e+01 | 4.2164e+01 | 1.4160e-08 | 3.3584e-10
# 'v_dot'    wrt 'alpha'      | 0.0000e+00 | 0.0000e+00 | 0.0000e+00 | nan
# 'v_dot'    wrt 'gam'        | 5.6010e+01 | 5.6010e+01 | 1.3316e-05 | 2.3775e-07 >ABS_TOL
# 'v_dot'    wrt 'm'          | 1.0415e+03 | 1.0415e+03 | 6.9432e-03 | 6.6667e-06 >ABS_TOL >REL_TOL
# 'v_dot'    wrt 'v'          | 0.0000e+00 | 0.0000e+00 | 0.0000e+00 | nan
#
# ####################################################################################################
# Sub Jacobian with Largest Relative Error: FlightPathEOM2D 'traj.phases.propelled_ascent.rhs_all.eom'
# ####################################################################################################
# '<output>' wrt '<variable>' | calc mag.  | check mag. | a(cal-chk) | r(cal-chk)
# -------------------------------------------------------------------------------
# 'v_dot'    wrt 'alpha'      | 0.0000e+00 | 1.3005e-03 | 1.3005e-03 | 1.0000e+00
# Full total jacobian was computed 3 times, taking 1.868234 seconds.
# Total jacobian shape: (1151, 1153)
#
#
# Jacobian shape: (1151, 1153)  ( 0.67% nonzero)
# FWD solves: 19   REV solves: 0
# Total colors vs. total size: 19 vs 1153  (98.4% improvement)
#
# Sparsity computed using tolerance: 1e-12
# Time to compute sparsity: 1.868234 sec.
# Time to compute coloring: 2.135180 sec.
#
#  ==============================
#  S N O P T  7.7.1    (Nov 2018)
#  ==============================
#
#  SNMEMB EXIT 100 -- finished successfully
#  SNMEMB INFO 104 -- memory requirements estimated
#
#  ==============================
#  S N O P T  7.7.1    (Nov 2018)
#  ==============================
#
#
#
#  Nonlinear constraints    1150     Linear constraints       0
#  Nonlinear variables      1153     Linear variables         0
#  Jacobian  variables      1153     Objective variables   1153
#  Total constraints        1150     Total variables       1153
#
#
#
#  The user has defined    8841   out of    8841   constraint gradients.
#  The user has defined    1153   out of    1153   objective  gradients.
# /Users/rfalck/anaconda3/envs/py39/lib/python3.9/site-packages/pyoptsparse/pyOpt_optimization.py:234: UserWarning: The argument `type=` is deprecated. Use `varType` in the future.
#   warnings.warn("The argument `type=` is deprecated. Use `varType` in the future.")
#
#  SNOPTC EXIT  50 -- error in the user-supplied functions
#  SNOPTC INFO  52 -- incorrect constraint derivatives
#
#  Problem name                 Optimiza
#  No. of iterations                   0   Objective           -2.0000000000E+01
#  No. of major iterations             0   Linear    obj. term  0.0000000000E+00
#  Penalty parameter           0.000E+00   Nonlinear obj. term -2.0000000000E+01
#  User function calls (total)      1155
#  No. of degenerate steps             0   Percentage                       0.00
#  Max x                     967 1.0E+02   Max pi                      1 0.0E+00
#  Max Primal infeas        2301 9.0E+01   Max Dual infeas          1061 1.0E+00
#  Nonlinear constraint violn    9.0E+01
#
#
#
#  Solution printed on file  18
#
#  Time for MPS input                             0.00 seconds
#  Time for solving problem                       5.19 seconds
#  Time for solution output                       0.00 seconds
#  Time for constraint functions                  5.19 seconds
#  Time for objective function                    0.00 seconds
#
#
# Optimization Problem -- Optimization using pyOpt_sparse
# ================================================================================
#     Objective Function: _objfunc
#
#     Solution:
# --------------------------------------------------------------------------------
#     Total Time:                    5.1953
#        User Objective Time :       4.0764
#        User Sensitivity Time :     0.0607
#        Interface Time :            0.8572
#        Opt Solver Time:            0.2009
#     Calls to Objective Function :    1155
#     Calls to Sens Function :            1
#
#
#    Objectives
#       Index  Name                                                 Value
#           0  traj.phases.descent.indep_states.states:r    -2.000000E+01
#
#    Variables (c - continuous, i - integer, d - discrete)
#       Index  Name                                                       Type      Lower Bound            Value      Upper Bound     Status
#           0  traj.parameters:m_empty_0                                     c     0.000000E+00     1.500000E+00     1.000000E+01
#           1  traj.phases.propelled_ascent.time_extents.t_duration_0        c     1.000000E-02     3.000000E+00     5.000000E+00
#           2  traj.phases.propelled_ascent.indep_states.states:r_0          c    -1.000000E+21     2.130306E-02     1.000000E+21
#           3  traj.phases.propelled_ascent.indep_states.states:r_1          c    -1.000000E+21     5.069694E-02     1.000000E+21
#           4  traj.phases.propelled_ascent.indep_states.states:r_2          c    -1.000000E+21     6.000000E-02     1.000000E+21
#           5  traj.phases.propelled_ascent.indep_states.states:r_3          c    -1.000000E+21     8.130306E-02     1.000000E+21
#           6  traj.phases.propelled_ascent.indep_states.states:r_4          c    -1.000000E+21     1.106969E-01     1.000000E+21
#           7  traj.phases.propelled_ascent.indep_states.states:r_5          c    -1.000000E+21     1.200000E-01     1.000000E+21
#           8  traj.phases.propelled_ascent.indep_states.states:r_6          c    -1.000000E+21     1.413031E-01     1.000000E+21
#           9  traj.phases.propelled_ascent.indep_states.states:r_7          c    -1.000000E+21     1.706969E-01     1.000000E+21
#          10  traj.phases.propelled_ascent.indep_states.states:r_8          c    -1.000000E+21     1.800000E-01     1.000000E+21
#          11  traj.phases.propelled_ascent.indep_states.states:r_9          c    -1.000000E+21     2.013031E-01     1.000000E+21
#          12  traj.phases.propelled_ascent.indep_states.states:r_10         c    -1.000000E+21     2.306969E-01     1.000000E+21
#          13  traj.phases.propelled_ascent.indep_states.states:r_11         c    -1.000000E+21     2.400000E-01     1.000000E+21
#          14  traj.phases.propelled_ascent.indep_states.states:r_12         c    -1.000000E+21     2.613031E-01     1.000000E+21
#          15  traj.phases.propelled_ascent.indep_states.states:r_13         c    -1.000000E+21     2.906969E-01     1.000000E+21
#          16  traj.phases.propelled_ascent.indep_states.states:r_14         c    -1.000000E+21     3.000000E-01     1.000000E+21
#          17  traj.phases.propelled_ascent.indep_states.states:r_15         c    -1.000000E+21     3.213031E-01     1.000000E+21
#          18  traj.phases.propelled_ascent.indep_states.states:r_16         c    -1.000000E+21     3.506969E-01     1.000000E+21
#          19  traj.phases.propelled_ascent.indep_states.states:r_17         c    -1.000000E+21     3.600000E-01     1.000000E+21
#          20  traj.phases.propelled_ascent.indep_states.states:r_18         c    -1.000000E+21     3.813031E-01     1.000000E+21
#          21  traj.phases.propelled_ascent.indep_states.states:r_19         c    -1.000000E+21     4.106969E-01     1.000000E+21
#          22  traj.phases.propelled_ascent.indep_states.states:r_20         c    -1.000000E+21     4.200000E-01     1.000000E+21
#          23  traj.phases.propelled_ascent.indep_states.states:r_21         c    -1.000000E+21     4.413031E-01     1.000000E+21
#          24  traj.phases.propelled_ascent.indep_states.states:r_22         c    -1.000000E+21     4.706969E-01     1.000000E+21
#          25  traj.phases.propelled_ascent.indep_states.states:r_23         c    -1.000000E+21     4.800000E-01     1.000000E+21
#          26  traj.phases.propelled_ascent.indep_states.states:r_24         c    -1.000000E+21     5.013031E-01     1.000000E+21
#          27  traj.phases.propelled_ascent.indep_states.states:r_25         c    -1.000000E+21     5.306969E-01     1.000000E+21
#          28  traj.phases.propelled_ascent.indep_states.states:r_26         c    -1.000000E+21     5.400000E-01     1.000000E+21
#          29  traj.phases.propelled_ascent.indep_states.states:r_27         c    -1.000000E+21     5.613031E-01     1.000000E+21
#          30  traj.phases.propelled_ascent.indep_states.states:r_28         c    -1.000000E+21     5.906969E-01     1.000000E+21
#          31  traj.phases.propelled_ascent.indep_states.states:r_29         c    -1.000000E+21     6.000000E-01     1.000000E+21
#          32  traj.phases.propelled_ascent.indep_states.states:r_30         c    -1.000000E+21     6.213031E-01     1.000000E+21
#          33  traj.phases.propelled_ascent.indep_states.states:r_31         c    -1.000000E+21     6.506969E-01     1.000000E+21
#          34  traj.phases.propelled_ascent.indep_states.states:r_32         c    -1.000000E+21     6.600000E-01     1.000000E+21
#          35  traj.phases.propelled_ascent.indep_states.states:r_33         c    -1.000000E+21     6.813031E-01     1.000000E+21
#          36  traj.phases.propelled_ascent.indep_states.states:r_34         c    -1.000000E+21     7.106969E-01     1.000000E+21
#          37  traj.phases.propelled_ascent.indep_states.states:r_35         c    -1.000000E+21     7.200000E-01     1.000000E+21
#          38  traj.phases.propelled_ascent.indep_states.states:r_36         c    -1.000000E+21     7.413031E-01     1.000000E+21
#          39  traj.phases.propelled_ascent.indep_states.states:r_37         c    -1.000000E+21     7.706969E-01     1.000000E+21
#          40  traj.phases.propelled_ascent.indep_states.states:r_38         c    -1.000000E+21     7.800000E-01     1.000000E+21
#          41  traj.phases.propelled_ascent.indep_states.states:r_39         c    -1.000000E+21     8.013031E-01     1.000000E+21
#          42  traj.phases.propelled_ascent.indep_states.states:r_40         c    -1.000000E+21     8.306969E-01     1.000000E+21
#          43  traj.phases.propelled_ascent.indep_states.states:r_41         c    -1.000000E+21     8.400000E-01     1.000000E+21
#          44  traj.phases.propelled_ascent.indep_states.states:r_42         c    -1.000000E+21     8.613031E-01     1.000000E+21
#          45  traj.phases.propelled_ascent.indep_states.states:r_43         c    -1.000000E+21     8.906969E-01     1.000000E+21
#          46  traj.phases.propelled_ascent.indep_states.states:r_44         c    -1.000000E+21     9.000000E-01     1.000000E+21
#          47  traj.phases.propelled_ascent.indep_states.states:r_45         c    -1.000000E+21     9.213031E-01     1.000000E+21
#          48  traj.phases.propelled_ascent.indep_states.states:r_46         c    -1.000000E+21     9.506969E-01     1.000000E+21
#          49  traj.phases.propelled_ascent.indep_states.states:r_47         c    -1.000000E+21     9.600000E-01     1.000000E+21
#          50  traj.phases.propelled_ascent.indep_states.states:r_48         c    -1.000000E+21     9.813031E-01     1.000000E+21
#          51  traj.phases.propelled_ascent.indep_states.states:r_49         c    -1.000000E+21     1.010697E+00     1.000000E+21
#          52  traj.phases.propelled_ascent.indep_states.states:r_50         c    -1.000000E+21     1.020000E+00     1.000000E+21
#          53  traj.phases.propelled_ascent.indep_states.states:r_51         c    -1.000000E+21     1.041303E+00     1.000000E+21
#          54  traj.phases.propelled_ascent.indep_states.states:r_52         c    -1.000000E+21     1.070697E+00     1.000000E+21
#          55  traj.phases.propelled_ascent.indep_states.states:r_53         c    -1.000000E+21     1.080000E+00     1.000000E+21
#          56  traj.phases.propelled_ascent.indep_states.states:r_54         c    -1.000000E+21     1.101303E+00     1.000000E+21
#          57  traj.phases.propelled_ascent.indep_states.states:r_55         c    -1.000000E+21     1.130697E+00     1.000000E+21
#          58  traj.phases.propelled_ascent.indep_states.states:r_56         c    -1.000000E+21     1.140000E+00     1.000000E+21
#          59  traj.phases.propelled_ascent.indep_states.states:r_57         c    -1.000000E+21     1.161303E+00     1.000000E+21
#          60  traj.phases.propelled_ascent.indep_states.states:r_58         c    -1.000000E+21     1.190697E+00     1.000000E+21
#          61  traj.phases.propelled_ascent.indep_states.states:r_59         c    -1.000000E+21     1.200000E+00     1.000000E+21
#          62  traj.phases.propelled_ascent.indep_states.states:r_60         c    -1.000000E+21     1.221303E+00     1.000000E+21
#          63  traj.phases.propelled_ascent.indep_states.states:r_61         c    -1.000000E+21     1.250697E+00     1.000000E+21
#          64  traj.phases.propelled_ascent.indep_states.states:r_62         c    -1.000000E+21     1.260000E+00     1.000000E+21
#          65  traj.phases.propelled_ascent.indep_states.states:r_63         c    -1.000000E+21     1.281303E+00     1.000000E+21
#          66  traj.phases.propelled_ascent.indep_states.states:r_64         c    -1.000000E+21     1.310697E+00     1.000000E+21
#          67  traj.phases.propelled_ascent.indep_states.states:r_65         c    -1.000000E+21     1.320000E+00     1.000000E+21
#          68  traj.phases.propelled_ascent.indep_states.states:r_66         c    -1.000000E+21     1.341303E+00     1.000000E+21
#          69  traj.phases.propelled_ascent.indep_states.states:r_67         c    -1.000000E+21     1.370697E+00     1.000000E+21
#          70  traj.phases.propelled_ascent.indep_states.states:r_68         c    -1.000000E+21     1.380000E+00     1.000000E+21
#          71  traj.phases.propelled_ascent.indep_states.states:r_69         c    -1.000000E+21     1.401303E+00     1.000000E+21
#          72  traj.phases.propelled_ascent.indep_states.states:r_70         c    -1.000000E+21     1.430697E+00     1.000000E+21
#          73  traj.phases.propelled_ascent.indep_states.states:r_71         c    -1.000000E+21     1.440000E+00     1.000000E+21
#          74  traj.phases.propelled_ascent.indep_states.states:r_72         c    -1.000000E+21     1.461303E+00     1.000000E+21
#          75  traj.phases.propelled_ascent.indep_states.states:r_73         c    -1.000000E+21     1.490697E+00     1.000000E+21
#          76  traj.phases.propelled_ascent.indep_states.states:r_74         c    -1.000000E+21     1.500000E+00     1.000000E+21
#          77  traj.phases.propelled_ascent.indep_states.states:r_75         c    -1.000000E+21     1.521303E+00     1.000000E+21
#          78  traj.phases.propelled_ascent.indep_states.states:r_76         c    -1.000000E+21     1.550697E+00     1.000000E+21
#          79  traj.phases.propelled_ascent.indep_states.states:r_77         c    -1.000000E+21     1.560000E+00     1.000000E+21
#          80  traj.phases.propelled_ascent.indep_states.states:r_78         c    -1.000000E+21     1.581303E+00     1.000000E+21
#          81  traj.phases.propelled_ascent.indep_states.states:r_79         c    -1.000000E+21     1.610697E+00     1.000000E+21
#          82  traj.phases.propelled_ascent.indep_states.states:r_80         c    -1.000000E+21     1.620000E+00     1.000000E+21
#          83  traj.phases.propelled_ascent.indep_states.states:r_81         c    -1.000000E+21     1.641303E+00     1.000000E+21
#          84  traj.phases.propelled_ascent.indep_states.states:r_82         c    -1.000000E+21     1.670697E+00     1.000000E+21
#          85  traj.phases.propelled_ascent.indep_states.states:r_83         c    -1.000000E+21     1.680000E+00     1.000000E+21
#          86  traj.phases.propelled_ascent.indep_states.states:r_84         c    -1.000000E+21     1.701303E+00     1.000000E+21
#          87  traj.phases.propelled_ascent.indep_states.states:r_85         c    -1.000000E+21     1.730697E+00     1.000000E+21
#          88  traj.phases.propelled_ascent.indep_states.states:r_86         c    -1.000000E+21     1.740000E+00     1.000000E+21
#          89  traj.phases.propelled_ascent.indep_states.states:r_87         c    -1.000000E+21     1.761303E+00     1.000000E+21
#          90  traj.phases.propelled_ascent.indep_states.states:r_88         c    -1.000000E+21     1.790697E+00     1.000000E+21
#          91  traj.phases.propelled_ascent.indep_states.states:r_89         c    -1.000000E+21     1.800000E+00     1.000000E+21
#          92  traj.phases.propelled_ascent.indep_states.states:r_90         c    -1.000000E+21     1.821303E+00     1.000000E+21
#          93  traj.phases.propelled_ascent.indep_states.states:r_91         c    -1.000000E+21     1.850697E+00     1.000000E+21
#          94  traj.phases.propelled_ascent.indep_states.states:r_92         c    -1.000000E+21     1.860000E+00     1.000000E+21
#          95  traj.phases.propelled_ascent.indep_states.states:r_93         c    -1.000000E+21     1.881303E+00     1.000000E+21
#          96  traj.phases.propelled_ascent.indep_states.states:r_94         c    -1.000000E+21     1.910697E+00     1.000000E+21
#          97  traj.phases.propelled_ascent.indep_states.states:r_95         c    -1.000000E+21     1.920000E+00     1.000000E+21
#          98  traj.phases.propelled_ascent.indep_states.states:r_96         c    -1.000000E+21     1.941303E+00     1.000000E+21
#          99  traj.phases.propelled_ascent.indep_states.states:r_97         c    -1.000000E+21     1.970697E+00     1.000000E+21
#         100  traj.phases.propelled_ascent.indep_states.states:r_98         c    -1.000000E+21     1.980000E+00     1.000000E+21
#         101  traj.phases.propelled_ascent.indep_states.states:r_99         c    -1.000000E+21     2.001303E+00     1.000000E+21
#         102  traj.phases.propelled_ascent.indep_states.states:r_100        c    -1.000000E+21     2.030697E+00     1.000000E+21
#         103  traj.phases.propelled_ascent.indep_states.states:r_101        c    -1.000000E+21     2.040000E+00     1.000000E+21
#         104  traj.phases.propelled_ascent.indep_states.states:r_102        c    -1.000000E+21     2.061303E+00     1.000000E+21
#         105  traj.phases.propelled_ascent.indep_states.states:r_103        c    -1.000000E+21     2.090697E+00     1.000000E+21
#         106  traj.phases.propelled_ascent.indep_states.states:r_104        c    -1.000000E+21     2.100000E+00     1.000000E+21
#         107  traj.phases.propelled_ascent.indep_states.states:r_105        c    -1.000000E+21     2.121303E+00     1.000000E+21
#         108  traj.phases.propelled_ascent.indep_states.states:r_106        c    -1.000000E+21     2.150697E+00     1.000000E+21
#         109  traj.phases.propelled_ascent.indep_states.states:r_107        c    -1.000000E+21     2.160000E+00     1.000000E+21
#         110  traj.phases.propelled_ascent.indep_states.states:r_108        c    -1.000000E+21     2.181303E+00     1.000000E+21
#         111  traj.phases.propelled_ascent.indep_states.states:r_109        c    -1.000000E+21     2.210697E+00     1.000000E+21
#         112  traj.phases.propelled_ascent.indep_states.states:r_110        c    -1.000000E+21     2.220000E+00     1.000000E+21
#         113  traj.phases.propelled_ascent.indep_states.states:r_111        c    -1.000000E+21     2.241303E+00     1.000000E+21
#         114  traj.phases.propelled_ascent.indep_states.states:r_112        c    -1.000000E+21     2.270697E+00     1.000000E+21
#         115  traj.phases.propelled_ascent.indep_states.states:r_113        c    -1.000000E+21     2.280000E+00     1.000000E+21
#         116  traj.phases.propelled_ascent.indep_states.states:r_114        c    -1.000000E+21     2.301303E+00     1.000000E+21
#         117  traj.phases.propelled_ascent.indep_states.states:r_115        c    -1.000000E+21     2.330697E+00     1.000000E+21
#         118  traj.phases.propelled_ascent.indep_states.states:r_116        c    -1.000000E+21     2.340000E+00     1.000000E+21
#         119  traj.phases.propelled_ascent.indep_states.states:r_117        c    -1.000000E+21     2.361303E+00     1.000000E+21
#         120  traj.phases.propelled_ascent.indep_states.states:r_118        c    -1.000000E+21     2.390697E+00     1.000000E+21
#         121  traj.phases.propelled_ascent.indep_states.states:r_119        c    -1.000000E+21     2.400000E+00     1.000000E+21
#         122  traj.phases.propelled_ascent.indep_states.states:r_120        c    -1.000000E+21     2.421303E+00     1.000000E+21
#         123  traj.phases.propelled_ascent.indep_states.states:r_121        c    -1.000000E+21     2.450697E+00     1.000000E+21
#         124  traj.phases.propelled_ascent.indep_states.states:r_122        c    -1.000000E+21     2.460000E+00     1.000000E+21
#         125  traj.phases.propelled_ascent.indep_states.states:r_123        c    -1.000000E+21     2.481303E+00     1.000000E+21
#         126  traj.phases.propelled_ascent.indep_states.states:r_124        c    -1.000000E+21     2.510697E+00     1.000000E+21
#         127  traj.phases.propelled_ascent.indep_states.states:r_125        c    -1.000000E+21     2.520000E+00     1.000000E+21
#         128  traj.phases.propelled_ascent.indep_states.states:r_126        c    -1.000000E+21     2.541303E+00     1.000000E+21
#         129  traj.phases.propelled_ascent.indep_states.states:r_127        c    -1.000000E+21     2.570697E+00     1.000000E+21
#         130  traj.phases.propelled_ascent.indep_states.states:r_128        c    -1.000000E+21     2.580000E+00     1.000000E+21
#         131  traj.phases.propelled_ascent.indep_states.states:r_129        c    -1.000000E+21     2.601303E+00     1.000000E+21
#         132  traj.phases.propelled_ascent.indep_states.states:r_130        c    -1.000000E+21     2.630697E+00     1.000000E+21
#         133  traj.phases.propelled_ascent.indep_states.states:r_131        c    -1.000000E+21     2.640000E+00     1.000000E+21
#         134  traj.phases.propelled_ascent.indep_states.states:r_132        c    -1.000000E+21     2.661303E+00     1.000000E+21
#         135  traj.phases.propelled_ascent.indep_states.states:r_133        c    -1.000000E+21     2.690697E+00     1.000000E+21
#         136  traj.phases.propelled_ascent.indep_states.states:r_134        c    -1.000000E+21     2.700000E+00     1.000000E+21
#         137  traj.phases.propelled_ascent.indep_states.states:r_135        c    -1.000000E+21     2.721303E+00     1.000000E+21
#         138  traj.phases.propelled_ascent.indep_states.states:r_136        c    -1.000000E+21     2.750697E+00     1.000000E+21
#         139  traj.phases.propelled_ascent.indep_states.states:r_137        c    -1.000000E+21     2.760000E+00     1.000000E+21
#         140  traj.phases.propelled_ascent.indep_states.states:r_138        c    -1.000000E+21     2.781303E+00     1.000000E+21
#         141  traj.phases.propelled_ascent.indep_states.states:r_139        c    -1.000000E+21     2.810697E+00     1.000000E+21
#         142  traj.phases.propelled_ascent.indep_states.states:r_140        c    -1.000000E+21     2.820000E+00     1.000000E+21
#         143  traj.phases.propelled_ascent.indep_states.states:r_141        c    -1.000000E+21     2.841303E+00     1.000000E+21
#         144  traj.phases.propelled_ascent.indep_states.states:r_142        c    -1.000000E+21     2.870697E+00     1.000000E+21
#         145  traj.phases.propelled_ascent.indep_states.states:r_143        c    -1.000000E+21     2.880000E+00     1.000000E+21
#         146  traj.phases.propelled_ascent.indep_states.states:r_144        c    -1.000000E+21     2.901303E+00     1.000000E+21
#         147  traj.phases.propelled_ascent.indep_states.states:r_145        c    -1.000000E+21     2.930697E+00     1.000000E+21
#         148  traj.phases.propelled_ascent.indep_states.states:r_146        c    -1.000000E+21     2.940000E+00     1.000000E+21
#         149  traj.phases.propelled_ascent.indep_states.states:r_147        c    -1.000000E+21     2.961303E+00     1.000000E+21
#         150  traj.phases.propelled_ascent.indep_states.states:r_148        c    -1.000000E+21     2.990697E+00     1.000000E+21
#         151  traj.phases.propelled_ascent.indep_states.states:r_149        c    -1.000000E+21     3.000000E+00     1.000000E+21
#         152  traj.phases.propelled_ascent.indep_states.states:h_0          c    -1.000000E+21     7.101021E-02     1.000000E+21
#         153  traj.phases.propelled_ascent.indep_states.states:h_1          c    -1.000000E+21     1.689898E-01     1.000000E+21
#         154  traj.phases.propelled_ascent.indep_states.states:h_2          c    -1.000000E+21     2.000000E-01     1.000000E+21
#         155  traj.phases.propelled_ascent.indep_states.states:h_3          c    -1.000000E+21     2.710102E-01     1.000000E+21
#         156  traj.phases.propelled_ascent.indep_states.states:h_4          c    -1.000000E+21     3.689898E-01     1.000000E+21
#         157  traj.phases.propelled_ascent.indep_states.states:h_5          c    -1.000000E+21     4.000000E-01     1.000000E+21
#         158  traj.phases.propelled_ascent.indep_states.states:h_6          c    -1.000000E+21     4.710102E-01     1.000000E+21
#         159  traj.phases.propelled_ascent.indep_states.states:h_7          c    -1.000000E+21     5.689898E-01     1.000000E+21
#         160  traj.phases.propelled_ascent.indep_states.states:h_8          c    -1.000000E+21     6.000000E-01     1.000000E+21
#         161  traj.phases.propelled_ascent.indep_states.states:h_9          c    -1.000000E+21     6.710102E-01     1.000000E+21
#         162  traj.phases.propelled_ascent.indep_states.states:h_10         c    -1.000000E+21     7.689898E-01     1.000000E+21
#         163  traj.phases.propelled_ascent.indep_states.states:h_11         c    -1.000000E+21     8.000000E-01     1.000000E+21
#         164  traj.phases.propelled_ascent.indep_states.states:h_12         c    -1.000000E+21     8.710102E-01     1.000000E+21
#         165  traj.phases.propelled_ascent.indep_states.states:h_13         c    -1.000000E+21     9.689898E-01     1.000000E+21
#         166  traj.phases.propelled_ascent.indep_states.states:h_14         c    -1.000000E+21     1.000000E+00     1.000000E+21
#         167  traj.phases.propelled_ascent.indep_states.states:h_15         c    -1.000000E+21     1.071010E+00     1.000000E+21
# ...
#        1054  traj.phases.descent.collocation_constraint.defects:h                       e   0.000000E+00    8.501264E-01    0.000000E+00         E    9.00000E+100
#        1055  traj.phases.descent.collocation_constraint.defects:h                       e   0.000000E+00    1.476758E+00    0.000000E+00         E    9.00000E+100
#        1056  traj.phases.descent.collocation_constraint.defects:h                       e   0.000000E+00    1.690083E+00    0.000000E+00         E    9.00000E+100
#        1057  traj.phases.descent.collocation_constraint.defects:h                       e   0.000000E+00    2.205370E+00    0.000000E+00         E    9.00000E+100
#        1058  traj.phases.descent.collocation_constraint.defects:h                       e   0.000000E+00    2.976680E+00    0.000000E+00         E    9.00000E+100
#        1059  traj.phases.descent.collocation_constraint.defects:h                       e   0.000000E+00    3.235126E+00    0.000000E+00         E    9.00000E+100
#        1060  traj.phases.descent.collocation_constraint.defects:h                       e   0.000000E+00    3.852418E+00    0.000000E+00         E    9.00000E+100
#        1061  traj.phases.descent.collocation_constraint.defects:h                       e   0.000000E+00    4.761200E+00    0.000000E+00         E    9.00000E+100
#        1062  traj.phases.descent.collocation_constraint.defects:h                       e   0.000000E+00    5.062306E+00    0.000000E+00         E    9.00000E+100
#        1063  traj.phases.descent.collocation_constraint.defects:h                       e   0.000000E+00    5.775635E+00    0.000000E+00         E    9.00000E+100
#        1064  traj.phases.descent.collocation_constraint.defects:h                       e   0.000000E+00    6.812919E+00    0.000000E+00         E    9.00000E+100
#        1065  traj.phases.descent.collocation_constraint.defects:h                       e   0.000000E+00    7.153669E+00    0.000000E+00         E    9.00000E+100
#        1066  traj.phases.descent.collocation_constraint.defects:h                       e   0.000000E+00    7.955816E+00    0.000000E+00         E    9.00000E+100
#        1067  traj.phases.descent.collocation_constraint.defects:h                       e   0.000000E+00    9.110939E+00    0.000000E+00         E    9.00000E+100
#        1068  traj.phases.descent.collocation_constraint.defects:h                       e   0.000000E+00    9.487791E+00    0.000000E+00         E    9.00000E+100
#        1069  traj.phases.descent.collocation_constraint.defects:h                       e   0.000000E+00    1.037035E+01    0.000000E+00         E    9.00000E+100
#        1070  traj.phases.descent.collocation_constraint.defects:h                       e   0.000000E+00    1.163105E+01    0.000000E+00         E    9.00000E+100
#        1071  traj.phases.descent.collocation_constraint.defects:h                       e   0.000000E+00    1.203997E+01    0.000000E+00         E    9.00000E+100
#        1072  traj.phases.descent.collocation_constraint.defects:h                       e   0.000000E+00    1.299341E+01    0.000000E+00         E    9.00000E+100
#        1073  traj.phases.descent.collocation_constraint.defects:h                       e   0.000000E+00    1.434593E+01    0.000000E+00         E    9.00000E+100
#        1074  traj.phases.descent.collocation_constraint.defects:h                       e   0.000000E+00    1.478242E+01    0.000000E+00         E    9.00000E+100
#        1075  traj.phases.descent.collocation_constraint.defects:h                       e   0.000000E+00    1.579620E+01    0.000000E+00         E    9.00000E+100
#        1076  traj.phases.descent.collocation_constraint.defects:h                       e   0.000000E+00    1.722542E+01    0.000000E+00         E    9.00000E+100
#        1077  traj.phases.descent.collocation_constraint.defects:h                       e   0.000000E+00    1.768455E+01    0.000000E+00         E    9.00000E+100
#        1078  traj.phases.descent.collocation_constraint.defects:h                       e   0.000000E+00    1.874717E+01    0.000000E+00         E    9.00000E+100
#        1079  traj.phases.descent.collocation_constraint.defects:h                       e   0.000000E+00    2.023672E+01    0.000000E+00         E    9.00000E+100
#        1080  traj.phases.descent.collocation_constraint.defects:gam                     e   0.000000E+00    1.179699E+01    0.000000E+00         E    9.00000E+100
#        1081  traj.phases.descent.collocation_constraint.defects:gam                     e   0.000000E+00    1.086055E+01    0.000000E+00         E    9.00000E+100
#        1082  traj.phases.descent.collocation_constraint.defects:gam                     e   0.000000E+00    9.739901E+00    0.000000E+00         E    9.00000E+100
#        1083  traj.phases.descent.collocation_constraint.defects:gam                     e   0.000000E+00    9.419741E+00    0.000000E+00         E    9.00000E+100
#        1084  traj.phases.descent.collocation_constraint.defects:gam                     e   0.000000E+00    8.739303E+00    0.000000E+00         E    9.00000E+100
#        1085  traj.phases.descent.collocation_constraint.defects:gam                     e   0.000000E+00    7.903312E+00    0.000000E+00         E    9.00000E+100
#        1086  traj.phases.descent.collocation_constraint.defects:gam                     e   0.000000E+00    7.660035E+00    0.000000E+00         E    9.00000E+100
#        1087  traj.phases.descent.collocation_constraint.defects:gam                     e   0.000000E+00    7.136330E+00    0.000000E+00         E    9.00000E+100
#        1088  traj.phases.descent.collocation_constraint.defects:gam                     e   0.000000E+00    6.480325E+00    0.000000E+00         E    9.00000E+100
#        1089  traj.phases.descent.collocation_constraint.defects:gam                     e   0.000000E+00    6.286795E+00    0.000000E+00         E    9.00000E+100
#        1090  traj.phases.descent.collocation_constraint.defects:gam                     e   0.000000E+00    5.866127E+00    0.000000E+00         E    9.00000E+100
#        1091  traj.phases.descent.collocation_constraint.defects:gam                     e   0.000000E+00    5.331362E+00    0.000000E+00         E    9.00000E+100
#        1092  traj.phases.descent.collocation_constraint.defects:gam                     e   0.000000E+00    5.171935E+00    0.000000E+00         E    9.00000E+100
#        1093  traj.phases.descent.collocation_constraint.defects:gam                     e   0.000000E+00    4.822789E+00    0.000000E+00         E    9.00000E+100
#        1094  traj.phases.descent.collocation_constraint.defects:gam                     e   0.000000E+00    4.373816E+00    0.000000E+00         E    9.00000E+100
#        1095  traj.phases.descent.collocation_constraint.defects:gam                     e   0.000000E+00    4.238864E+00    0.000000E+00         E    9.00000E+100
#        1096  traj.phases.descent.collocation_constraint.defects:gam                     e   0.000000E+00    3.941568E+00    0.000000E+00         E    9.00000E+100
#        1097  traj.phases.descent.collocation_constraint.defects:gam                     e   0.000000E+00    3.555786E+00    0.000000E+00         E    9.00000E+100
#        1098  traj.phases.descent.collocation_constraint.defects:gam                     e   0.000000E+00    3.439073E+00    0.000000E+00         E    9.00000E+100
#        1099  traj.phases.descent.collocation_constraint.defects:gam                     e   0.000000E+00    3.180749E+00    0.000000E+00         E    9.00000E+100
#        1100  traj.phases.descent.collocation_constraint.defects:gam                     e   0.000000E+00    2.843106E+00    0.000000E+00         E    9.00000E+100
#        1101  traj.phases.descent.collocation_constraint.defects:gam                     e   0.000000E+00    2.740429E+00    0.000000E+00         E    9.00000E+100
#        1102  traj.phases.descent.collocation_constraint.defects:gam                     e   0.000000E+00    2.512316E+00    0.000000E+00         E    9.00000E+100
#        1103  traj.phases.descent.collocation_constraint.defects:gam                     e   0.000000E+00    2.212437E+00    0.000000E+00         E    9.00000E+100
#        1104  traj.phases.descent.collocation_constraint.defects:gam                     e   0.000000E+00    2.120867E+00    0.000000E+00         E    9.00000E+100
#        1105  traj.phases.descent.collocation_constraint.defects:gam                     e   0.000000E+00    1.916823E+00    0.000000E+00         E    9.00000E+100
#        1106  traj.phases.descent.collocation_constraint.defects:gam                     e   0.000000E+00    1.647348E+00    0.000000E+00         E    9.00000E+100
#        1107  traj.phases.descent.collocation_constraint.defects:gam                     e   0.000000E+00    1.564791E+00    0.000000E+00         E    9.00000E+100
#        1108  traj.phases.descent.collocation_constraint.defects:gam                     e   0.000000E+00    1.380395E+00    0.000000E+00         E    9.00000E+100
#        1109  traj.phases.descent.collocation_constraint.defects:gam                     e   0.000000E+00    1.135980E+00    0.000000E+00         E    9.00000E+100
#        1110  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    4.484273E+00    0.000000E+00         E    9.00000E+100
#        1111  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    4.713000E+00    0.000000E+00         E    9.00000E+100
#        1112  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    5.069970E+00    0.000000E+00         E    9.00000E+100
#        1113  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    5.192986E+00    0.000000E+00         E    9.00000E+100
#        1114  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    5.492929E+00    0.000000E+00         E    9.00000E+100
#        1115  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    5.948665E+00    0.000000E+00         E    9.00000E+100
#        1116  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    6.103061E+00    0.000000E+00         E    9.00000E+100
#        1117  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    6.475080E+00    0.000000E+00         E    9.00000E+100
#        1118  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    7.030764E+00    0.000000E+00         E    9.00000E+100
#        1119  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    7.216912E+00    0.000000E+00         E    9.00000E+100
#        1120  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    7.661858E+00    0.000000E+00         E    9.00000E+100
#        1121  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    8.318656E+00    0.000000E+00         E    9.00000E+100
#        1122  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    8.536925E+00    0.000000E+00         E    9.00000E+100
#        1123  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    9.055635E+00    0.000000E+00         E    9.00000E+100
#        1124  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    9.814693E+00    0.000000E+00         E    9.00000E+100
#        1125  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    1.006544E+01    0.000000E+00         E    9.00000E+100
#        1126  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    1.065873E+01    0.000000E+00         E    9.00000E+100
#        1127  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    1.152117E+01    0.000000E+00         E    9.00000E+100
#        1128  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    1.180475E+01    0.000000E+00         E    9.00000E+100
#        1129  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    1.247341E+01    0.000000E+00         E    9.00000E+100
#        1130  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    1.344031E+01    0.000000E+00         E    9.00000E+100
#        1131  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    1.375705E+01    0.000000E+00         E    9.00000E+100
#        1132  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    1.450186E+01    0.000000E+00         E    9.00000E+100
#        1133  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    1.557425E+01    0.000000E+00         E    9.00000E+100
#        1134  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    1.592449E+01    0.000000E+00         E    9.00000E+100
#        1135  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    1.674617E+01    0.000000E+00         E    9.00000E+100
#        1136  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    1.792504E+01    0.000000E+00         E    9.00000E+100
#        1137  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    1.830913E+01    0.000000E+00         E    9.00000E+100
#        1138  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    1.920831E+01    0.000000E+00         E    9.00000E+100
#        1139  traj.phases.descent.collocation_constraint.defects:v                       e   0.000000E+00    2.049470E+01    0.000000E+00         E    9.00000E+100
#        1140  traj.linkages.propelled_ascent:time_final|ballistic_ascent:time_initial    e   0.000000E+00    5.551115E-17    0.000000E+00              9.00000E+100
#        1141  traj.linkages.propelled_ascent:r_final|ballistic_ascent:r_initial          e   0.000000E+00    3.000000E+00    0.000000E+00         E    9.00000E+100
#        1142  traj.linkages.propelled_ascent:h_final|ballistic_ascent:h_initial          e   0.000000E+00    0.000000E+00    0.000000E+00              9.00000E+100
#        1143  traj.linkages.propelled_ascent:gam_final|ballistic_ascent:gam_initial      e   0.000000E+00    0.000000E+00    0.000000E+00              9.00000E+100
#        1144  traj.linkages.propelled_ascent:v_final|ballistic_ascent:v_initial          e   0.000000E+00    4.000000E+01    0.000000E+00         E    9.00000E+100
#        1145  traj.linkages.ballistic_ascent:time_final|descent:time_initial             e   0.000000E+00   -4.700000E+00    0.000000E+00         E    9.00000E+100
#        1146  traj.linkages.ballistic_ascent:r_final|descent:r_initial                   e   0.000000E+00    0.000000E+00    0.000000E+00              9.00000E+100
#        1147  traj.linkages.ballistic_ascent:h_final|descent:h_initial                   e   0.000000E+00    9.000000E+01    0.000000E+00         E    9.00000E+100
#        1148  traj.linkages.ballistic_ascent:gam_final|descent:gam_initial               e   0.000000E+00    0.000000E+00    0.000000E+00              9.00000E+100
#        1149  traj.linkages.ballistic_ascent:v_final|descent:v_initial                   e   0.000000E+00    0.000000E+00    0.000000E+00              9.00000E+100
#
# --------------------------------------------------------------------------------
# Launch angle: 80.0000 deg
# Flight angle at end of propulsion: 80.0000 deg
# Empty mass: 0.1500 kg
# Water volume: 9.0000 L
# Maximum range: 20.0000 m
# Maximum height: 100.0000 m
# Maximum velocity: 100.0000 m/s
#
# Simulating trajectory traj
# Done simulating trajectory traj

# %%
from openmdao.utils.assert_utils import assert_near_equal

# Check results (tolerance is relative unless value is zero)
assert_near_equal(summary['Launch angle'].value, 46, 0.02)
assert_near_equal(summary['Flight angle at end of propulsion'].value, 38, 0.02)
assert_near_equal(summary['Empty mass'].value, 0.189, 1e-2)
assert_near_equal(summary['Water volume'].value, 1.026, 1e-2)
assert_near_equal(summary['Maximum range'].value, 85.11, 1e-2)
assert_near_equal(summary['Maximum height'].value, 23.08, 1e-2)
assert_near_equal(summary['Maximum velocity'].value, 41.31, 1e-2)

# %% [markdown]
# ## References
#
# ```{bibliography}
# :filter: docname in docnames
# ```
